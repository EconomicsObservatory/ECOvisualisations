# %%
import json
import altair as alt
from altair import expr, datum
import altair_viewer
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import re

# %%
import colorsys
from matplotlib.colors import to_hex, to_rgb


def scale_lightness(rgb, scale_l):
    rgbhex = False
    if "#" in rgb:
        rgb = to_rgb(rgb)
        rgbhex = True
    # convert rgb to hls
    h, l, s = colorsys.rgb_to_hls(*rgb)
    # manipulate h, l, s values and return as rgb
    c = colorsys.hls_to_rgb(h, min(1, l * scale_l), s=s)
    if rgbhex:
        c = to_hex(c)
    return c

# %%
LOCAL = True

if LOCAL:
    local_suffix = "_local"
else:
    local_suffix = ""

# %%
# %%capture pwd
# !pwd

# %%
uid = pwd.stdout.split("/")[-1].split("\r")[0]
eco_git_home = (
    "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/"
)
eco_git_path = (
    eco_git_home + "magazine/" + uid + "/data/"
)  #!!! make sure this points to the magazine
vega_embed = requests.get(eco_git_home + "guidelines/html/vega-embed.html").text
colors = json.loads(
    requests.get(eco_git_home + "guidelines/colors/eco-colors.json").content
)
category_color = json.loads(
    requests.get(eco_git_home + "guidelines/colors/eco-category-color.json").content
)
hue_color = json.loads(
    requests.get(eco_git_home + "guidelines/colors/eco-single-hue-color.json").content
)
mhue_color = json.loads(
    requests.get(eco_git_home + "guidelines/colors/eco-multi-hue-color.json").content
)
div_color = json.loads(
    requests.get(eco_git_home + "guidelines/colors/eco-diverging-color.json").content
)
config = json.loads(
    requests.get(eco_git_home + "guidelines/charts/eco-global-config.json").content
)
height = config["height"]
width = config["width"]
uid, height, width
# Out:
# ('issue-2', 300, 500)

# %% [markdown]
# # Article 4
# ## Climate in numbers

# %%
readme = "# Article 4 \n\n## Climate in numbers\n\n"
open("README.md", "w").write(readme)
# Out:
# 37

# %% [markdown]
# ### Fig 4-1

# %%
configSource = "raw/ECO2.DATA.C1.json"
config = json.loads(open(configSource, "r").read())
df = pd.read_csv(config["data"]["url"]).drop("Detail", axis=1)

# %%
f = "fig4-1_fossil-fuels"
f4_1 = eco_git_path + f + ".csv"
df.to_csv("data/" + f + ".csv")
f += local_suffix
open("visualisation/" + f + ".html", "w").write(
    vega_embed.replace(
        "JSON_PATH", f4_1.replace("/data/", "/visualisation/").replace(".csv", ".json")
    )
)
if LOCAL:
    f4_1 = df
readme = (
    "### "
    + f
    + " --- [json](visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg](visualisation/'
    + f
    + '.svg "'
    + f
    + '") [png](visualisation/'
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"](visualisation/'
    + f
    + '.svg "'
    + f
    + '")](visualisation/'
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
df.head()
# Out:
#    Time  Value Source
# 0  1850    569   Coal
# 1  1860   1061   Coal
# 2  1870   1642   Coal
# 3  1880   2542   Coal
# 4  1890   3856   Coal

# %%
config = json.loads(open(configSource, "r").read())
if not LOCAL:
    config["data"]["url"] = f4_1
config["encoding"]["x"]["axis"]["grid"] = False
config["encoding"]["x"]["axis"]["labelColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["titleColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["tickColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["domainColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["grid"] = True
config["encoding"]["y"]["axis"]["gridColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["gridOpacity"] = 0.1
config["encoding"]["y"]["axis"]["title"] = ""
config["encoding"]["y"]["axis"]["titleAnchor"] = "start"
config["encoding"]["y"]["axis"]["labelColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["titleColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["tickColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["domainColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["titleFontSize"] = 10
config["encoding"]["y"]["axis"]["titleFontWeight"] = "normal"
config["encoding"]["y"]["axis"]["ticks"] = False
config["encoding"]["y"]["axis"]["labelAlign"] = "left"
config["encoding"]["y"]["axis"]["labelBaseline"] = "middle"
config["encoding"]["y"]["axis"]["labelPadding"] = -5
config["encoding"]["y"]["axis"]["labelOffset"] = -10
config["encoding"]["y"]["axis"]["titleBaseline"] = "bottom"
config["encoding"]["y"]["axis"]["titleAngle"] = 0
config["encoding"]["y"]["axis"]["titleAlign"] = "left"
config["encoding"]["y"]["axis"]["tickCount"] = 7
config["encoding"]["y"]["axis"]["titleX"] = 45
config["encoding"]["y"]["axis"]["titleY"] = -5
config["title"]["dy"] = -5
config["mark"] = {"type": "area", "opacity": 0.9}
config.pop("$schema")
config["encoding"]["color"]["legend"] = None
config["view"] = {"stroke": None}
config["width"] = 300
config["height"] = 220
base = alt.Chart.from_dict(config)
text = (
    base.mark_text(dy=35, color=colors["eco-gray"])
    .encode(
        text="Source:N",
        y=alt.Y("Value:Q", stack=True),
        color=alt.Color("c:N", scale=None),
    )
    .transform_calculate(c="'" + scale_lightness(colors["eco-gray"], 0.1) + "'")
    .transform_filter("year(datum.Time)==2012")
)
layer1 = (base + text).configure_view(stroke=None)
layer1.save("visualisation/" + f + ".json")
layer1.save("visualisation/" + f + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + ".svg")
open("README.md", "a").write(readme)
layer1
# altair_viewer.display(config, inline=True)
# Out:
# alt.LayerChart(...)

# %%
theme = "_dark"
base.title.fontSize = 14
base.title.subtitleFontSize = 12
base.title.dy -= 2
base.encoding.y.axis.titleY += 2
base.encoding.y.axis.titleX += 8
base.title.color = colors["eco-dot"]
base.title.subtitleColor = colors["eco-dot"]
layer1 = (base + text).configure_view(stroke=None)
layer1 = layer1.configure_axisY(labelFontSize=12)
layer1 = layer1.configure_axisX(labelFontSize=12)
layer1.config.font = "Georgia"
layer1.config.background = colors["eco-background"]
layer1.config.view.stroke = None
layer1.save("visualisation/" + f + theme + ".json")
layer1.save("visualisation/" + f + theme + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + theme + ".svg")
readme = re.sub(f, f + theme, readme)
open("README.md", "a").write(readme)
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Fig 4-2

# %% [markdown]
# #### a

# %%
configSource = "raw/ECO2.DATA.C2.json"
config = json.loads(open(configSource, "r").read())
df = pd.read_csv(config["data"]["url"]).drop("Detail", axis=1)

# %%
f = "fig4-2a_emissions"
f4_2a = eco_git_path + f + ".csv"
df.to_csv("data/" + f + ".csv")
f += local_suffix
open("visualisation/" + f + ".html", "w").write(
    vega_embed.replace(
        "JSON_PATH", f4_2a.replace("/data/", "/visualisation/").replace(".csv", ".json")
    )
)
if LOCAL:
    f4_2a = df
readme = (
    "### "
    + f
    + " --- [json](visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg](visualisation/'
    + f
    + '.svg "'
    + f
    + '") [png](visualisation/'
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"](visualisation/'
    + f
    + '.svg "'
    + f
    + '")](visualisation/'
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
df.head()
# Out:
#    Time Country     Value    Value2
# 0  1901  Brazil  0.113602  National
# 1  1902  Brazil  0.132434  National
# 2  1903  Brazil  0.126165  National
# 3  1904  Brazil  0.132560  National
# 4  1905  Brazil  0.138663  National

# %%
config = json.loads(open(configSource, "r").read())
if not LOCAL:
    config["data"]["url"] = f4_2a
config["encoding"]["x"]["axis"]["grid"] = False
config["encoding"]["x"]["axis"]["labelColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["titleColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["tickColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["domainColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["grid"] = True
config["encoding"]["y"]["axis"]["gridColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["gridOpacity"] = 0.1
config["encoding"]["y"]["axis"]["title"] = ""
config["encoding"]["y"]["axis"]["titleAnchor"] = "start"
config["encoding"]["y"]["axis"]["labelColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["titleColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["tickColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["domainColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["titleFontSize"] = 10
config["encoding"]["y"]["axis"]["titleFontWeight"] = "normal"
config["encoding"]["y"]["axis"]["ticks"] = False
config["encoding"]["y"]["axis"]["labelAlign"] = "left"
config["encoding"]["y"]["axis"]["labelBaseline"] = "middle"
config["encoding"]["y"]["axis"]["labelPadding"] = -5
config["encoding"]["y"]["axis"]["labelOffset"] = -10
config["encoding"]["y"]["axis"]["titleBaseline"] = "bottom"
config["encoding"]["y"]["axis"]["titleAngle"] = 0
config["encoding"]["y"]["axis"]["titleAlign"] = "left"
config["encoding"]["y"]["axis"]["tickCount"] = 7
config["encoding"]["y"]["axis"]["titleX"] = 45
config["encoding"]["y"]["axis"]["titleY"] = -5
config["title"]["dy"] = -5
config["encoding"].pop("facet")
config.pop("$schema")
config.pop("resolve")
config["encoding"]["color"]["legend"] = None
config["view"] = {"stroke": None}
config["width"] = 300
config["height"] = 220
base = alt.Chart.from_dict(config)
text = (
    base.mark_text(dx=5, align="left")
    .encode(text="Country:N")
    .transform_filter("year(datum.Time)==2018")
    .transform_filter("datum.Country!='Brazil'")
)
text2 = (
    base.mark_text(dx=5, dy=-10, align="left")
    .encode(text="Country:N")
    .transform_filter("year(datum.Time)==2018")
    .transform_filter("datum.Country=='Brazil'")
)
layer1 = (
    (base + text + text2)
    .transform_filter("datum.Country!='World'")
    .configure_view(stroke=None)
)
layer1.save("visualisation/" + f + ".json")
layer1.save("visualisation/" + f + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + ".svg")
open("README.md", "a").write(readme)
layer1
# altair_viewer.display(config, inline=True)
# Out:
# alt.LayerChart(...)

# %%
theme = "_dark"
base.title.fontSize = 14
base.title.subtitleFontSize = 12
base.title.dy -= 2
base.encoding.y.axis.titleY += 2
base.encoding.y.axis.titleX += 8
base.title.color = colors["eco-dot"]
base.title.subtitleColor = colors["eco-dot"]
layer1 = (
    (base + text + text2)
    .transform_filter("datum.Country!='World'")
    .configure_view(stroke=None)
)
layer1 = layer1.configure_axisY(labelFontSize=12)
layer1 = layer1.configure_axisX(labelFontSize=12)
layer1.config.font = "Georgia"
layer1.config.background = colors["eco-background"]
layer1.config.view.stroke = None
layer1.save("visualisation/" + f + theme + ".json")
layer1.save("visualisation/" + f + theme + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + theme + ".svg")
readme = re.sub(f, f + theme, readme)
open("README.md", "a").write(readme)
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# #### b

# %%
f = "fig4-2b_emissions"
f4_2b = eco_git_path + f + ".csv"
df.to_csv("data/" + f + ".csv")
f += local_suffix
open("visualisation/" + f + ".html", "w").write(
    vega_embed.replace(
        "JSON_PATH", f4_2b.replace("/data/", "/visualisation/").replace(".csv", ".json")
    )
)
if LOCAL:
    f4_2b = df
readme = (
    "### "
    + f
    + " --- [json](visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg](visualisation/'
    + f
    + '.svg "'
    + f
    + '") [png](visualisation/'
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"](visualisation/'
    + f
    + '.svg "'
    + f
    + '")](visualisation/'
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
df.head()
# Out:
#    Time Country     Value    Value2
# 0  1901  Brazil  0.113602  National
# 1  1902  Brazil  0.132434  National
# 2  1903  Brazil  0.126165  National
# 3  1904  Brazil  0.132560  National
# 4  1905  Brazil  0.138663  National

# %%
config = json.loads(open(configSource, "r").read())
if not LOCAL:
    config["data"]["url"] = f4_2a
config["encoding"]["x"]["axis"]["grid"] = False
config["encoding"]["x"]["axis"]["labelColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["titleColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["tickColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["domainColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["grid"] = True
config["encoding"]["y"]["axis"]["gridColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["gridOpacity"] = 0.1
config["encoding"]["y"]["axis"]["title"] = ""
config["encoding"]["y"]["axis"]["titleAnchor"] = "start"
config["encoding"]["y"]["axis"]["labelColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["titleColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["tickColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["domainColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["titleFontSize"] = 10
config["encoding"]["y"]["axis"]["titleFontWeight"] = "normal"
config["encoding"]["y"]["axis"]["ticks"] = False
config["encoding"]["y"]["axis"]["labelAlign"] = "left"
config["encoding"]["y"]["axis"]["labelBaseline"] = "middle"
config["encoding"]["y"]["axis"]["labelPadding"] = -5
config["encoding"]["y"]["axis"]["labelOffset"] = -10
config["encoding"]["y"]["axis"]["titleBaseline"] = "bottom"
config["encoding"]["y"]["axis"]["titleAngle"] = 0
config["encoding"]["y"]["axis"]["titleAlign"] = "left"
config["encoding"]["y"]["axis"]["tickCount"] = 7
config["encoding"]["y"]["axis"]["titleX"] = 45
config["encoding"]["y"]["axis"]["titleY"] = -5
config["title"]["dy"] = -5
config["encoding"].pop("facet")
config.pop("$schema")
config.pop("resolve")
config["encoding"]["color"]["legend"] = None
config["view"] = {"stroke": None}
config["width"] = 300
config["height"] = 220
base = alt.Chart.from_dict(config)
text = (
    base.mark_text(dx=5, align="left")
    .encode(text="Country:N")
    .transform_filter("year(datum.Time)==2018")
)
layer1 = (
    (base + text).transform_filter("datum.Country=='World'").configure_view(stroke=None)
)
layer1.save("visualisation/" + f + ".json")
layer1.save("visualisation/" + f + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + ".svg")
open("README.md", "a").write(readme)
layer1
# Out:
# alt.LayerChart(...)

# %%
theme = "_dark"
base.title.fontSize = 14
base.title.subtitleFontSize = 12
base.title.dy -= 2
base.encoding.y.axis.titleY += 2
base.encoding.y.axis.titleX += 8
base.title.color = colors["eco-dot"]
base.title.subtitleColor = colors["eco-dot"]
layer1 = (
    (base + text).transform_filter("datum.Country=='World'").configure_view(stroke=None)
)
layer1 = layer1.configure_axisY(labelFontSize=12)
layer1 = layer1.configure_axisX(labelFontSize=12)
layer1.config.font = "Georgia"
layer1.config.background = colors["eco-background"]
layer1.config.view.stroke = None
layer1.save("visualisation/" + f + theme + ".json")
layer1.save("visualisation/" + f + theme + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + theme + ".svg")
readme = re.sub(f, f + theme, readme)
open("README.md", "a").write(readme)
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Fig 4-3

# %%
# https://climateactiontracker.org/global/temperatures/
df = pd.read_excel(
    "raw/CAT_2021-05_PublicData_EmissionPathways.xlsx", skiprows=14, nrows=12
).dropna(axis=1, how="all")
df = df.set_index(["Unnamed: 1", "GtCO2e"]).T.reset_index()
df.columns = [
    "year",
    "current_high",
    "current_low",
    "pledges_high",
    "pledges_low",
    "optimistic",
    "c2_high",
    "c2_median",
    "c2_low",
    "c1_high",
    "c1_median",
    "c1_low",
    "historical",
]
df = df.set_index("year").stack().reset_index()
df["scenario"] = df["level_1"].str.split("_").str[0]
df["projection"] = df["level_1"].str.split("_").str[-1]
df = df.set_index(["year", "scenario", "projection"])[0].unstack().reset_index()
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/core/async_helpers.py:68: PerformanceWarning: indexing past lexsort depth may impact performance.
#   coro.send(None)

# %%
f = "fig4-3_climate-scenarios"
f4_3 = eco_git_path + f + ".csv"
df.to_csv("data/" + f + ".csv")
f += local_suffix
open("visualisation/" + f + ".html", "w").write(
    vega_embed.replace(
        "JSON_PATH", f4_3.replace("/data/", "/visualisation/").replace(".csv", ".json")
    )
)
if LOCAL:
    f4_3 = df
readme = (
    "### "
    + f
    + " --- [json](visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg](visualisation/'
    + f
    + '.svg "'
    + f
    + '") [png](visualisation/'
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"](visualisation/'
    + f
    + '.svg "'
    + f
    + '")](visualisation/'
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
df.head()
# Out:
# projection  year    scenario  high  historical  low  median  optimistic
# 0           1990  historical   NaN   35.989277  NaN     NaN         NaN
# 1           1991  historical   NaN   36.352906  NaN     NaN         NaN
# 2           1992  historical   NaN   35.529755  NaN     NaN         NaN
# 3           1993  historical   NaN   35.736477  NaN     NaN         NaN
# 4           1994  historical   NaN   35.857245  NaN     NaN         NaN

# %%
base = alt.Chart(f4_3).encode(
    x=alt.X(
        "year:Q",
        axis=alt.Axis(
            grid=False,
            titleAlign="center",
            titleAnchor="middle",
            title="",
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            tickCount=5,
            orient="bottom",
            labelAngle=0,
            format=".0f",
            # zindex=1,
            # offset=-43
        ),
    )
)
line1 = (
    base.mark_line(color=colors["eco-gray"])
    .encode(
        y=alt.Y(
            "historical:Q",
            axis=alt.Axis(
                grid=True,
                gridColor=colors["eco-gray"],
                gridOpacity=0.1,
                title="GtCO₂e per year",
                titleAnchor="start",
                labelColor=colors["eco-gray"],
                titleColor=colors["eco-gray"],
                tickColor=colors["eco-gray"],
                domainColor=colors["eco-gray"],
                titleFontSize=10,
                titleFontWeight="normal",
                ticks=False,
                labelAlign="left",
                labelBaseline="middle",
                labelPadding=-5,
                labelOffset=-10,
                titleX=20,
                titleY=-5,
                titleBaseline="bottom",
                titleAngle=0,
                titleAlign="left",
                tickCount=7,
                format=".0f",
            ),
        )
    )
    .transform_filter('datum.scenario=="historical"')
)
line2 = (
    base.mark_line(color=colors["eco-mid-blue"])
    .encode(y=alt.Y("optimistic:Q"))
    .transform_filter('datum.scenario=="optimistic"')
)
line3 = (
    base.mark_line(color=colors["eco-turquiose"], strokeDash=[5, 5], strokeWidth=1)
    .encode(y=alt.Y("median:Q"))
    .transform_filter('datum.scenario=="c1"')
)
line4 = (
    base.mark_line(color=colors["eco-light-blue"], strokeDash=[5, 5], strokeWidth=1)
    .encode(y=alt.Y("median:Q"))
    .transform_filter('datum.scenario=="c2"')
)
area1 = line3.mark_area(color=colors["eco-turquiose"], opacity=0.6).encode(
    y="low:Q", y2="high:Q"
)
area2 = line4.mark_area(color=colors["eco-light-blue"], opacity=0.6).encode(
    y="low:Q", y2="high:Q"
)
area3 = (
    base.mark_area(color=colors["eco-mid-blue"], opacity=0.6)
    .encode(y="low:Q", y2="high:Q")
    .transform_filter('datum.scenario=="pledges"')
)
area4 = (
    base.mark_area(color=colors["eco-gray"], opacity=0.6)
    .encode(
        y="low:Q",
        y2="high:Q",
    )
    .transform_filter('datum.scenario=="current"')
)
ruler = (
    base.mark_line(color=colors["eco-gray"]).encode(y="y:Q").transform_calculate(y="0")
)
r2021 = (
    base.mark_rule(
        color=scale_lightness(colors["eco-gray"], 1.5),
        strokeDash=[5, 5],
        strokeWidth=0.5,
    )
    .encode(x="x:Q")
    .transform_calculate(x="2021")
)
text2021 = (
    alt.Chart(pd.DataFrame([{"x": 2021, "y": 0, "t": "2021"}]))
    .mark_text(
        color=scale_lightness(colors["eco-gray"], 1.5),
        align="left",
        baseline="bottom",
        dx=5,
        dy=-5,
    )
    .encode(x="x:Q", y="y:Q", text="t:N")
)
text1 = (
    alt.Chart(
        pd.DataFrame(
            [
                {"x": 2100, "y": 43, "t": "Current policies"},
                {"x": 2100, "y": 40, "t": "2.7 - 3.1 °C"},
            ]
        )
    )
    .mark_text(color=colors["eco-gray"], align="left", dx=5)
    .encode(x="x:Q", y="y:Q", text="t:N")
)
text2 = (
    alt.Chart(
        pd.DataFrame(
            [
                {"x": 2100, "y": 21, "t": "Pledges & targets"},
                {"x": 2100, "y": 18, "t": "2.4 °C"},
            ]
        )
    )
    .mark_text(color=colors["eco-mid-blue"], align="left", dx=5)
    .encode(x="x:Q", y="y:Q", text="t:N")
)
text3 = (
    alt.Chart(
        pd.DataFrame(
            [
                {"x": 2100, "y": 14, "t": "Net-zero targets"},
                {"x": 2100, "y": 11, "t": "2.0 °C"},
            ]
        )
    )
    .mark_text(color=colors["eco-mid-blue"], align="left", dx=5)
    .encode(x="x:Q", y="y:Q", text="t:N")
)
text4 = (
    alt.Chart(
        pd.DataFrame(
            [
                {"x": 2100, "y": 2, "t": "<2 °C consistent"},
                {"x": 2100, "y": -1, "t": "1.6 - 1.7 °C"},
            ]
        )
    )
    .mark_text(color=colors["eco-light-blue"], align="left", dx=5)
    .encode(x="x:Q", y="y:Q", text="t:N")
)
text5 = (
    alt.Chart(
        pd.DataFrame(
            [
                {"x": 2100, "y": -5, "t": "<1.5 °C consistent"},
                {"x": 2100, "y": -8, "t": "1.3 °C"},
            ]
        )
    )
    .mark_text(color=colors["eco-turquiose"], align="left", dx=5)
    .encode(x="x:Q", y="y:Q", text="t:N")
)
title = alt.TitleParams(
    "Global greenhouse gas emissions and warming projections until 2100",
    subtitle=[
        "Global CO₂ emissions. Source: Climate Action Tracker, May 2021 briefing"
    ],
    anchor="start",
    align="left",
    dx=5,
    fontSize=12,
    subtitleFontSize=11,
    subtitleFontStyle="italic",
)
layer1 = (
    (
        (
            ruler
            + r2021
            + area1
            + area2
            + area3
            + area4
            + line1
            + line2
            + line3
            + line4
            + text2021
            + text1
            + text2
            + text3
            + text4
            + text5
        ).properties(height=300, width=400)
    )
    .configure_view(stroke=None)
    .properties(title=title)
)
layer1.save("visualisation/" + f + ".json")
layer1.save("visualisation/" + f + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + ".svg")
open("README.md", "a").write(readme)
layer1
# Out:
# alt.LayerChart(...)

# %%
base = alt.Chart(f4_3).encode(
    x=alt.X(
        "year:Q",
        axis=alt.Axis(
            grid=False,
            titleAlign="center",
            titleAnchor="middle",
            title="",
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            tickCount=5,
            titleFontSize=12,
            labelFontSize=12,
            orient="bottom",
            labelAngle=0,
            format=".0f",
            # zindex=1,
            # offset=-43
        ),
    )
)
line1 = (
    base.mark_line(color=colors["eco-gray"])
    .encode(
        y=alt.Y(
            "historical:Q",
            axis=alt.Axis(
                grid=True,
                gridColor=colors["eco-gray"],
                gridOpacity=0.1,
                title="GtCO₂e per year",
                titleAnchor="start",
                labelColor=colors["eco-gray"],
                titleColor=colors["eco-gray"],
                tickColor=colors["eco-gray"],
                domainColor=colors["eco-gray"],
                titleFontSize=12,
                labelFontSize=12,
                titleFontWeight="normal",
                ticks=False,
                labelAlign="left",
                labelBaseline="middle",
                labelPadding=-5,
                labelOffset=-10,
                titleX=22,
                titleY=-3,
                titleBaseline="bottom",
                titleAngle=0,
                titleAlign="left",
                tickCount=7,
                format=".0f",
            ),
        )
    )
    .transform_filter('datum.scenario=="historical"')
)
line2 = (
    base.mark_line(color=colors["eco-mid-blue"])
    .encode(y=alt.Y("optimistic:Q"))
    .transform_filter('datum.scenario=="optimistic"')
)
line3 = (
    base.mark_line(color=colors["eco-turquiose"], strokeDash=[5, 5], strokeWidth=1)
    .encode(y=alt.Y("median:Q"))
    .transform_filter('datum.scenario=="c1"')
)
line4 = (
    base.mark_line(color=colors["eco-light-blue"], strokeDash=[5, 5], strokeWidth=1)
    .encode(y=alt.Y("median:Q"))
    .transform_filter('datum.scenario=="c2"')
)
area1 = line3.mark_area(color=colors["eco-turquiose"], opacity=0.6).encode(
    y="low:Q", y2="high:Q"
)
area2 = line4.mark_area(color=colors["eco-light-blue"], opacity=0.6).encode(
    y="low:Q", y2="high:Q"
)
area3 = (
    base.mark_area(color=colors["eco-mid-blue"], opacity=0.6)
    .encode(y="low:Q", y2="high:Q")
    .transform_filter('datum.scenario=="pledges"')
)
area4 = (
    base.mark_area(color=colors["eco-gray"], opacity=0.6)
    .encode(
        y="low:Q",
        y2="high:Q",
    )
    .transform_filter('datum.scenario=="current"')
)
ruler = (
    base.mark_line(color=colors["eco-gray"]).encode(y="y:Q").transform_calculate(y="0")
)
r2021 = (
    base.mark_rule(
        color=scale_lightness(colors["eco-gray"], 0.7),
        strokeDash=[5, 5],
        strokeWidth=0.5,
    )
    .encode(x="x:Q")
    .transform_calculate(x="2021")
)
text2021 = (
    alt.Chart(pd.DataFrame([{"x": 2021, "y": 0, "t": "2021"}]))
    .mark_text(
        color=scale_lightness(colors["eco-gray"], 0.7),
        align="left",
        baseline="bottom",
        dx=5,
        dy=-5,
    )
    .encode(x="x:Q", y="y:Q", text="t:N")
)
text1 = (
    alt.Chart(
        pd.DataFrame(
            [
                {"x": 2100, "y": 43, "t": "Current policies"},
                {"x": 2100, "y": 40, "t": "2.7 - 3.1 °C"},
            ]
        )
    )
    .mark_text(color=colors["eco-gray"], align="left", dx=5)
    .encode(x="x:Q", y="y:Q", text="t:N")
)
text2 = (
    alt.Chart(
        pd.DataFrame(
            [
                {"x": 2100, "y": 21, "t": "Pledges & targets"},
                {"x": 2100, "y": 18, "t": "2.4 °C"},
            ]
        )
    )
    .mark_text(color=colors["eco-mid-blue"], align="left", dx=5)
    .encode(x="x:Q", y="y:Q", text="t:N")
)
text3 = (
    alt.Chart(
        pd.DataFrame(
            [
                {"x": 2100, "y": 14, "t": "Net-zero targets"},
                {"x": 2100, "y": 11, "t": "2.0 °C"},
            ]
        )
    )
    .mark_text(color=colors["eco-mid-blue"], align="left", dx=5)
    .encode(x="x:Q", y="y:Q", text="t:N")
)
text4 = (
    alt.Chart(
        pd.DataFrame(
            [
                {"x": 2100, "y": 2, "t": "<2 °C consistent"},
                {"x": 2100, "y": -1, "t": "1.6 - 1.7 °C"},
            ]
        )
    )
    .mark_text(color=colors["eco-light-blue"], align="left", dx=5)
    .encode(x="x:Q", y="y:Q", text="t:N")
)
text5 = (
    alt.Chart(
        pd.DataFrame(
            [
                {"x": 2100, "y": -5, "t": "<1.5 °C consistent"},
                {"x": 2100, "y": -8, "t": "1.3 °C"},
            ]
        )
    )
    .mark_text(color=colors["eco-turquiose"], align="left", dx=5)
    .encode(x="x:Q", y="y:Q", text="t:N")
)
title = alt.TitleParams(
    "Global greenhouse gas emissions and warming projections until 2100",
    subtitle=[
        "Global CO₂ emissions. Source: Climate Action Tracker, May 2021 breifing"
    ],
    anchor="start",
    align="left",
    dx=5,
    dy=-10,
    fontSize=14,
    subtitleFontSize=12,
    color=colors["eco-dot"],
    subtitleColor=colors["eco-dot"],
    subtitleFontStyle="italic",
)
layer1 = (
    (
        (
            ruler
            + r2021
            + area1
            + area2
            + area3
            + area4
            + line1
            + line2
            + line3
            + line4
            + text2021
            + text1
            + text2
            + text3
            + text4
            + text5
        ).properties(height=300, width=400)
    )
    .configure(font="Georgia", background=colors["eco-background"])
    .configure_view(stroke=None)
    .properties(title=title)
)
layer1.save("visualisation/" + f + "_dark.json")
layer1.save("visualisation/" + f + "_dark.png", scale_factor=2.0)
layer1.save("visualisation/" + f + "_dark.svg")
readme = re.sub(f, f + "_dark", readme)
open("README.md", "a").write(readme)
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Fig 4-4

# %%
configSource = "raw/ECO2.DATA.C4.json"
config = json.loads(open(configSource, "r").read())
df = pd.read_csv(config["data"]["url"])

# %%
f = "fig4-4_gdp-loss"
f4_4 = eco_git_path + f + ".csv"
df.to_csv("data/" + f + ".csv")
f += local_suffix
open("visualisation/" + f + ".html", "w").write(
    vega_embed.replace(
        "JSON_PATH", f4_4.replace("/data/", "/visualisation/").replace(".csv", ".json")
    )
)
if LOCAL:
    f4_4 = df
readme = (
    "### "
    + f
    + " --- [json](visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg](visualisation/'
    + f
    + '.svg "'
    + f
    + '") [png](visualisation/'
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"](visualisation/'
    + f
    + '.svg "'
    + f
    + '")](visualisation/'
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
df.head()
# Out:
#         Country  Scenario  Value 1
# 0      Thailand       1.4     -1.2
# 1   Phillipines       1.4     -1.3
# 2      Malaysia       1.4     -1.2
# 3  Saudi Arabia       1.4     -0.9
# 4     Indonesia       1.4     -0.6

# %%
config = json.loads(open(configSource, "r").read())
if not LOCAL:
    config["data"]["url"] = f4_4
config["encoding"]["x"]["axis"]["grid"] = False
config["title"][
    "subtitle"
] = "% change in GDP, ordered by most affected country. Source: Swiss Re"
config["encoding"]["x"]["axis"]["labelColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["titleColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["tickColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["domainColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"] = None
config["encoding"]["color"]["legend"]["labelColor"] = colors["eco-gray"]
config["encoding"]["color"]["legend"]["titleColor"] = colors["eco-gray"]
config["encoding"]["column"]["header"] = {}
config["encoding"]["column"]["header"]["labelColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["grid"] = True
config["encoding"]["y"]["axis"]["gridColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["gridOpacity"] = 0.1
config["encoding"]["y"]["axis"]["title"] = ""
config["encoding"]["y"]["axis"]["titleAnchor"] = "start"
config["encoding"]["y"]["axis"]["labelColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["titleColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["tickColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["domainColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["titleFontSize"] = 10
config["encoding"]["y"]["axis"]["titleFontWeight"] = "normal"
config["encoding"]["y"]["axis"]["tickCount"] = 7
config["encoding"]["y"]["axis"]["titleX"] = 45
config["encoding"]["y"]["axis"]["titleY"] = -5
config["encoding"]["y"]["axis"]["format"] = ".0%"
config["encoding"]["y"]["scale"] = {"domain": [-0.13, 0]}
config["encoding"]["y"]["field"] = "m"
config["title"]["dy"] = -5
config.pop("$schema")
config.pop("config")
config["view"] = {"stroke": None}
config["mark"] = {"type": "bar", "opacity": 0.9}
config["width"] = 50
config["height"] = 220
base = alt.Chart.from_dict(config).transform_calculate(m='datum["Value 1"]/100')
text = (
    base.mark_text(dx=5, align="left")
    .encode(text="Country:N")
    .transform_filter("year(datum.Time)==2018")
)
layer1 = (base).configure_view(stroke=None)
layer1.save("visualisation/" + f + ".json")
layer1.save("visualisation/" + f + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + ".svg")
open("README.md", "a").write(readme)
layer1
# altair_viewer.display(config, inline=True)
# Out:
# alt.Chart(...)

# %%
theme = "_dark"
base.title.fontSize = 14
base.title.subtitleFontSize = 12
base.title.dy -= 2
base.encoding.y.axis.titleY += 2
base.encoding.y.axis.titleX += 8
base.title.color = colors["eco-dot"]
base.title.subtitleColor = colors["eco-dot"]
layer1 = (base).configure_view(stroke=None)
layer1 = layer1.configure_axisY(labelFontSize=12)
layer1 = layer1.configure_axisX(labelFontSize=12)
layer1.config.font = "Georgia"
layer1.config.background = colors["eco-background"]
layer1.config.view.stroke = None
layer1.save("visualisation/" + f + theme + ".json")
layer1.save("visualisation/" + f + theme + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + theme + ".svg")
readme = re.sub(f, f + theme, readme)
open("README.md", "a").write(readme)
layer1
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Fig 4-5

# %%
configSource = "raw/ECO2.DATA.C5.json"
config = json.loads(open(configSource, "r").read())
df = pd.read_csv(config["data"]["url"])

# %%
f = "fig4-5_forest-area"
f4_5 = eco_git_path + f + ".csv"
df.to_csv("data/" + f + ".csv")
f += local_suffix
open("visualisation/" + f + ".html", "w").write(
    vega_embed.replace(
        "JSON_PATH", f4_5.replace("/data/", "/visualisation/").replace(".csv", ".json")
    )
)
if LOCAL:
    f4_5 = df
readme = (
    "### "
    + f
    + " --- [json](visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg](visualisation/'
    + f
    + '.svg "'
    + f
    + '") [png](visualisation/'
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"](visualisation/'
    + f
    + '.svg "'
    + f
    + '")](visualisation/'
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
df.head()
# Out:
#    Year Country    Value 1  Value 2
# 0  1990  Brazil  70.458021      0.0
# 1  1991  Brazil  70.005654     -0.6
# 2  1992  Brazil  69.553288     -1.3
# 3  1993  Brazil  69.100922     -1.9
# 4  1994  Brazil  68.648556     -2.6

# %%
config = json.loads(open(configSource, "r").read())
if not LOCAL:
    config["data"]["url"] = f4_5
config["title"]["text"] = "Forest area by country"
config["title"][
    "subtitle"
] = "% change, in square km (Base year = 1990). Source: World Bank"
config["encoding"]["x"]["axis"]["grid"] = False
config["encoding"]["x"]["axis"]["labelColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["titleColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["tickColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["domainColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["grid"] = True
config["encoding"]["y"]["axis"]["gridColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["gridOpacity"] = 0.1
config["encoding"]["y"]["axis"]["title"] = ""
config["encoding"]["y"]["axis"]["titleAnchor"] = "start"
config["encoding"]["y"]["axis"]["labelColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["titleColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["tickColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["domainColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["titleFontSize"] = 10
config["encoding"]["y"]["axis"]["titleFontWeight"] = "normal"
config["encoding"]["y"]["axis"]["ticks"] = False
config["encoding"]["y"]["axis"]["labelAlign"] = "left"
config["encoding"]["y"]["axis"]["labelBaseline"] = "middle"
config["encoding"]["y"]["axis"]["labelPadding"] = -5
config["encoding"]["y"]["axis"]["labelOffset"] = -10
config["encoding"]["y"]["axis"]["titleBaseline"] = "bottom"
config["encoding"]["y"]["axis"]["titleAngle"] = 0
config["encoding"]["y"]["axis"]["titleAlign"] = "left"
config["encoding"]["y"]["axis"]["format"] = ".0%"
config["encoding"]["y"]["axis"]["tickCount"] = 7
config["encoding"]["y"]["axis"]["titleX"] = 45
config["encoding"]["y"]["axis"]["titleY"] = -5
config["encoding"]["y"]["field"] = "m"
config["encoding"]["y"]["scale"] = {"domain": [-0.4, 0.05]}
config["title"]["dy"] = -5
config.pop("$schema")
config["encoding"]["color"]["legend"] = None
config["view"] = {"stroke": None}
config["width"] = 300
config["height"] = 220
base = alt.Chart.from_dict(config).transform_calculate(m='datum["Value 2"]/100')
text = (
    base.mark_text(dx=5, align="left")
    .encode(text="Country:N")
    .transform_filter("year(datum.Year)==2018")
)
layer1 = (base + text).configure_view(stroke=None)
layer1.save("visualisation/" + f + ".json")
layer1.save("visualisation/" + f + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + ".svg")
open("README.md", "a").write(readme)
layer1
# altair_viewer.display(config, inline=True)
# Out:
# alt.LayerChart(...)

# %%
theme = "_dark"
base.title.fontSize = 14
base.title.subtitleFontSize = 12
base.title.dy -= 2
base.encoding.y.axis.titleY += 2
base.encoding.y.axis.titleX += 8
base.title.color = colors["eco-dot"]
base.title.subtitleColor = colors["eco-dot"]
layer1 = (base + text).configure_view(stroke=None)
layer1 = layer1.configure_axisY(labelFontSize=12)
layer1 = layer1.configure_axisX(labelFontSize=12)
layer1.config.font = "Georgia"
layer1.config.background = colors["eco-background"]
layer1.config.view.stroke = None
layer1.save("visualisation/" + f + theme + ".json")
layer1.save("visualisation/" + f + theme + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + theme + ".svg")
readme = re.sub(f, f + theme, readme)
open("README.md", "a").write(readme)
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Fig 4-6

# %%
configSource = "raw/ECO2.DATA.C6.json"
config = json.loads(open(configSource, "r").read())
df = pd.read_csv(config["data"]["url"])

# %%
f = "fig4-6_endangered-species"
f4_6 = eco_git_path + f + ".csv"
df.to_csv("data/" + f + ".csv")
f += local_suffix
open("visualisation/" + f + ".html", "w").write(
    vega_embed.replace(
        "JSON_PATH", f4_6.replace("/data/", "/visualisation/").replace(".csv", ".json")
    )
)
if LOCAL:
    f4_6 = df
readme = (
    "### "
    + f
    + " --- [json](visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg](visualisation/'
    + f
    + '.svg "'
    + f
    + '") [png](visualisation/'
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"](visualisation/'
    + f
    + '.svg "'
    + f
    + '")](visualisation/'
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
df.head()
# Out:
#          Type  Value    Category  \
# 0     Mammals   1323  Vertebrate
# 1       Birds   1481  Vertebrate
# 2    Reptiles   1458  Vertebrate
# 3  Amphibians   2442  Vertebrate
# 4      Fishes   3210  Vertebrate
#
#                                               Detail
# 0  Value = Number of threatened species by 2021 (...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
config = json.loads(open(configSource, "r").read())
if not LOCAL:
    config["data"]["url"] = f4_6
config["encoding"]["x"]["axis"] = {}
config["encoding"]["x"]["axis"]["grid"] = True
config["encoding"]["x"]["axis"]["gridColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["gridOpacity"] = 0.1
config["encoding"]["x"]["axis"]["labelColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["titleColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["tickColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["domainColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["titleFontSize"] = 10
config["encoding"]["x"]["axis"]["titleAlign"] = "right"
config["encoding"]["x"]["axis"]["titleAnchor"] = "end"
config["encoding"]["x"]["axis"]["titleY"] = -15
config["encoding"]["x"]["axis"]["titleFontWeight"] = "normal"
config["encoding"]["y"]["axis"] = {}
config["encoding"]["y"]["axis"]["grid"] = False
config["encoding"]["y"]["axis"]["labelColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["titleColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["tickColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["domainColor"] = colors["eco-gray"]
config["encoding"]["y"].pop("sort")
config["title"]["dy"] = -5
# config.pop("$schema")
config["encoding"]["color"]["legend"] = None
config["mark"] = {"type": "bar", "opacity": 0.9}
config["view"] = {"stroke": None}
config["width"] = 300
config["height"] = 220
base = alt.Chart.from_dict(config)
text = (
    base.mark_text(dx=5, align="left")
    .encode(text="Country:N")
    .transform_filter("year(datum.Year)==2018")
)
layer1 = (base + text).configure_view(stroke=None)
layer1.save("visualisation/" + f + ".json")
layer1.save("visualisation/" + f + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + ".svg")
open("README.md", "a").write(readme)
layer1
# altair_viewer.display(config, inline=True)
# Out:
# WARN Infinite extent for field "sum_Value": [Infinity, -Infinity]
# WARN Infinite extent for field "sum_Value": [Infinity, -Infinity]
# alt.LayerChart(...)

# %%
theme = "_dark"
base.title.fontSize = 14
base.title.subtitleFontSize = 12
base.title.dy -= 2
base.title.color = colors["eco-dot"]
base.title.subtitleColor = colors["eco-dot"]
layer1 = (base + text).configure_view(stroke=None)
layer1 = layer1.configure_axisY(labelFontSize=12)
layer1 = layer1.configure_axisX(labelFontSize=12)
layer1.config.font = "Georgia"
layer1.config.background = colors["eco-background"]
layer1.config.view.stroke = None
layer1.save("visualisation/" + f + theme + ".json")
layer1.save("visualisation/" + f + theme + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + theme + ".svg")
readme = re.sub(f, f + theme, readme)
open("README.md", "a").write(readme)
layer1
# Out:
# WARN Infinite extent for field "sum_Value": [Infinity, -Infinity]
# WARN Infinite extent for field "sum_Value": [Infinity, -Infinity]
# alt.LayerChart(...)

# %% [markdown]
# # Article 5

# %% [markdown]
# ## Targets

# %%
readme = "# Article 5 \n\n## Targets\n\n"
open("README.md", "a").write(readme)
# Out:
# 26

# %%
p = (
    eco_git_path.split("main")[0].replace("rawgit", "github")
    + "tree/"
    + "main"
    + "/articles/is-the-uk-on-track-to-meet-its-climate-commitments/"
)
readme = "Cloned from [" + p.split("/")[-2] + "](" + p + ")\n\n"
open("README.md", "a").write(readme)
# Out:
# 206

# %% [markdown]
# ### Fig 5-1

# %%
f = "fig1_projected-emissions"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-cb855f641b7549c785ade2589679d3e2"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-cb855f641b7549c785ade2589679d3e2");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}}, "layer": [{"mark": {"type": "line", "color": "#676A86"}, "encoding": {"x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 5, "title": "\u2b05 historical   projection \u27a1", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": 302, "titleY": -15}, "field": "year"}, "y": {"type": "quantitative", "field": "y"}}, "transform": [{"calculate": "254", "as": "y"}]}, {"mark": {"type": "rule", "color": "#a8aabc", "strokeDash": [5, 5], "strokeWidth": 0.5}, "encoding": {"x": {"type": "quantitative", "field": "x"}}, "transform": [{"calculate": "2020", "as": "x"}]}, {"mark": {"type": "line", "color": "#36B7B4"}, "encoding": {"x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 5, "title": "\u2b05 historical   projection \u27a1", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": 302, "titleY": -15}, "field": "year"}, "y": {"type": "quantitative", "field": "projected"}}, "transform": [{"filter": "datum.year>=2020"}]}, {"mark": {"type": "line", "color": "#122B39"}, "encoding": {"x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 5, "title": "\u2b05 historical   projection \u27a1", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": 302, "titleY": -15}, "field": "year"}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 4, "ticks": false, "title": "GtCO\u2082e per year", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": 25, "titleY": 28}, "field": "historic"}}, "transform": [{"filter": "datum.year<=2020"}]}, {"data": {"name": "data-03bab3de6ba2d6853e83d9488b5b605d"}, "mark": {"type": "text", "color": "#676A86", "fontSize": 10}, "encoding": {"text": {"type": "nominal", "field": "t"}, "x": {"type": "quantitative", "field": "x"}, "y": {"type": "quantitative", "field": "y"}}}], "data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/is-the-uk-on-track-to-meet-its-climate-commitments/data/fig1_projected-emissions.csv"}, "height": 300, "title": {"text": "UK emissions up to date and projected reduction to 2030", "align": "left", "anchor": "start", "dx": 5, "fontSize": 12, "subtitle": ["Source: BEIS (2020)"], "subtitleFontSize": 11, "subtitleFontStyle": "italic"}, "width": 400, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-03bab3de6ba2d6853e83d9488b5b605d": [{"x": 2000, "y": 280, "t": "2030 target"}]}}, {});
# </script>

# %%
f += "_dark"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-85ed7890b4134331bdc83954ce3ef0a5"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-85ed7890b4134331bdc83954ce3ef0a5");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}, "background": "#122B39", "font": "Georgia"}, "layer": [{"mark": {"type": "line", "color": "#676A86"}, "encoding": {"x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "labelFontSize": 12, "orient": "bottom", "tickColor": "#676A86", "tickCount": 5, "title": "\u2b05 historical   projection \u27a1", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86", "titleFontSize": 12, "titleFontWeight": "normal", "titleX": 302, "titleY": -15}, "field": "year"}, "y": {"type": "quantitative", "field": "y"}}, "transform": [{"calculate": "254", "as": "y"}]}, {"mark": {"type": "rule", "color": "#484a5e", "strokeDash": [5, 5], "strokeWidth": 0.5}, "encoding": {"x": {"type": "quantitative", "field": "x"}}, "transform": [{"calculate": "2020", "as": "x"}]}, {"mark": {"type": "line", "color": "#36B7B4"}, "encoding": {"x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "labelFontSize": 12, "orient": "bottom", "tickColor": "#676A86", "tickCount": 5, "title": "\u2b05 historical   projection \u27a1", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86", "titleFontSize": 12, "titleFontWeight": "normal", "titleX": 302, "titleY": -15}, "field": "year"}, "y": {"type": "quantitative", "field": "projected"}}, "transform": [{"filter": "datum.year>=2020"}]}, {"mark": {"type": "line", "color": "#0063AF"}, "encoding": {"x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "labelFontSize": 12, "orient": "bottom", "tickColor": "#676A86", "tickCount": 5, "title": "\u2b05 historical   projection \u27a1", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86", "titleFontSize": 12, "titleFontWeight": "normal", "titleX": 302, "titleY": -15}, "field": "year"}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "gridColor": "#676A86", "gridOpacity": 0.1, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelFontSize": 12, "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 4, "ticks": false, "title": "GtCO\u2082e per year", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 12, "titleFontWeight": "normal", "titleX": 31, "titleY": 30.5}, "field": "historic"}}, "transform": [{"filter": "datum.year<=2020"}]}, {"data": {"name": "data-10333300d2c90bd6f3b020687a228f41"}, "mark": {"type": "text", "color": "#676A86", "fontSize": 12}, "encoding": {"text": {"type": "nominal", "field": "t"}, "x": {"type": "quantitative", "field": "x"}, "y": {"type": "quantitative", "field": "y"}}}], "data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/is-the-uk-on-track-to-meet-its-climate-commitments/data/fig1_projected-emissions.csv"}, "height": 300, "title": {"text": "UK emissions up to date and projected reduction to 2030", "align": "left", "anchor": "start", "color": "#F4134D", "dx": 5, "fontSize": 14, "subtitle": ["Source: BEIS (2020)"], "subtitleColor": "#F4134D", "subtitleFontSize": 12, "subtitleFontStyle": "italic"}, "width": 400, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-10333300d2c90bd6f3b020687a228f41": [{"x": 2000, "y": 290, "t": "2030 target"}]}}, {});
# </script>

# %% [markdown]
# ### Fig 5-2

# %%
f = "fig2_patents"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-e5b7c5dddd4844aaa7e28908135fb6d7"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-e5b7c5dddd4844aaa7e28908135fb6d7");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}}, "layer": [{"mark": "line", "description": "Carbon per capita by country", "encoding": {"color": {"type": "nominal", "field": "Country", "legend": null, "scale": {"scheme": "yellowgreenblue"}, "sort": [], "title": null}, "tooltip": [{"type": "temporal", "field": "Time", "timeUnit": "year", "title": "Year"}, {"type": "quantitative", "field": "Value", "title": "Green patents (%)"}, {"type": "nominal", "field": "Country"}], "x": {"type": "temporal", "axis": {"domainColor": "#676A86", "grid": false, "labelColor": "#676A86", "tickColor": "#676A86", "titleColor": "#676A86"}, "field": "Time", "title": ""}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0%", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 7, "ticks": false, "title": "", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": 45, "titleY": -5}, "field": "m", "scale": {"domain": [0.0, 0.18]}, "sort": [], "title": ""}}, "height": 220, "title": {"text": "Innovation: environmental technology patents", "anchor": "start", "color": "black", "dy": -5, "subtitle": "Environmental patents as share national total, G7. Source: OECD", "subtitleFontSize": 10, "subtitleFontStyle": "italic"}, "transform": [{"calculate": "datum.Value/100", "as": "m"}], "view": {"stroke": null}, "width": 300}, {"mark": {"type": "text", "align": "left", "dx": 5}, "description": "Carbon per capita by country", "encoding": {"color": {"type": "nominal", "field": "Country", "legend": null, "scale": {"scheme": "yellowgreenblue"}, "sort": [], "title": null}, "text": {"type": "nominal", "field": "Country"}, "tooltip": [{"type": "temporal", "field": "Time", "timeUnit": "year", "title": "Year"}, {"type": "quantitative", "field": "Value", "title": "Green patents (%)"}, {"type": "nominal", "field": "Country"}], "x": {"type": "temporal", "axis": {"domainColor": "#676A86", "grid": false, "labelColor": "#676A86", "tickColor": "#676A86", "titleColor": "#676A86"}, "field": "Time", "title": ""}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0%", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 7, "ticks": false, "title": "", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": 45, "titleY": -5}, "field": "m", "scale": {"domain": [0.0, 0.18]}, "sort": [], "title": ""}}, "height": 220, "title": {"text": "Innovation: environmental technology patents", "anchor": "start", "color": "black", "dy": -5, "subtitle": "Environmental patents as share national total, G7. Source: OECD", "subtitleFontSize": 10, "subtitleFontStyle": "italic"}, "transform": [{"calculate": "datum.Value/100", "as": "m"}, {"filter": "year(datum.Time)==2018"}, {"filter": "datum.Country!='Italy'"}, {"filter": "datum.Country!='Canada'"}, {"filter": "datum.Country!='Great Britain'"}, {"filter": "datum.Country!='United States'"}], "view": {"stroke": null}, "width": 300}, {"mark": {"type": "text", "align": "left", "dx": 5, "dy": 13}, "description": "Carbon per capita by country", "encoding": {"color": {"type": "nominal", "field": "Country", "legend": null, "scale": {"scheme": "yellowgreenblue"}, "sort": [], "title": null}, "text": {"type": "nominal", "field": "Country"}, "tooltip": [{"type": "temporal", "field": "Time", "timeUnit": "year", "title": "Year"}, {"type": "quantitative", "field": "Value", "title": "Green patents (%)"}, {"type": "nominal", "field": "Coun ...

# %%
f += "_dark"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-c3e045e9b5864181910b6654ab1ab360"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-c3e045e9b5864181910b6654ab1ab360");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}, "axisX": {"labelFontSize": 12}, "axisY": {"labelFontSize": 12}, "background": "#122B39", "font": "Georgia"}, "layer": [{"mark": "line", "description": "Carbon per capita by country", "encoding": {"color": {"type": "nominal", "field": "Country", "legend": null, "scale": {"scheme": "yellowgreenblue"}, "sort": [], "title": null}, "tooltip": [{"type": "temporal", "field": "Time", "timeUnit": "year", "title": "Year"}, {"type": "quantitative", "field": "Value", "title": "Green patents (%)"}, {"type": "nominal", "field": "Country"}], "x": {"type": "temporal", "axis": {"domainColor": "#676A86", "grid": false, "labelColor": "#676A86", "tickColor": "#676A86", "titleColor": "#676A86"}, "field": "Time", "title": ""}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0%", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 7, "ticks": false, "title": "", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": 53, "titleY": -3}, "field": "m", "scale": {"domain": [0.0, 0.18]}, "sort": [], "title": ""}}, "height": 220, "title": {"text": "Innovation: environmental technology patents", "anchor": "start", "color": "#F4134D", "dy": -7, "fontSize": 14, "subtitle": "Environmental patents as share national total, G7. Source: OECD", "subtitleColor": "#F4134D", "subtitleFontSize": 12, "subtitleFontStyle": "italic"}, "transform": [{"calculate": "datum.Value/100", "as": "m"}], "view": {"stroke": null}, "width": 300}, {"mark": {"type": "text", "align": "left", "dx": 5}, "description": "Carbon per capita by country", "encoding": {"color": {"type": "nominal", "field": "Country", "legend": null, "scale": {"scheme": "yellowgreenblue"}, "sort": [], "title": null}, "text": {"type": "nominal", "field": "Country"}, "tooltip": [{"type": "temporal", "field": "Time", "timeUnit": "year", "title": "Year"}, {"type": "quantitative", "field": "Value", "title": "Green patents (%)"}, {"type": "nominal", "field": "Country"}], "x": {"type": "temporal", "axis": {"domainColor": "#676A86", "grid": false, "labelColor": "#676A86", "tickColor": "#676A86", "titleColor": "#676A86"}, "field": "Time", "title": ""}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0%", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 7, "ticks": false, "title": "", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": 53, "titleY": -3}, "field": "m", "scale": {"domain": [0.0, 0.18]}, "sort": [], "title": ""}}, "height": 220, "title": {"text": "Innovation: environmental technology patents", "anchor": "start", "color": "#F4134D", "dy": -7, "fontSize": 14, "subtitle": "Environmental patents as share national total, G7. Source: OECD", "subtitleColor": "#F4134D", "subtitleFontSize": 12, "subtitleFontStyle": "italic"}, "transform": [{"calculate": "datum.Value/100", "as": "m"}, {"filter": "year(datum.Time)==2018"}, {"filter": "datum.Country!='Italy'"}, {"filter": "datum.Country!='Canada'"}, {"filter": "datum.Country!='Great Britain'"}, {"filter": "datum.Country!='United States'"}], "view": {"stroke": null}, "width": 300}, {"mark": {"type": "text", "align": "left", "dx": 5, "dy": 13}, "description": "Carbon per capita by country", "encoding": {"color": {"type": "nominal", "field": "Country", "legend": null, "scale": {"scheme": "yellowgreenblue"}, "sort": [], "title": null}, "text": {"type": "nominal", "field": "Country ...

# %% [markdown]
# # Article 6

# %% [markdown]
# ## Weather

# %%
readme = "# Article 6 \n\n## Weather\n\n"
open("README.md", "a").write(readme)
# Out:
# 26

# %%
p = (
    eco_git_path.split("main")[0].replace("rawgit", "github")
    + "tree/"
    + "main"
    + "/articles/what-are-the-economic-effects-of-extreme-weather-caused-by-climate-change/"
)
readme = "Cloned from [" + p.split("/")[-2] + "](" + p + ")\n\n"
open("README.md", "a").write(readme)
# Out:
# 252

# %% [markdown]
# ### Fig 6-1a

# %%
f = "fig1a_extreme-events"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-a1cf7903b3834460bbc5c9fd0ee2d8f4"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-a1cf7903b3834460bbc5c9fd0ee2d8f4");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}}, "layer": [{"data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/what-are-the-economic-effects-of-extreme-weather-caused-by-climate-change/data/fig1a_extreme-events.csv"}, "mark": "bar", "encoding": {"color": {"type": "nominal", "field": "data", "legend": null, "scale": {"range": ["#179FDB", "#0063AF", "#36B7B4", "#676A86"]}}, "x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 5, "title": "", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86"}, "field": "year"}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 7, "ticks": false, "title": "number of events", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": 25, "titleY": -5}, "field": "value", "stack": true}}, "transform": [{"filter": "datum.data!=\"total\""}]}, {"data": {"name": "data-a62937e521aa6d2915dd6f8f4c0bcd93"}, "mark": {"type": "text", "align": "left"}, "encoding": {"color": {"type": "nominal", "field": "d"}, "text": {"type": "nominal", "field": "t"}, "x": {"type": "quantitative", "field": "x"}, "y": {"type": "quantitative", "field": "y"}}}], "height": 300, "title": {"text": "Extreme events are becoming more frequent", "align": "left", "anchor": "start", "dx": 5, "fontSize": 12, "subtitle": ["Number of relevant loss events by peril. Source: Met Office, based on Munich RE"], "subtitleFontSize": 11, "subtitleFontStyle": "italic"}, "width": 400, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-a62937e521aa6d2915dd6f8f4c0bcd93": [{"x": 2020, "y": 700, "t": "Geophysical events:", "d": "geo"}, {"x": 2020, "y": 660, "t": "earthquakes, tsunami", "d": "geo"}, {"x": 2020, "y": 620, "t": "volcanic activity", "d": "geo"}, {"x": 2020, "y": 850, "t": "Climatological events:", "d": "climate"}, {"x": 2020, "y": 810, "t": "extreme temperature,", "d": "climate"}, {"x": 2020, "y": 770, "t": "drought, wildfire", "d": "climate"}, {"x": 2020, "y": 240, "t": "Meteorological events:", "d": "meteo"}, {"x": 2020, "y": 200, "t": "tropical storm,", "d": "meteo"}, {"x": 2020, "y": 160, "t": "extratropical storm,", "d": "meteo"}, {"x": 2020, "y": 120, "t": "convective storm,", "d": "meteo"}, {"x": 2020, "y": 80, "t": "local storm", "d": "meteo"}, {"x": 2020, "y": 500, "t": "Hydrological events:", "d": "hydro"}, {"x": 2020, "y": 460, "t": "flood, mass movement", "d": "hydro"}]}}, {});
# </script>

# %%
f += "_dark"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-ea9ca9fa198341b3bd36d6aa0bff8a6f"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-ea9ca9fa198341b3bd36d6aa0bff8a6f");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}, "background": "#122B39", "font": "Georgia"}, "layer": [{"data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/what-are-the-economic-effects-of-extreme-weather-caused-by-climate-change/data/fig1a_extreme-events.csv"}, "mark": "bar", "encoding": {"color": {"type": "nominal", "field": "data", "legend": null, "scale": {"range": ["#179FDB", "#0063AF", "#36B7B4", "#676A86"]}}, "x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "labelFontSize": 12, "orient": "bottom", "tickColor": "#676A86", "tickCount": 5, "title": "", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86", "titleFontSize": 12}, "field": "year"}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelFontSize": 12, "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 7, "ticks": false, "title": "number of events", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 12, "titleFontWeight": "normal", "titleX": 32, "titleY": -3}, "field": "value", "stack": true}}, "transform": [{"filter": "datum.data!=\"total\""}]}, {"data": {"name": "data-a62937e521aa6d2915dd6f8f4c0bcd93"}, "mark": {"type": "text", "align": "left"}, "encoding": {"color": {"type": "nominal", "field": "d"}, "text": {"type": "nominal", "field": "t"}, "x": {"type": "quantitative", "field": "x"}, "y": {"type": "quantitative", "field": "y"}}}], "height": 300, "title": {"text": "Extreme events are becoming more frequent", "align": "left", "anchor": "start", "color": "#F4134D", "dx": 5, "dy": -5, "fontSize": 14, "subtitle": ["Number of relevant loss events by peril. Source: Met Office, based on Munich RE"], "subtitleColor": "#F4134D", "subtitleFontSize": 12, "subtitleFontStyle": "italic"}, "width": 400, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-a62937e521aa6d2915dd6f8f4c0bcd93": [{"x": 2020, "y": 700, "t": "Geophysical events:", "d": "geo"}, {"x": 2020, "y": 660, "t": "earthquakes, tsunami", "d": "geo"}, {"x": 2020, "y": 620, "t": "volcanic activity", "d": "geo"}, {"x": 2020, "y": 850, "t": "Climatological events:", "d": "climate"}, {"x": 2020, "y": 810, "t": "extreme temperature,", "d": "climate"}, {"x": 2020, "y": 770, "t": "drought, wildfire", "d": "climate"}, {"x": 2020, "y": 240, "t": "Meteorological events:", "d": "meteo"}, {"x": 2020, "y": 200, "t": "tropical storm,", "d": "meteo"}, {"x": 2020, "y": 160, "t": "extratropical storm,", "d": "meteo"}, {"x": 2020, "y": 120, "t": "convective storm,", "d": "meteo"}, {"x": 2020, "y": 80, "t": "local storm", "d": "meteo"}, {"x": 2020, "y": 500, "t": "Hydrological events:", "d": "hydro"}, {"x": 2020, "y": 460, "t": "flood, mass movement", "d": "hydro"}]}}, {});
# </script>

# %% [markdown]
# ### Fig 6-1b

# %%
f = "fig1b_extreme-event-dotplot"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-95825004401341e082fea1b1f1f6188b"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-95825004401341e082fea1b1f1f6188b");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}}, "layer": [{"data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/what-are-the-economic-effects-of-extreme-weather-caused-by-climate-change/data/fig1b_extreme-event-dotplot.csv"}, "mark": "point", "encoding": {"color": {"type": "nominal", "field": "data", "legend": null, "scale": {"range": ["#179FDB", "#0063AF", "#36B7B4", "#676A86"]}}, "fill": {"type": "nominal", "field": "data", "legend": null, "scale": {"range": ["#179FDB", "#0063AF", "#36B7B4", "#676A86"]}}, "size": {"type": "quantitative", "field": "value", "legend": null, "scale": {"domain": [15, 150]}}, "x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 5, "title": "", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86"}, "field": "year", "scale": {"domain": [1980, 2020]}}, "y": {"type": "nominal", "axis": null, "field": "data", "stack": true}}, "transform": [{"filter": "datum.data!=\"total\""}]}, {"data": {"name": "data-7ce78eaa6e72b506005686f27f794f24"}, "mark": {"type": "text", "align": "left", "dx": -6, "dy": -16, "fontWeight": "bold"}, "encoding": {"color": {"type": "nominal", "field": "d"}, "text": {"type": "nominal", "field": "t"}, "x": {"type": "quantitative", "field": "x"}, "y": {"type": "nominal", "field": "d"}}}, {"data": {"name": "data-2f93d16646690afee693780eea2e21e0"}, "mark": {"type": "text", "align": "left", "dx": 8, "dy": -16}, "encoding": {"color": {"type": "nominal", "field": "d"}, "text": {"type": "nominal", "field": "t"}, "x": {"type": "quantitative", "field": "x"}, "y": {"type": "nominal", "field": "d"}}}], "height": 150, "title": {"text": "Extreme events are becoming more frequent", "align": "left", "anchor": "start", "dx": 5, "dy": -10, "fontSize": 12, "subtitle": ["Circle size is proportional to the number of relevant loss events by peril type and year. Source: Met Office, based on Munich RE"], "subtitleFontSize": 11, "subtitleFontStyle": "italic"}, "width": 620, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-7ce78eaa6e72b506005686f27f794f24": [{"x": 1980, "y": 700, "t": "Geophysical events:", "d": "geo"}, {"x": 1980, "y": 850, "t": "Climatological events:", "d": "climate"}, {"x": 1980, "y": 240, "t": "Meteorological events:", "d": "meteo"}, {"x": 1980, "y": 500, "t": "Hydrological events:", "d": "hydro"}], "data-2f93d16646690afee693780eea2e21e0": [{"x": 1986.2, "y": 660, "t": "earthquakes, tsunami, volcanic activity", "d": "geo"}, {"x": 1986.8, "y": 810, "t": "extreme temperature, drought, wildfire", "d": "climate"}, {"x": 1986.9, "y": 200, "t": "tropical storm, extratropical storm, convective storm, local storm", "d": "meteo"}, {"x": 1986.3, "y": 460, "t": "flood, mass movement", "d": "hydro"}]}}, {});
# </script>

# %%
f += "_dark"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-05ecc4548bbd401aa10c0453d79ded2c"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-05ecc4548bbd401aa10c0453d79ded2c");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}, "background": "#122B39", "font": "Georgia"}, "layer": [{"data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/what-are-the-economic-effects-of-extreme-weather-caused-by-climate-change/data/fig1b_extreme-event-dotplot.csv"}, "mark": "point", "encoding": {"color": {"type": "nominal", "field": "data", "legend": null, "scale": {"range": ["#179FDB", "#0063AF", "#36B7B4", "#676A86"]}}, "fill": {"type": "nominal", "field": "data", "legend": null, "scale": {"range": ["#179FDB", "#0063AF", "#36B7B4", "#676A86"]}}, "size": {"type": "quantitative", "field": "value", "legend": null, "scale": {"domain": [15, 150]}}, "x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "labelFontSize": 12, "orient": "bottom", "tickColor": "#676A86", "tickCount": 5, "title": "", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86", "titleFontSize": 12}, "field": "year", "scale": {"domain": [1980, 2020]}}, "y": {"type": "nominal", "axis": null, "field": "data", "stack": true}}, "transform": [{"filter": "datum.data!=\"total\""}]}, {"data": {"name": "data-7ce78eaa6e72b506005686f27f794f24"}, "mark": {"type": "text", "align": "left", "dx": -6, "dy": -18, "fontSize": 12, "fontWeight": "bold"}, "encoding": {"color": {"type": "nominal", "field": "d"}, "text": {"type": "nominal", "field": "t"}, "x": {"type": "quantitative", "field": "x"}, "y": {"type": "nominal", "field": "d"}}}, {"data": {"name": "data-0dc1791d72d5d242d45f8fc372374301"}, "mark": {"type": "text", "align": "left", "dx": 8, "dy": -18, "fontSize": 12}, "encoding": {"color": {"type": "nominal", "field": "d"}, "text": {"type": "nominal", "field": "t"}, "x": {"type": "quantitative", "field": "x"}, "y": {"type": "nominal", "field": "d"}}}], "height": 150, "title": {"text": "Extreme events are becoming more frequent", "align": "left", "anchor": "start", "color": "#F4134D", "dx": 5, "dy": -15, "fontSize": 14, "subtitle": ["Circle size is proportional to the number of relevant loss events by peril type and year. Source: Met Office, based on Munich RE"], "subtitleColor": "#F4134D", "subtitleFontSize": 12, "subtitleFontStyle": "italic"}, "width": 620, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-7ce78eaa6e72b506005686f27f794f24": [{"x": 1980, "y": 700, "t": "Geophysical events:", "d": "geo"}, {"x": 1980, "y": 850, "t": "Climatological events:", "d": "climate"}, {"x": 1980, "y": 240, "t": "Meteorological events:", "d": "meteo"}, {"x": 1980, "y": 500, "t": "Hydrological events:", "d": "hydro"}], "data-0dc1791d72d5d242d45f8fc372374301": [{"x": 1987.5, "y": 660, "t": "earthquakes, tsunami, volcanic activity", "d": "geo"}, {"x": 1988.1, "y": 810, "t": "extreme temperature, drought, wildfire", "d": "climate"}, {"x": 1988.3, "y": 200, "t": "tropical storm, extratropical storm, convective storm, local storm", "d": "meteo"}, {"x": 1987.6, "y": 460, "t": "flood, mass movement", "d": "hydro"}]}}, {});
# </script>

# %% [markdown]
# # Article 7

# %% [markdown]
# ## Plastics

# %%
readme = "# Article 7 \n\n## Plastics\n\n"
open("README.md", "a").write(readme)
# Out:
# 27

# %% [markdown]
# ### Fig 7-1

# %%
configSource = "raw/ECO2.PLASTIC_C1.json"
config = json.loads(open(configSource, "r").read())
df = pd.read_csv(config["data"]["url"]).drop("Detail", axis=1)

# %%
f = "fig7-1_ocean"
f7_1 = eco_git_path + f + ".csv"
df.to_csv("data/" + f + ".csv")
f += local_suffix
open("visualisation/" + f + ".html", "w").write(
    vega_embed.replace(
        "JSON_PATH", f7_1.replace("/data/", "/visualisation/").replace(".csv", ".json")
    )
)
if LOCAL:
    f7_1 = df
readme = (
    "### "
    + f
    + " --- [json](visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg](visualisation/'
    + f
    + '.svg "'
    + f
    + '") [png](visualisation/'
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"](visualisation/'
    + f
    + '.svg "'
    + f
    + '")](visualisation/'
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
df.head()
# Out:
#    Year                         Scenario  Value
# 0  1950  Plastic waste growth up to 2050      0
# 1  1951  Plastic waste growth up to 2050      0
# 2  1952  Plastic waste growth up to 2050      0
# 3  1953  Plastic waste growth up to 2050      0
# 4  1954  Plastic waste growth up to 2050    100

# %%
config = json.loads(open(configSource, "r").read())
if not LOCAL:
    config["data"]["url"] = f7_1
config["encoding"]["x"]["axis"] = {}
config["encoding"]["x"]["axis"]["grid"] = False
config["encoding"]["x"]["axis"]["gridColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["gridOpacity"] = 0.1
config["encoding"]["x"]["axis"]["labelColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["titleColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["tickColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["domainColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["titleFontSize"] = 10
config["encoding"]["x"]["axis"]["titleAlign"] = "right"
config["encoding"]["x"]["axis"]["titleAnchor"] = "end"
config["encoding"]["x"]["axis"]["titleY"] = -15
config["encoding"]["x"]["axis"]["titleFontWeight"] = "normal"
config["encoding"]["y"]["axis"]["grid"] = True
config["encoding"]["y"]["axis"]["gridColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["gridOpacity"] = 0.1
config["encoding"]["y"]["axis"]["title"] = "million tonnes"
config["encoding"]["y"]["axis"]["titleAnchor"] = "start"
config["encoding"]["y"]["axis"]["labelColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["titleColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["tickColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["domainColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["titleFontSize"] = 10
config["encoding"]["y"]["axis"]["titleFontWeight"] = "normal"
config["encoding"]["y"]["axis"]["ticks"] = False
config["encoding"]["y"]["axis"]["labelAlign"] = "left"
config["encoding"]["y"]["axis"]["labelBaseline"] = "middle"
config["encoding"]["y"]["axis"]["labelPadding"] = -5
config["encoding"]["y"]["axis"]["labelOffset"] = -10
config["encoding"]["y"]["axis"]["titleBaseline"] = "bottom"
config["encoding"]["y"]["axis"]["titleAngle"] = 0
config["encoding"]["y"]["axis"]["titleAlign"] = "left"
config["encoding"]["y"]["axis"]["tickCount"] = 7
config["encoding"]["y"]["axis"]["titleX"] = 25
config["encoding"]["y"]["axis"]["titleY"] = 19
config["encoding"]["y"].pop("sort")
config["encoding"]["y"]["field"] = "m"
config["title"]["subtitle"] = config["title"]["subtitle"].replace("Tonnes. ", "")
config["encoding"]["color"]["legend"]["offset"] = 40
config["encoding"]["color"]["legend"]["labelColor"] = colors["eco-gray"]
config["title"]["dy"] = -5
config.pop("$schema")
config["view"] = {"stroke": None}
config["width"] = 300
config["height"] = 220
base = alt.Chart.from_dict(config).transform_calculate(m="datum.Value/1000000")
layer1 = (base).configure_view(stroke=None)
layer1.save("visualisation/" + f + ".json")
layer1.save("visualisation/" + f + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + ".svg")
open("README.md", "a").write(readme)
layer1
# altair_viewer.display(config, inline=True)
# Out:
# alt.Chart(...)

# %%
theme = "_dark"
base.title.fontSize = 14
base.title.subtitleFontSize = 12
base.title.dy -= 2
base.title.color = colors["eco-dot"]
base.title.subtitleColor = colors["eco-dot"]
layer1 = (base).configure_view(stroke=None)
layer1 = layer1.configure_axisY(labelFontSize=12)
layer1 = layer1.configure_axisX(labelFontSize=12)
layer1.config.font = "Georgia"
layer1.config.background = colors["eco-background"]
layer1.config.view.stroke = None
base.encoding.color.legend.labelFontSize = 11
layer1.save("visualisation/" + f + theme + ".json")
layer1.save("visualisation/" + f + theme + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + theme + ".svg")
readme = re.sub(f, f + theme, readme)
open("README.md", "a").write(readme)
layer1
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Fig 7-2

# %%
configSource = "raw/ECO2.PLASTIC.C2.json"
config = json.loads(open(configSource, "r").read())
df = pd.read_csv(config["data"]["url"]).drop("Detail", axis=1)

# %%
f = "fig7-2_river"
f7_2 = eco_git_path + f + ".csv"
df.to_csv("data/" + f + ".csv")
f += local_suffix
open("visualisation/" + f + ".html", "w").write(
    vega_embed.replace(
        "JSON_PATH", f7_2.replace("/data/", "/visualisation/").replace(".csv", ".json")
    )
)
if LOCAL:
    f7_2 = df
readme = (
    "### "
    + f
    + " --- [json](visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg](visualisation/'
    + f
    + '.svg "'
    + f
    + '") [png](visualisation/'
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"](visualisation/'
    + f
    + '.svg "'
    + f
    + '")](visualisation/'
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
df.head()
# Out:
#                                       River   Value
# 0  Amazon (Brazil, Peru, Colombia, Ecuador)   38900
# 1                       Brantas (Indonesia)   38900
# 2                 Cross (Nigeria, Cameroon)   40300
# 3                              Dong (China)   19100
# 4                Ganges (India, Bangladesh)  115000

# %%
config = json.loads(open(configSource, "r").read())
if not LOCAL:
    config["data"]["url"] = f7_2
config["encoding"]["x"]["axis"] = {}
config["encoding"]["x"]["axis"]["grid"] = True
config["encoding"]["x"]["axis"]["gridColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["gridOpacity"] = 0.1
config["encoding"]["x"]["axis"]["labelColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["titleColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["tickColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["domainColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["titleFontSize"] = 10
config["encoding"]["x"]["axis"]["titleAlign"] = "right"
config["encoding"]["x"]["axis"]["titleAnchor"] = "end"
config["encoding"]["x"]["axis"]["titleY"] = -15
config["encoding"]["x"]["axis"]["titleFontWeight"] = "normal"
config["encoding"]["y"]["axis"] = {}
config["encoding"]["y"]["axis"]["grid"] = False
config["encoding"]["y"]["axis"]["labelColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["titleColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["tickColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["domainColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["labelLimit"] = 190
config["title"]["subtitle"] = config["title"]["subtitle"].replace(
    "Tonnes", "Thousand tonnes"
)
config["encoding"]["y"].pop("sort")
config["encoding"]["x"]["field"] = "m"
config["title"]["dy"] = -5
config.pop("$schema")
# config["encoding"]["color"]["legend"] = None
config["mark"] = {"type": "bar", "opacity": 0.9, "color": colors["eco-turquiose"]}
config["view"] = {"stroke": None}
config["width"] = 200
config["height"] = 330
base = alt.Chart.from_dict(config).transform_calculate(m="datum.Value/1000")
text = (
    base.mark_text(dx=5, align="left")
    .encode(text="Country:N")
    .transform_filter("year(datum.Year)==2018")
)
layer1 = (base + text).configure_view(stroke=None)
layer1.save("visualisation/" + f + ".json")
layer1.save("visualisation/" + f + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + ".svg")
open("README.md", "a").write(readme)
layer1
# altair_viewer.display(config, inline=True)
# Out:
# WARN Infinite extent for field "m": [Infinity, -Infinity]
# WARN Infinite extent for field "m": [Infinity, -Infinity]
# alt.LayerChart(...)

# %%
theme = "_dark"
base.title.fontSize = 14
base.title.subtitleFontSize = 12
base.title.dy -= 2
base.title.color = colors["eco-dot"]
base.title.subtitleColor = colors["eco-dot"]
layer1 = (base).configure_view(stroke=None)
layer1 = layer1.configure_axisY(labelFontSize=12)
layer1 = layer1.configure_axisX(labelFontSize=12)
layer1.config.font = "Georgia"
layer1.config.background = colors["eco-background"]
layer1.config.view.stroke = None
layer1.save("visualisation/" + f + theme + ".json")
layer1.save("visualisation/" + f + theme + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + theme + ".svg")
readme = re.sub(f, f + theme, readme)
open("README.md", "a").write(readme)
layer1
# Out:
# alt.Chart(...)

# %% [markdown]
# # Article 8

# %% [markdown]
# ## JG interview

# %%
readme = "# Article 8 \n\n## JG interview\n\n"
open("README.md", "a").write(readme)
# Out:
# 31

# %% [markdown]
# ### Fig 8-1

# %%
configSource = "raw/ECO2.JG.C1c.json"
config = json.loads(open(configSource, "r").read())
df = pd.read_csv(config["data"]["url"]).drop("Detail", axis=1)

# %%
f = "fig8-1_east-africa-gdp"
f8_1 = eco_git_path + f + ".csv"
df.to_csv("data/" + f + ".csv")
f += local_suffix
open("visualisation/" + f + ".html", "w").write(
    vega_embed.replace(
        "JSON_PATH", f8_1.replace("/data/", "/visualisation/").replace(".csv", ".json")
    )
)
if LOCAL:
    f8_1 = df
readme = (
    "### "
    + f
    + " --- [json](visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg](visualisation/'
    + f
    + '.svg "'
    + f
    + '") [png](visualisation/'
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"](visualisation/'
    + f
    + '.svg "'
    + f
    + '")](visualisation/'
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
df.head()
# Out:
#    Year                  Country       Value
# 0  1960  Central Afican Republic  599.700618
# 1  1961  Central Afican Republic  619.348109
# 2  1962  Central Afican Republic  586.413076
# 3  1963  Central Afican Republic  572.140833
# 4  1964  Central Afican Republic  573.425922

# %%
config = json.loads(open(configSource, "r").read())
if not LOCAL:
    config["data"]["url"] = f8_1
config["encoding"]["x"]["axis"]["grid"] = False
config["encoding"]["x"]["axis"]["labelColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["titleColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["tickColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["domainColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["grid"] = True
config["encoding"]["y"]["axis"]["gridColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["gridOpacity"] = 0.1
config["encoding"]["y"]["axis"]["title"] = "$ / year / person"
config["encoding"]["y"]["axis"]["titleAnchor"] = "start"
config["encoding"]["y"]["axis"]["labelColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["titleColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["tickColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["domainColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["titleFontSize"] = 10
config["encoding"]["y"]["axis"]["titleFontWeight"] = "normal"
config["encoding"]["y"]["axis"]["ticks"] = False
config["encoding"]["y"]["axis"]["labelAlign"] = "left"
config["encoding"]["y"]["axis"]["labelBaseline"] = "middle"
config["encoding"]["y"]["axis"]["labelPadding"] = -5
config["encoding"]["y"]["axis"]["labelOffset"] = -10
config["encoding"]["y"]["axis"]["titleBaseline"] = "bottom"
config["encoding"]["y"]["axis"]["titleAngle"] = 0
config["encoding"]["y"]["axis"]["titleAlign"] = "left"
config["encoding"]["y"]["axis"]["tickCount"] = 7
config["encoding"]["y"]["axis"]["titleX"] = 35
config["encoding"]["y"]["axis"]["titleY"] = 12
config["title"]["dy"] = -5
config.pop("$schema")
config["encoding"]["color"]["legend"] = None
config["view"] = {"stroke": None}
config["width"] = 300
config["height"] = 220
base = alt.Chart.from_dict(config).transform_filter("datum.Country!='Tanzania'")
text = (
    base.mark_text(dx=5, align="left")
    .encode(text="Country:N")
    .transform_filter("year(datum.Year)==2020")
    .transform_filter("datum.Country!='Central Afican Republic'")
    .transform_filter("datum.Country!='Democratic Republic of Congo'")
)
text2 = (
    base.mark_text(dx=5, align="left", text="Central African Republic")
    .transform_filter("year(datum.Year)==2012")
    .transform_filter("datum.Country=='Central Afican Republic'")
)
text3 = (
    base.mark_text(dx=5, align="left", text="DRC")
    .transform_filter("year(datum.Year)==2020")
    .transform_filter("datum.Country=='Democratic Republic of Congo'")
)
base2 = (
    alt.Chart.from_dict(config)
    .transform_filter("datum.Country=='Tanzania'")
    .transform_filter("year(datum.Year)>1987")
)
text4 = base2.mark_text(dx=5, align="left", text="Tanzania").transform_filter(
    "year(datum.Year)==2020"
)
layer1 = (base + base2 + text + text2 + text3 + text4).configure_view(stroke=None)
layer1.save("visualisation/" + f + ".json")
layer1.save("visualisation/" + f + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + ".svg")
open("README.md", "a").write(readme)
layer1
# altair_viewer.display(config, inline=True)
# Out:
# alt.LayerChart(...)

# %%
theme = "_dark"
base.title.fontSize = 14
base.title.subtitleFontSize = 12
base.title.dy -= 2
base.encoding.y.axis.titleY += 1
base.encoding.y.axis.titleX += 5
base.title.color = colors["eco-dot"]
base.title.subtitleColor = colors["eco-dot"]
layer1 = (base + base2 + text + text2 + text3 + text4).configure_view(stroke=None)
layer1 = layer1.configure_axisY(labelFontSize=12)
layer1 = layer1.configure_axisX(labelFontSize=12)
layer1.config.font = "Georgia"
layer1.config.background = colors["eco-background"]
layer1.config.view.stroke = None
layer1.save("visualisation/" + f + theme + ".json")
layer1.save("visualisation/" + f + theme + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + theme + ".svg")
readme = re.sub(f, f + theme, readme)
open("README.md", "a").write(readme)
layer1
# Out:
# WARN Conflicting axis property "titleX" (40 and 35). Using 40.
# WARN Conflicting axis property "titleY" (13 and 12). Using 13.
# WARN Conflicting axis property "titleX" (40 and 35). Using 40.
# WARN Conflicting axis property "titleY" (13 and 12). Using 13.
# WARN Conflicting axis property "titleX" (40 and 35). Using 40.
# WARN Conflicting axis property "titleY" (13 and 12). Using 13.
# WARN Conflicting axis property "titleX" (40 and 35). Using 40.
# WARN Conflicting axis property "titleY" (13 and 12). Using 13.
# alt.LayerChart(...)

# %% [markdown]
# ### Fig 8-2

# %%
f = "fig8-2/map"
readme = (
    "### "
    + f
    + " --- [html]("
    + "visualisation/"
    + f.replace("map", "")
    + 'index.html "'
    + f
    + '") [svg]('
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
# Out:
# 275

# %%
f += "_dark"
readme = (
    "### "
    + f
    + " --- [html]("
    + "visualisation/"
    + f.replace("map_dark", "")
    + 'index_dark.html "'
    + f
    + '") [svg]('
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
# Out:
# 335

# %% [markdown]
# # Article 9

# %% [markdown]
# ## Transition

# %%
readme = "# Article 9 \n\n## Transition\n\n"
open("README.md", "a").write(readme)
# Out:
# 29

# %%
p = (
    eco_git_path.split("main")[0].replace("rawgit", "github")
    + "tree/"
    + "main"
    + "/articles/what-are-the-likely-costs-of-the-transition-to-a-sustainable-economy/"
)
readme = "Cloned from [" + p.split("/")[-2] + "](" + p + ")\n\n"
open("README.md", "a").write(readme)
# Out:
# 242

# %% [markdown]
# ### Fig 9-1

# %%
f = "fig1_lcoe"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-9fb23221affe4efb83ce9bd4dcc5a118"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-9fb23221affe4efb83ce9bd4dcc5a118");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}}, "layer": [{"data": {"name": "data-66e9ab00c27a59734f8f2024a468ccbf"}, "mark": {"type": "area", "fill": "#676A86", "opacity": 0.2}, "encoding": {"x": {"type": "quantitative", "field": "x"}, "y": {"type": "quantitative", "field": "y"}, "y2": {"field": "y2"}}}, {"data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/what-are-the-likely-costs-of-the-transition-to-a-sustainable-economy/data/fig1_lcoe.csv"}, "mark": "line", "encoding": {"color": {"type": "nominal", "field": "tech", "legend": null}, "x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 10, "title": "", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86"}, "field": "year", "sort": []}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".2f", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 7, "ticks": false, "title": "$/kWh", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": 27, "titleY": -5}, "field": "avg", "sort": []}}, "transform": [{"filter": "datum.db==\"lcoe\""}]}, {"data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/what-are-the-likely-costs-of-the-transition-to-a-sustainable-economy/data/fig1_lcoe.csv"}, "mark": {"type": "point", "opacity": 0.6, "strokeOpacity": 0.8}, "encoding": {"color": {"type": "nominal", "field": "tech", "legend": null, "scale": {"range": ["#EB5C2E", "#0063AF", "#00A767", "#cf970c"]}}, "fill": {"type": "nominal", "field": "tech", "legend": null, "scale": {"range": ["#EB5C2E", "#0063AF", "#00A767", "#cf970c"]}}, "x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 10, "title": "", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86"}, "field": "year", "sort": []}, "y": {"type": "quantitative", "field": "avg", "sort": []}}, "transform": [{"filter": "datum.db==\"auction\""}]}, {"data": {"name": "data-7b085bcd579a30523712d200970b338f"}, "mark": {"type": "text", "align": "right", "angle": 270, "color": "#676A86", "dx": -5, "dy": -7, "fontSize": 10}, "encoding": {"text": {"type": "nominal", "field": "t"}, "x": {"type": "quantitative", "field": "x"}, "y": {"type": "quantitative", "field": "y"}}}, {"data": {"name": "data-aa9be91e3721dd4cbcf686d70831b30a"}, "mark": {"type": "text", "align": "right", "color": "#676A86", "dx": -5, "fontSize": 10}, "encoding": {"text": {"type": "nominal", "field": "t"}, "x": {"type": "quantitative", "field": "x"}, "y": {"type": "quantitative", "field": "y"}}}, {"data": {"name": "data-91ee8ccb0456755c4f6e52d4e4aac060"}, "mark": {"type": "text", "align": "left", "fontSize": 10}, "encoding": {"color": {"type": "nominal", "field": "t", "legend": null, "scale": {"range": ["#EB5C2E", "#0063AF", "#00A767", "#cf970c"]}}, "text": {"type": "nominal", "field": "t"}, "x": {"type": "quantitative", "field": "x"}, "y": {"type": "quantitative", "field": "y"}}}], "height": 300, "title": {"text": "Evolution of LCOE for renewable energy technologies", "align": "left", "anchor": "start", "dx": 5, "dy": -5, "fontSize": 12, "subtitle": ["Levelised cost of electricity. Source: CCC, based on IRENA (2020)"], "subtitleFontSize": 11, "subtitleFontStyle": "italic"}, "width": 400, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-66e9ab00c27a59734f8f2024a468ccbf": [{"x": 2008, "y": 0.05, "y2": 0. ...
# </script>

# %%
f += "_dark"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-3807b07881c94576afccd13bb16bbf74"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-3807b07881c94576afccd13bb16bbf74");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}, "background": "#122B39", "font": "Georgia"}, "layer": [{"data": {"name": "data-66e9ab00c27a59734f8f2024a468ccbf"}, "mark": {"type": "area", "fill": "#676A86", "opacity": 0.2}, "encoding": {"x": {"type": "quantitative", "field": "x"}, "y": {"type": "quantitative", "field": "y"}, "y2": {"field": "y2"}}}, {"data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/what-are-the-likely-costs-of-the-transition-to-a-sustainable-economy/data/fig1_lcoe.csv"}, "mark": "line", "encoding": {"color": {"type": "nominal", "field": "tech", "legend": null}, "x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "labelFontSize": 12, "orient": "bottom", "tickColor": "#676A86", "tickCount": 10, "title": "", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86", "titleFontSize": 12}, "field": "year", "sort": []}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".2f", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelFontSize": 12, "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 7, "ticks": false, "title": "$/kWh", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 12, "titleFontWeight": "normal", "titleX": 32, "titleY": -3}, "field": "avg", "sort": []}}, "transform": [{"filter": "datum.db==\"lcoe\""}]}, {"data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/what-are-the-likely-costs-of-the-transition-to-a-sustainable-economy/data/fig1_lcoe.csv"}, "mark": {"type": "point", "opacity": 0.6, "strokeOpacity": 0.8}, "encoding": {"color": {"type": "nominal", "field": "tech", "legend": null, "scale": {"range": ["#EB5C2E", "#179FDB", "#00A767", "#cf970c"]}}, "fill": {"type": "nominal", "field": "tech", "legend": null, "scale": {"range": ["#EB5C2E", "#179FDB", "#00A767", "#cf970c"]}}, "x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "labelFontSize": 12, "orient": "bottom", "tickColor": "#676A86", "tickCount": 10, "title": "", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86", "titleFontSize": 12}, "field": "year", "sort": []}, "y": {"type": "quantitative", "field": "avg", "sort": []}}, "transform": [{"filter": "datum.db==\"auction\""}]}, {"data": {"name": "data-7b085bcd579a30523712d200970b338f"}, "mark": {"type": "text", "align": "right", "angle": 270, "color": "#676A86", "dx": -5, "dy": -7, "fontSize": 10}, "encoding": {"text": {"type": "nominal", "field": "t"}, "x": {"type": "quantitative", "field": "x"}, "y": {"type": "quantitative", "field": "y"}}}, {"data": {"name": "data-aa9be91e3721dd4cbcf686d70831b30a"}, "mark": {"type": "text", "align": "right", "color": "#676A86", "dx": -5, "fontSize": 10}, "encoding": {"text": {"type": "nominal", "field": "t"}, "x": {"type": "quantitative", "field": "x"}, "y": {"type": "quantitative", "field": "y"}}}, {"data": {"name": "data-91ee8ccb0456755c4f6e52d4e4aac060"}, "mark": {"type": "text", "align": "left", "fontSize": 10}, "encoding": {"color": {"type": "nominal", "field": "t", "legend": null, "scale": {"range": ["#EB5C2E", "#179FDB", "#00A767", "#cf970c"]}}, "text": {"type": "nominal", "field": "t"}, "x": {"type": "quantitative", "field": "x"}, "y": {"type": "quantitative", "field": "y"}}}], "height": 300, "title": {"text": "Evolution of LCOE for renewable energy technologies", "align": "left", "anchor": "start", "color": "#F4134D", "dx": 5, "dy": -5, "fontSize": 14, "subtitle": ["Levelised cost of electricity. Source: CCC, based on IRENA (2020)"], "subtitleColor": "#F4134D", "subtitleFontSize": 12, " ...
# </script>

# %% [markdown]
# ### Fig 9-2

# %%
f = "fig2_energy-investment"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-13878a0d87214377a5d25964c1286d8c"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-13878a0d87214377a5d25964c1286d8c");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}}, "layer": [{"data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/what-are-the-likely-costs-of-the-transition-to-a-sustainable-economy/data/fig2_energy-investment.csv"}, "mark": {"type": "bar", "opacity": 0.9}, "encoding": {"color": {"type": "nominal", "field": "industry", "legend": null, "scale": {"range": ["#122B39", "#5C267B", "#cf970c", "#00A767", "#0063AF", "#F4134D", "#179FDB", "#36B7B4"]}}, "x": {"type": "nominal", "axis": null, "field": "index", "sort": []}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelColor": "#676A86", "labelFontSize": 10, "tickColor": "#676A86", "tickCount": 7, "title": "billion US$", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": -5, "titleY": -5}, "field": "value", "sort": []}}}, {"data": {"name": "data-a20f1176c7465a125ee0bed6fe7dee57"}, "mark": {"type": "text", "align": "left", "angle": 270}, "encoding": {"color": {"type": "nominal", "field": "t", "legend": null}, "text": {"type": "nominal", "field": "t"}, "x": {"type": "nominal", "axis": null, "field": "x", "sort": null}, "y": {"type": "quantitative", "field": "y"}}}, {"data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/what-are-the-likely-costs-of-the-transition-to-a-sustainable-economy/data/fig2_energy-investment.csv"}, "mark": {"type": "text", "align": "right", "angle": 60, "dx": -8, "dy": -3}, "encoding": {"color": {"type": "nominal", "field": "industry", "legend": null, "scale": {"range": ["#122B39", "#5C267B", "#cf970c", "#00A767", "#0063AF", "#F4134D", "#179FDB", "#36B7B4"]}}, "text": {"type": "nominal", "field": "year"}, "x": {"type": "nominal", "axis": null, "field": "index", "sort": []}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelColor": "#676A86", "labelFontSize": 10, "tickColor": "#676A86", "tickCount": 7, "title": "billion US$", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": -5, "titleY": -5}, "field": "value", "sort": []}}, "transform": [{"filter": "datum.industry=='Renewable power'"}, {"filter": {"field": "year", "oneOf": ["2019", "2020", "2021E"]}}]}], "height": 200, "title": {"text": "Global energy supply investment by sector", "align": "left", "anchor": "start", "dx": 5, "dy": -5, "fontSize": 12, "subtitle": ["Billion US$ 2019. Source: IEA (2021)"], "subtitleFontSize": 11, "subtitleFontStyle": "italic"}, "width": 500, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-a20f1176c7465a125ee0bed6fe7dee57": [{"t": "Upstream", "y": 0, "x": "Upstream_2018"}, {"t": "Mid/downstream", "y": 0, "x": "Mid/downstream_2018"}, {"t": "Coal supply", "y": 0, "x": "Coal supply_2018"}, {"t": "Low-carbon fuels", "y": 0, "x": "Low-carbon fuels_2018"}, {"t": "Renewable power", "y": 0, "x": "Renewable power_2018"}, {"t": "Fossil fuel power", "y": 0, "x": "Fossil fuel power_2018"}, {"t": "Nuclear power", "y": 0, "x": "Nuclear power_2018"}, {"t": "Electricity networks and battery storage", "y": 0, "x": "Electricity networks and battery storage_2018"}]}}, {});
# </script>

# %%
f += "_dark"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-f10e14c6b084495f9ea44d4e7fb315b2"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-f10e14c6b084495f9ea44d4e7fb315b2");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}, "background": "#122B39", "font": "Georgia"}, "layer": [{"data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/what-are-the-likely-costs-of-the-transition-to-a-sustainable-economy/data/fig2_energy-investment.csv"}, "mark": {"type": "bar", "opacity": 0.9}, "encoding": {"color": {"type": "nominal", "field": "industry", "legend": null, "scale": {"range": ["#676A86", "#EB5C2E", "#cf970c", "#00A767", "#0063AF", "#F4134D", "#179FDB", "#36B7B4"]}}, "x": {"type": "nominal", "axis": null, "field": "index", "sort": []}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelColor": "#676A86", "labelFontSize": 12, "tickColor": "#676A86", "tickCount": 7, "title": "billion US$", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 12, "titleFontWeight": "normal", "titleX": -5, "titleY": -5}, "field": "value", "sort": []}}}, {"data": {"name": "data-a20f1176c7465a125ee0bed6fe7dee57"}, "mark": {"type": "text", "align": "left", "angle": 270}, "encoding": {"color": {"type": "nominal", "field": "t", "legend": null}, "text": {"type": "nominal", "field": "t"}, "x": {"type": "nominal", "axis": null, "field": "x", "sort": null}, "y": {"type": "quantitative", "field": "y"}}}, {"data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/what-are-the-likely-costs-of-the-transition-to-a-sustainable-economy/data/fig2_energy-investment.csv"}, "mark": {"type": "text", "align": "right", "angle": 60, "dx": -8, "dy": -3}, "encoding": {"color": {"type": "nominal", "field": "industry", "legend": null, "scale": {"range": ["#676A86", "#EB5C2E", "#cf970c", "#00A767", "#0063AF", "#F4134D", "#179FDB", "#36B7B4"]}}, "text": {"type": "nominal", "field": "year"}, "x": {"type": "nominal", "axis": null, "field": "index", "sort": []}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelColor": "#676A86", "labelFontSize": 12, "tickColor": "#676A86", "tickCount": 7, "title": "billion US$", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 12, "titleFontWeight": "normal", "titleX": -5, "titleY": -5}, "field": "value", "sort": []}}, "transform": [{"filter": "datum.industry=='Renewable power'"}, {"filter": {"field": "year", "oneOf": ["2019", "2020", "2021E"]}}]}], "height": 200, "title": {"text": "Global energy supply investment by sector", "align": "left", "anchor": "start", "color": "#F4134D", "dx": 5, "dy": -5, "fontSize": 14, "subtitle": ["Billion US$ 2019. Source: IEA (2021)"], "subtitleColor": "#F4134D", "subtitleFontSize": 12, "subtitleFontStyle": "italic"}, "width": 500, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-a20f1176c7465a125ee0bed6fe7dee57": [{"t": "Upstream", "y": 0, "x": "Upstream_2018"}, {"t": "Mid/downstream", "y": 0, "x": "Mid/downstream_2018"}, {"t": "Coal supply", "y": 0, "x": "Coal supply_2018"}, {"t": "Low-carbon fuels", "y": 0, "x": "Low-carbon fuels_2018"}, {"t": "Renewable power", "y": 0, "x": "Renewable power_2018"}, {"t": "Fossil fuel power", "y": 0, "x": "Fossil fuel power_2018"}, {"t": "Nuclear power", "y": 0, "x": "Nuclear power_2018"}, {"t": "Electricity networks and battery storage", "y": 0, "x": "Electricity networks and battery storage_2018"}]}}, {});
# </script>

# %% [markdown]
# ### Fig 9-3

# %%
f = "fig3_investment"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-eaf06968b758472daf531917250fa9c9"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-eaf06968b758472daf531917250fa9c9");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}}, "layer": [{"mark": {"type": "area", "opacity": 0.7}, "encoding": {"color": {"type": "nominal", "field": "sector", "legend": null, "scale": {"range": ["#36B7B4", "#E6224B", "#F4C245", "#0063AF", "#00A767", "#179FDB", "#EB5C2E"]}, "sort": []}, "x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 5, "title": "", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86"}, "field": "year", "sort": []}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 7, "ticks": false, "title": "\u00a3 billion / year", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": 30, "titleY": -5}, "field": "value", "stack": true}}, "transform": [{"filter": "datum.sector!=\"Total\""}]}, {"mark": {"type": "text", "align": "left", "dx": 5}, "encoding": {"color": {"type": "nominal", "field": "sector", "legend": null, "scale": {"range": ["#36B7B4", "#E6224B", "#F4C245", "#0063AF", "#00A767", "#179FDB", "#EB5C2E"]}, "sort": []}, "text": {"type": "nominal", "field": "sector"}, "x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 5, "title": "", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86"}, "field": "year", "sort": []}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 7, "ticks": false, "title": "\u00a3 billion / year", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": 30, "titleY": -5}, "field": "value", "stack": true}}, "transform": [{"filter": "datum.sector!=\"Total\""}, {"filter": "datum.year==2050"}]}], "data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/what-are-the-likely-costs-of-the-transition-to-a-sustainable-economy/data/fig3_investment.csv"}, "height": 300, "title": {"text": "Capital investment costs and operating cost savings", "align": "left", "anchor": "start", "dx": 5, "dy": -5, "fontSize": 12, "subtitle": ["The Sixth Carbon Budget - Balanced Pathway. Source: CCC (2020)"], "subtitleFontSize": 11, "subtitleFontStyle": "italic"}, "width": 400, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json"}, {});
# </script>

# %%
f += "_dark"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-d10dc3b4737243fd8feb4517b5a84826"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-d10dc3b4737243fd8feb4517b5a84826");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}, "background": "#122B39", "font": "Georgia"}, "layer": [{"mark": {"type": "area", "opacity": 0.7}, "encoding": {"color": {"type": "nominal", "field": "sector", "legend": null, "scale": {"range": ["#36B7B4", "#E6224B", "#F4C245", "#0063AF", "#00A767", "#179FDB", "#EB5C2E"]}, "sort": []}, "x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "labelFontSize": 12, "orient": "bottom", "tickColor": "#676A86", "tickCount": 5, "title": "", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86", "titleFontSize": 12}, "field": "year", "sort": []}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelFontSize": 12, "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 7, "ticks": false, "title": "\u00a3 billion / year", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 12, "titleFontWeight": "normal", "titleX": 30, "titleY": -5}, "field": "value", "stack": true}}, "transform": [{"filter": "datum.sector!=\"Total\""}]}, {"mark": {"type": "text", "align": "left", "dx": 5}, "encoding": {"color": {"type": "nominal", "field": "sector", "legend": null, "scale": {"range": ["#36B7B4", "#E6224B", "#F4C245", "#0063AF", "#00A767", "#179FDB", "#EB5C2E"]}, "sort": []}, "text": {"type": "nominal", "field": "sector"}, "x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "labelFontSize": 12, "orient": "bottom", "tickColor": "#676A86", "tickCount": 5, "title": "", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86", "titleFontSize": 12}, "field": "year", "sort": []}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelFontSize": 12, "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 7, "ticks": false, "title": "\u00a3 billion / year", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 12, "titleFontWeight": "normal", "titleX": 30, "titleY": -5}, "field": "value", "stack": true}}, "transform": [{"filter": "datum.sector!=\"Total\""}, {"filter": "datum.year==2050"}]}], "data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/what-are-the-likely-costs-of-the-transition-to-a-sustainable-economy/data/fig3_investment.csv"}, "height": 300, "title": {"text": "Capital investment costs and operating cost savings", "align": "left", "anchor": "start", "color": "#F4134D", "dx": 5, "dy": -5, "fontSize": 14, "subtitle": ["The Sixth Carbon Budget - Balanced Pathway. Source: CCC (2020)"], "subtitleColor": "#F4134D", "subtitleFontSize": 12, "subtitleFontStyle": "italic"}, "width": 400, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json"}, {});
# </script>

# %% [markdown]
# # Article 11

# %% [markdown]
# ## Post-growth

# %%
readme = "# Article 11 \n\n## Post-growth\n\n"
open("README.md", "a").write(readme)
# Out:
# 31

# %% [markdown]
# ### Fig 11-1

# %%
# https://data.worldbank.org/indicator/EN.ATM.CO2E.KD.GD
df = (
    pd.read_csv("raw/API_EN.ATM.CO2E.KD.GD_DS2_en_csv_v2_3016406.csv", skiprows=3)
    .drop(["Indicator Name", "Indicator Code", "Country Code", "Unnamed: 65"], axis=1)
    .set_index("Country Name")
    .stack()
    .reset_index()
)
df.columns = ["country", "year", "value"]

# %%
f = "fig11-1_gdp-emissions-intensity"
f11_1 = eco_git_path + f + ".csv"
df.to_csv("data/" + f + ".csv")
f += local_suffix
open("visualisation/" + f + ".html", "w").write(
    vega_embed.replace(
        "JSON_PATH", f11_1.replace("/data/", "/visualisation/").replace(".csv", ".json")
    )
)
if LOCAL:
    f11_1 = df
readme = (
    "### "
    + f
    + " --- [json](visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg](visualisation/'
    + f
    + '.svg "'
    + f
    + '") [png](visualisation/'
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"](visualisation/'
    + f
    + '.svg "'
    + f
    + '")](visualisation/'
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
df.head()
# Out:
#                        country  year     value
# 0                        Aruba  1986  0.183050
# 1                        Aruba  1987  0.392628
# 2                        Aruba  1988  0.452976
# 3                        Aruba  1989  0.428165
# 4  Africa Eastern and Southern  1960  0.767570

# %%
base = alt.Chart(f11_1).encode(
    x=alt.X(
        "year:Q",
        axis=alt.Axis(
            grid=False,
            titleAlign="center",
            titleAnchor="middle",
            title="",
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            tickCount=5,
            orient="bottom",
            labelAngle=0,
            format=".0f",
            # zindex=1,
            # offset=-43
        ),
    )
)
lines = (
    base.mark_line()
    .encode(
        y=alt.Y(
            "value:Q",
            axis=alt.Axis(
                grid=True,
                gridColor=colors["eco-gray"],
                gridOpacity=0.1,
                title="kgCO₂e per 2010 US$ of GDP",
                titleAnchor="start",
                labelColor=colors["eco-gray"],
                titleColor=colors["eco-gray"],
                tickColor=colors["eco-gray"],
                domainColor=colors["eco-gray"],
                titleFontSize=10,
                titleFontWeight="normal",
                ticks=False,
                labelAlign="left",
                labelBaseline="middle",
                labelPadding=-5,
                labelOffset=-10,
                titleX=25,
                titleY=-5,
                titleBaseline="bottom",
                titleAngle=0,
                titleAlign="left",
                tickCount=7,
                format=".1f",
            ),
        ),
        color=alt.Color(
            "country:N",
            legend=None,
            scale=alt.Scale(
                range=[
                    colors["eco-light-blue"],
                    colors["eco-turquiose"],
                    colors["eco-mid-blue"],
                ]
            ),
        ),
    )
    .transform_filter(
        alt.FieldOneOfPredicate(
            field="country", oneOf=["United States", "United Kingdom", "European Union"]
        )
    )
)
line = (
    base.mark_line(color=colors["eco-gray"], strokeWidth=3)
    .encode(y="value:Q")
    .transform_filter(alt.FieldOneOfPredicate(field="country", oneOf=["World"]))
)
labels = (
    lines.mark_text(align="left", dx=5)
    .encode(
        text="country:N",
    )
    .transform_filter("datum.year==2018")
)
label = (
    line.mark_text(
        align="left", dx=5, fontSize=12, fontStyle="bold", color=colors["eco-gray"]
    )
    .encode(text="country:N")
    .transform_filter("datum.year==2018")
)
title = alt.TitleParams(
    "Evolution of the emissions intensity of GDP",
    subtitle=["Emissions intensity of GDP. Source: World Bank Development Indicators"],
    anchor="start",
    align="left",
    dx=5,
    fontSize=12,
    subtitleFontSize=11,
    subtitleFontStyle="italic",
)
layer1 = (
    ((lines + line + labels + label).properties(height=300, width=400))
    .configure_view(stroke=None)
    .properties(title=title)
)
layer1.save("visualisation/" + f + ".json")
layer1.save("visualisation/" + f + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + ".svg")
open("README.md", "a").write(readme)
with alt.data_transformers.disable_max_rows():
    layer1.display()
# Out:
# alt.LayerChart(...)

# %%
base = alt.Chart(f11_1).encode(
    x=alt.X(
        "year:Q",
        axis=alt.Axis(
            grid=False,
            titleAlign="center",
            titleAnchor="middle",
            title="",
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            tickCount=5,
            titleFontSize=12,
            labelFontSize=12,
            orient="bottom",
            labelAngle=0,
            format=".0f",
            # zindex=1,
            # offset=-43
        ),
    )
)
lines = (
    base.mark_line()
    .encode(
        y=alt.Y(
            "value:Q",
            axis=alt.Axis(
                grid=True,
                gridColor=colors["eco-gray"],
                gridOpacity=0.1,
                title="kgCO₂e per 2010 US$ of GDP",
                titleAnchor="start",
                labelColor=colors["eco-gray"],
                titleColor=colors["eco-gray"],
                tickColor=colors["eco-gray"],
                domainColor=colors["eco-gray"],
                titleFontSize=12,
                labelFontSize=12,
                titleFontWeight="normal",
                ticks=False,
                labelAlign="left",
                labelBaseline="middle",
                labelPadding=-5,
                labelOffset=-10,
                titleX=25,
                titleY=-2,
                titleBaseline="bottom",
                titleAngle=0,
                titleAlign="left",
                tickCount=7,
                format=".1f",
            ),
        ),
        color=alt.Color(
            "country:N",
            legend=None,
            scale=alt.Scale(
                range=[
                    colors["eco-light-blue"],
                    colors["eco-turquiose"],
                    colors["eco-mid-blue"],
                ]
            ),
        ),
    )
    .transform_filter(
        alt.FieldOneOfPredicate(
            field="country", oneOf=["United States", "United Kingdom", "European Union"]
        )
    )
)
line = (
    base.mark_line(color=colors["eco-gray"], strokeWidth=3)
    .encode(y="value:Q")
    .transform_filter(alt.FieldOneOfPredicate(field="country", oneOf=["World"]))
)
labels = (
    lines.mark_text(align="left", dx=5)
    .encode(
        text="country:N",
    )
    .transform_filter("datum.year==2018")
)
label = (
    line.mark_text(
        align="left", dx=5, fontSize=12, fontStyle="bold", color=colors["eco-gray"]
    )
    .encode(text="country:N")
    .transform_filter("datum.year==2018")
)
title = alt.TitleParams(
    "Evolution of the emissions intensity of GDP",
    subtitle=["Emissions intensity of GDP. Source: World Bank Development Indicators"],
    anchor="start",
    align="left",
    dx=5,
    dy=-5,
    fontSize=14,
    subtitleFontSize=12,
    color=colors["eco-dot"],
    subtitleColor=colors["eco-dot"],
    subtitleFontStyle="italic",
)
layer1 = (
    ((lines + line + labels + label).properties(height=300, width=400))
    .configure(font="Georgia", background=colors["eco-background"])
    .configure_view(stroke=None)
    .properties(title=title)
)
layer1.save("visualisation/" + f + "_dark.json")
layer1.save("visualisation/" + f + "_dark.png", scale_factor=2.0)
layer1.save("visualisation/" + f + "_dark.svg")
readme = re.sub(f, f + "_dark", readme)
open("README.md", "a").write(readme)
with alt.data_transformers.disable_max_rows():
    layer1.display()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Article 12

# %% [markdown]
# ## Centre page

# %%
readme = "# Article 12 \n\n## Centre page\n\n"
open("README.md", "a").write(readme)
# Out:
# 31

# %% [markdown]
# ### Fig 12-1

# %%
# https://www.datagraver.com/case/kyoto-cherry-blossom-full-flower-dates
# https://www1.ncdc.noaa.gov/pub/data/paleo/historical/phenology/japan/LatestVersion/
# https://n-kishou.com/corp/news-contents/sakura/?lang=en
df = pd.read_excel("raw/KyotoFullFlower7.xls", skiprows=25, usecols="A:C").dropna()
df.columns = ["year", "day", "date"]
df["date"] = "0" + df["date"].astype(str).str[0] + "-" + df["date"].astype(str).str[1:3]

# %%
f = "fig12-1_cherry-blossom"
f12_1 = eco_git_path + f + ".csv"
df.to_csv("data/" + f + ".csv")
f += local_suffix
open("visualisation/" + f + ".html", "w").write(
    vega_embed.replace(
        "JSON_PATH", f12_1.replace("/data/", "/visualisation/").replace(".csv", ".json")
    )
)
if LOCAL:
    f12_1 = df
readme = (
    "### "
    + f
    + " --- [json](visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg](visualisation/'
    + f
    + '.svg "'
    + f
    + '") [png](visualisation/'
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"](visualisation/'
    + f
    + '.svg "'
    + f
    + '")](visualisation/'
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
df.head()
# Out:
#     year    day   date
# 11   812   92.0  04-01
# 14   815  105.0  04-15
# 30   831   96.0  04-06
# 50   851  108.0  04-18
# 52   853  104.0  04-14

# %%
base = alt.Chart(f12_1).encode(
    x=alt.X(
        "year:Q",
        sort=[],
        axis=alt.Axis(
            grid=False,
            title="Year",
            titleAlign="right",
            titleAnchor="end",
            titleY=-15,
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            tickCount=10,
            orient="bottom",
            labelAngle=0,
            format=".0f",
        ),
        scale=alt.Scale(domain=[800, 2021], nice=False),
    )
)
points = base.mark_point(
    color=colors["eco-dot"], fill=colors["eco-dot"], size=10, opacity=0.2
).encode(
    y=alt.Y(
        "date:T",
        sort=[],
        axis=alt.Axis(
            grid=False,
            title="First full-flowering day",
            titleX=5,
            titleY=15,
            titleBaseline="bottom",
            titleAngle=0,
            titleAlign="left",
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
        ),
        scale=alt.Scale(domain=["03-15", "05-15"]),
    )
)
line = (
    points.mark_line(color=colors["eco-dot"])
    .encode(y=alt.Y("y:T", sort=[]))
    .transform_window(y="mean(date)", frame=[-25, 25])
)
line2 = (
    points.mark_line(color=colors["eco-gray"], opacity=0.5)
    .encode(y="y:T")
    .transform_window(y="mean(date)", frame=[-1000, 1000])
)
text1 = (
    alt.Chart(pd.DataFrame([{"x": 810, "y": "04-16", "t": "overall mean"}]))
    .mark_text(color=colors["eco-gray"], align="left", dy=2)
    .encode(x="x:Q", y="y:T", text="t:N")
)
text2 = (
    alt.Chart(pd.DataFrame([{"x": 890, "y": "04-09", "t": "50-year moving window"}]))
    .mark_text(color=colors["eco-dot"], align="left")
    .encode(x="x:Q", y="y:T", text="t:N")
)
text3 = (
    alt.Chart(
        pd.DataFrame(
            [
                {"x": 2021, "y": "04-14", "t": "14th"},
                {"x": 2021, "y": "04-17", "t": "April"},
            ]
        )
    )
    .mark_text(color=colors["eco-gray"], align="left")
    .encode(x="x:Q", y="y:T", text="t:N")
)
text4 = (
    alt.Chart(pd.DataFrame([{"x": 2021, "y": "04-05", "t": "5th"}]))
    .mark_text(color=colors["eco-dot"], align="left")
    .encode(x="x:Q", y="y:T", text="t:N")
)
points2 = points.mark_point(fill=colors["eco-turquiose"]).transform_filter(
    alt.FieldOneOfPredicate(field="year", oneOf=[2021, 1323, 1409])
)
points3 = (
    alt.Chart(pd.DataFrame([{"x": 2021, "y": "03-26"}]))
    .mark_point(fill=colors["eco-turquiose"], opacity=0.8)
    .encode(x="x:Q", y="y:T")
)
text5 = (
    alt.Chart(pd.DataFrame([{"x": 1323, "y": "05-05", "t": "May 5th, 1323"}]))
    .mark_text(
        color=scale_lightness(colors["eco-turquiose"], 0.7), align="center", dy=-8
    )
    .encode(x="x:Q", y="y:T", text="t:N")
)
text6 = (
    alt.Chart(pd.DataFrame([{"x": 1409, "y": "03-27", "t": "March 27th, 1409"}]))
    .mark_text(
        color=scale_lightness(colors["eco-turquiose"], 0.7), align="center", dy=15
    )
    .encode(x="x:Q", y="y:T", text="t:N")
)
text7 = (
    alt.Chart(pd.DataFrame([{"x": 2021, "y": "03-26", "t": "March 26th, 2021"}]))
    .mark_text(
        color=scale_lightness(colors["eco-turquiose"], 0.7), align="right", dx=-7, dy=10
    )
    .encode(x="x:Q", y="y:T", text="t:N")
)
title = alt.TitleParams(
    "Full-flowering day of the cherry blossom in Kyoto, Japan",
    subtitle=[
        "Source: NOAA, based on Aono, Kazui (2008), Aono, Saito (2010) and Aono (2012)"
    ],
    anchor="start",
    align="left",
    dx=5,
    fontSize=12,
    subtitleFontSize=11,
    subtitleFontStyle="italic",
)
layer1 = (
    (
        (
            points
            + line2
            + line
            + text1
            + text2
            + text3
            + text4
            + points2
            + points3
            + text5
            + text6
            + text7
        ).properties(height=300, width=400)
    )
    .configure_view(stroke=None)
    .properties(title=title)
)
layer1.save("visualisation/" + f + ".json")
layer1.save("visualisation/" + f + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + ".svg")
open("README.md", "a").write(readme)
layer1
# Out:
# WARN An ancestor parsed field "y" as number but a child wants to parse the field as date.
# WARN An ancestor parsed field "y" as number but a child wants to parse the field as date.
# WARN An ancestor parsed field "y" as number but a child wants to parse the field as date.
# WARN An ancestor parsed field "y" as number but a child wants to parse the field as date.
# alt.LayerChart(...)

# %%
base = alt.Chart(f12_1).encode(
    x=alt.X(
        "year:Q",
        sort=[],
        axis=alt.Axis(
            grid=False,
            title="Year",
            titleAlign="right",
            titleAnchor="end",
            titleY=-15,
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            tickCount=10,
            titleFontSize=12,
            labelFontSize=12,
            orient="bottom",
            labelAngle=0,
            format=".0f",
        ),
        scale=alt.Scale(domain=[800, 2021], nice=False),
    )
)
points = base.mark_point(
    color=colors["eco-dot"], fill=colors["eco-dot"], size=10, opacity=0.2
).encode(
    y=alt.Y(
        "date:T",
        sort=[],
        axis=alt.Axis(
            grid=False,
            title="First full-flowering day",
            titleX=5,
            titleY=15,
            titleBaseline="bottom",
            titleAngle=0,
            titleFontSize=12,
            labelFontSize=12,
            titleAlign="left",
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
        ),
        scale=alt.Scale(domain=["03-15", "05-15"]),
    )
)
line = (
    points.mark_line(color=colors["eco-dot"])
    .encode(y=alt.Y("y:T", sort=[]))
    .transform_window(y="mean(date)", frame=[-25, 25])
)
line2 = (
    points.mark_line(color=colors["eco-gray"], opacity=0.5)
    .encode(y="y:T")
    .transform_window(y="mean(date)", frame=[-1000, 1000])
)
text1 = (
    alt.Chart(pd.DataFrame([{"x": 810, "y": "04-16", "t": "overall mean"}]))
    .mark_text(color=colors["eco-gray"], align="left", dy=2)
    .encode(x="x:Q", y="y:T", text="t:N")
)
text2 = (
    alt.Chart(pd.DataFrame([{"x": 890, "y": "04-09", "t": "50-year moving window"}]))
    .mark_text(color=colors["eco-dot"], align="left")
    .encode(x="x:Q", y="y:T", text="t:N")
)
text3 = (
    alt.Chart(
        pd.DataFrame(
            [
                {"x": 2021, "y": "04-14", "t": "14th"},
                {"x": 2021, "y": "04-17", "t": "April"},
            ]
        )
    )
    .mark_text(color=colors["eco-gray"], align="left")
    .encode(x="x:Q", y="y:T", text="t:N")
)
text4 = (
    alt.Chart(pd.DataFrame([{"x": 2021, "y": "04-05", "t": "5th"}]))
    .mark_text(color=colors["eco-dot"], align="left")
    .encode(x="x:Q", y="y:T", text="t:N")
)
points2 = points.mark_point(fill=colors["eco-turquiose"]).transform_filter(
    alt.FieldOneOfPredicate(field="year", oneOf=[2021, 1323, 1409])
)
points3 = (
    alt.Chart(pd.DataFrame([{"x": 2021, "y": "03-26"}]))
    .mark_point(fill=colors["eco-turquiose"], opacity=0.8)
    .encode(x="x:Q", y="y:T")
)
text5 = (
    alt.Chart(pd.DataFrame([{"x": 1323, "y": "05-05", "t": "May 5th, 1323"}]))
    .mark_text(
        color=scale_lightness(colors["eco-turquiose"], 0.7), align="center", dy=-8
    )
    .encode(x="x:Q", y="y:T", text="t:N")
)
text6 = (
    alt.Chart(pd.DataFrame([{"x": 1409, "y": "03-27", "t": "March 27th, 1409"}]))
    .mark_text(
        color=scale_lightness(colors["eco-turquiose"], 0.7), align="center", dy=15
    )
    .encode(x="x:Q", y="y:T", text="t:N")
)
text7 = (
    alt.Chart(pd.DataFrame([{"x": 2021, "y": "03-26", "t": "March 26th, 2021"}]))
    .mark_text(
        color=scale_lightness(colors["eco-turquiose"], 0.7), align="right", dx=-7, dy=10
    )
    .encode(x="x:Q", y="y:T", text="t:N")
)
title = alt.TitleParams(
    "Full-flowering day of the cherry blossom in Kyoto, Japan",
    subtitle=[
        "Source: NOAA, based on Aono, Kazui (2008), Aono, Saito (2010) and Aono (2012)"
    ],
    anchor="start",
    align="left",
    dx=5,
    dy=-5,
    fontSize=14,
    subtitleFontSize=12,
    color=colors["eco-dot"],
    subtitleColor=colors["eco-dot"],
    subtitleFontStyle="italic",
)
layer1 = (
    (
        (
            points
            + line2
            + line
            + text1
            + text2
            + text3
            + text4
            + points2
            + points3
            + text5
            + text6
            + text7
        ).properties(height=300, width=400)
    )
    .configure(font="Georgia", background=colors["eco-background"])
    .configure_view(stroke=None)
    .properties(title=title)
)
layer1.save("visualisation/" + f + "_dark.json")
layer1.save("visualisation/" + f + "_dark.png", scale_factor=2.0)
layer1.save("visualisation/" + f + "_dark.svg")
readme = re.sub(f, f + "_dark", readme)
open("README.md", "a").write(readme)
layer1
# Out:
# WARN An ancestor parsed field "y" as number but a child wants to parse the field as date.
# WARN An ancestor parsed field "y" as number but a child wants to parse the field as date.
# WARN An ancestor parsed field "y" as number but a child wants to parse the field as date.
# WARN An ancestor parsed field "y" as number but a child wants to parse the field as date.
# alt.LayerChart(...)

# %% [markdown]
# ### Fig 12-2a

# %%
# https://www.eea.europa.eu/data-and-maps/data/external/mass-balance-of-the-greenland
# https://www.epa.gov/climate-indicators/climate-change-indicators-glaciers
# https://wgms.ch/latest-glacier-mass-balance-data/
df = pd.read_csv("raw/glaciers_fig-1.csv", skiprows=6)
df.columns = ["year", "glaciers", "d"]
df = df.drop(["d"], axis=1)
df2 = pd.read_excel("raw/imbie_dataset_greenland_dynamics-2019_12_10.xlsx")
df2 = df2[
    [
        "Year",
        "Cumulative ice sheet mass change (Gt)",
        "Cumulative ice sheet mass change uncertainty (Gt)",
    ]
].dropna()
df2.columns = ["year", "greenland", "e"]
df2 = pd.concat([pd.DataFrame([{"year": 1991, "greenland": 0, "e": 0}]), df2])
df2["greenland1"] = df2["greenland"] - df2["e"] / 2
df2["greenland2"] = df2["greenland"] + df2["e"] / 2
df2 = df2.drop(["e"], axis=1)
df3 = pd.read_excel("raw/imbie_dataset-2018_07_23.xlsx")
df3 = df3[
    [
        "Year",
        "Cumulative ice mass change (Gt)",
        "Cumulative ice mass change uncertainty (Gt)",
    ]
]
df3.columns = ["year", "antarctica", "e"]
df3["antarctica1"] = df3["antarctica"] - df3["e"] / 2
df3["antarctica2"] = df3["antarctica"] + df3["e"] / 2
df3 = df3.drop(["e"], axis=1)
df0 = -df.set_index("year").join(df2.set_index("year")).join(df3.set_index("year"))
df = df0.drop("glaciers", axis=1).reset_index()

# %%
f = "fig12-2a_ice"
f12_2a = eco_git_path + f + ".csv"
df.to_csv("data/" + f + ".csv")
f += local_suffix
open("visualisation/" + f + ".html", "w").write(
    vega_embed.replace(
        "JSON_PATH",
        f12_2a.replace("/data/", "/visualisation/").replace(".csv", ".json"),
    )
)
if LOCAL:
    f12_2a = df
readme = (
    "### "
    + f
    + " --- [json](visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg](visualisation/'
    + f
    + '.svg "'
    + f
    + '") [png](visualisation/'
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"](visualisation/'
    + f
    + '.svg "'
    + f
    + '")](visualisation/'
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
df.head()
# Out:
#    year  greenland  greenland1  greenland2  antarctica  antarctica1  \
# 0  1956        NaN         NaN         NaN         NaN          NaN
# 1  1957        NaN         NaN         NaN         NaN          NaN
# 2  1958        NaN         NaN         NaN         NaN          NaN
# 3  1959        NaN         NaN         NaN         NaN          NaN
# 4  1960        NaN         NaN         NaN         NaN          NaN
#
#    antarctica2
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
base = (
    alt.Chart(f12_2a)
    .encode(
        x=alt.X(
            "year:Q",
            axis=alt.Axis(
                grid=False,
                titleAlign="center",
                titleAnchor="middle",
                title="",
                labelColor=colors["eco-gray"],
                titleColor=colors["eco-gray"],
                tickColor=colors["eco-gray"],
                domainColor=colors["eco-gray"],
                tickCount=5,
                orient="bottom",
                labelAngle=0,
                format=".0f",
                # zindex=1,
                # offset=-43
            ),
            scale=alt.Scale(domain=[1991, 2020]),
        )
    )
    .transform_filter("datum.year<2018")
    .transform_filter("datum.year>1990")
)
line1 = base.mark_line(color=colors["eco-turquiose"]).encode(
    y=alt.Y(
        "greenland:Q",
        axis=alt.Axis(
            grid=True,
            gridColor=colors["eco-gray"],
            gridOpacity=0.1,
            title="Gt of ice",
            titleAnchor="start",
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            titleFontSize=10,
            titleFontWeight="normal",
            ticks=False,
            labelAlign="left",
            labelBaseline="middle",
            labelPadding=-5,
            labelOffset=-10,
            titleX=30,
            titleY=28,
            titleBaseline="bottom",
            titleAngle=0,
            titleAlign="left",
            tickCount=4,
            format=".0f",
        ),
        scale=alt.Scale(domain=[0, 4300]),
    )
)
line2 = base.mark_line(color=colors["eco-light-blue"]).encode(y=alt.Y("antarctica:Q"))
area1 = line1.mark_area(color=colors["eco-turquiose"], opacity=0.5).encode(
    y="greenland1:Q", y2="greenland2:Q"
)
area2 = line2.mark_area(color=colors["eco-light-blue"], opacity=0.5).encode(
    y="antarctica1:Q", y2="antarctica2:Q"
)
ruler = (
    alt.Chart(pd.DataFrame([{"x": 1991, "y": 0}, {"x": 2020, "y": 0}]))
    .mark_line(color=colors["eco-gray"])
    .encode(y="y:Q", x="x:Q")
)
text1 = (
    alt.Chart(pd.DataFrame([{"x": 2017, "y": 3800, "t": "Greenland"}]))
    .mark_text(color=colors["eco-turquiose"], align="left", dx=5)
    .encode(x="x:Q", y="y:Q", text="t:N")
)
text2 = (
    alt.Chart(pd.DataFrame([{"x": 2017, "y": 2600, "t": "Antarctica"}]))
    .mark_text(color=colors["eco-light-blue"], align="left", dx=5)
    .encode(x="x:Q", y="y:Q", text="t:N")
)
title = alt.TitleParams(
    "Cumulative ice mass loss of ice sheets",
    subtitle=["Source: IMBIE/EEA/ESA"],
    anchor="start",
    align="left",
    dx=5,
    fontSize=12,
    subtitleFontSize=11,
    subtitleFontStyle="italic",
)
layer1 = (
    ((area1 + area2 + line1 + line2 + text1 + text2).properties(height=300, width=400))
    .configure_view(stroke=None)
    .properties(title=title)
)
layer1.save("visualisation/" + f + ".json")
layer1.save("visualisation/" + f + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + ".svg")
open("README.md", "a").write(readme)
layer1
# Out:
# alt.LayerChart(...)

# %%
base = (
    alt.Chart(f12_2a)
    .encode(
        x=alt.X(
            "year:Q",
            axis=alt.Axis(
                grid=False,
                titleAlign="center",
                titleAnchor="middle",
                title="",
                labelColor=colors["eco-gray"],
                titleColor=colors["eco-gray"],
                tickColor=colors["eco-gray"],
                domainColor=colors["eco-gray"],
                tickCount=5,
                titleFontSize=12,
                labelFontSize=12,
                orient="bottom",
                labelAngle=0,
                format=".0f",
                # zindex=1,
                # offset=-43
            ),
            scale=alt.Scale(domain=[1991, 2020]),
        )
    )
    .transform_filter("datum.year<2018")
    .transform_filter("datum.year>1990")
)
line1 = base.mark_line(color=colors["eco-turquiose"]).encode(
    y=alt.Y(
        "greenland:Q",
        axis=alt.Axis(
            grid=True,
            gridColor=colors["eco-gray"],
            gridOpacity=0.1,
            title="Gt of ice",
            titleAnchor="start",
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            titleFontSize=12,
            labelFontSize=12,
            titleFontWeight="normal",
            ticks=False,
            labelAlign="left",
            labelBaseline="middle",
            labelPadding=-5,
            labelOffset=-10,
            titleX=40,
            titleY=31,
            titleBaseline="bottom",
            titleAngle=0,
            titleAlign="left",
            tickCount=4,
            format=".0f",
        ),
        scale=alt.Scale(domain=[0, 4300]),
    )
)
line2 = base.mark_line(color=colors["eco-light-blue"]).encode(y=alt.Y("antarctica:Q"))
area1 = line1.mark_area(color=colors["eco-turquiose"], opacity=0.5).encode(
    y="greenland1:Q", y2="greenland2:Q"
)
area2 = line2.mark_area(color=colors["eco-light-blue"], opacity=0.5).encode(
    y="antarctica1:Q", y2="antarctica2:Q"
)
ruler = (
    alt.Chart(pd.DataFrame([{"x": 1991, "y": 0}, {"x": 2020, "y": 0}]))
    .mark_line(color=colors["eco-gray"])
    .encode(y="y:Q", x="x:Q")
)
text1 = (
    alt.Chart(pd.DataFrame([{"x": 2017, "y": 3800, "t": "Greenland"}]))
    .mark_text(color=colors["eco-turquiose"], align="left", dx=5)
    .encode(x="x:Q", y="y:Q", text="t:N")
)
text2 = (
    alt.Chart(pd.DataFrame([{"x": 2017, "y": 2600, "t": "Antarctica"}]))
    .mark_text(color=colors["eco-light-blue"], align="left", dx=5)
    .encode(x="x:Q", y="y:Q", text="t:N")
)
title = alt.TitleParams(
    "Cumulative ice mass loss of ice sheets",
    subtitle=["Source: IMBIE/EEA/ESA"],
    anchor="start",
    align="left",
    dx=5,
    fontSize=14,
    subtitleFontSize=12,
    color=colors["eco-dot"],
    subtitleColor=colors["eco-dot"],
    subtitleFontStyle="italic",
)
layer1 = (
    ((area1 + area2 + line1 + line2 + text1 + text2).properties(height=300, width=400))
    .configure(font="Georgia", background=colors["eco-background"])
    .configure_view(stroke=None)
    .properties(title=title)
)
layer1.save("visualisation/" + f + "_dark.json")
layer1.save("visualisation/" + f + "_dark.png", scale_factor=2.0)
layer1.save("visualisation/" + f + "_dark.svg")
readme = re.sub(f, f + "_dark", readme)
open("README.md", "a").write(readme)
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Fig 12-2b

# %%
df = df0["glaciers"].reset_index()

# %%
f = "fig12-2b_glaciers"
f12_2b = eco_git_path + f + ".csv"
df.to_csv("data/" + f + ".csv")
f += local_suffix
open("visualisation/" + f + ".html", "w").write(
    vega_embed.replace(
        "JSON_PATH",
        f12_2b.replace("/data/", "/visualisation/").replace(".csv", ".json"),
    )
)
if LOCAL:
    f12_2b = df
readme = (
    "### "
    + f
    + " --- [json](visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg](visualisation/'
    + f
    + '.svg "'
    + f
    + '") [png](visualisation/'
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"](visualisation/'
    + f
    + '.svg "'
    + f
    + '")](visualisation/'
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
df.head()
# Out:
#    year  glaciers
# 0  1956    -0.000
# 1  1957     0.120
# 2  1958     0.976
# 3  1959     1.414
# 4  1960     1.968

# %%
base = alt.Chart(f12_2b).encode(
    x=alt.X(
        "year:Q",
        axis=alt.Axis(
            grid=False,
            titleAlign="center",
            titleAnchor="middle",
            title="",
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            tickCount=5,
            orient="bottom",
            labelAngle=0,
            format=".0f",
            # zindex=1,
            # offset=-43
        ),
    )
)
area = base.mark_area(
    interpolate="monotone",
    fillOpacity=0.7,
    line={"color": colors["eco-light-blue"]},
    color=alt.Gradient(
        gradient="linear",
        stops=[
            alt.GradientStop(color="white", offset=0),
            alt.GradientStop(color=colors["eco-light-blue"], offset=0.7),
        ],
        x1=0.8,
        x2=1,
        y1=1,
        y2=0,
    ),
).encode(
    y=alt.Y(
        "glaciers:Q",
        axis=alt.Axis(
            grid=True,
            gridColor=colors["eco-gray"],
            gridOpacity=0.1,
            title="m of water equivalent",
            titleAnchor="start",
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            titleFontSize=10,
            titleFontWeight="normal",
            ticks=False,
            labelAlign="left",
            labelBaseline="middle",
            labelPadding=-5,
            labelOffset=-10,
            titleX=20,
            titleY=27,
            titleBaseline="bottom",
            titleAngle=0,
            titleAlign="left",
            tickCount=4,
            format=".0f",
        ),
    )
)
title = alt.TitleParams(
    "Cumulative mass loss of glaciers worldwide",
    subtitle=["Source: EPA, based on WGMS"],
    anchor="start",
    align="left",
    dx=5,
    fontSize=12,
    subtitleFontSize=11,
    subtitleFontStyle="italic",
)
layer1 = (
    ((area).properties(height=300, width=400))
    .configure_view(stroke=None)
    .properties(title=title)
)
layer1.save("visualisation/" + f + ".json")
layer1.save("visualisation/" + f + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + ".svg")
open("README.md", "a").write(readme)
layer1
# Out:
# alt.Chart(...)

# %%
base = alt.Chart(f12_2b).encode()
area = base.mark_area(
    interpolate="monotone",
    fillOpacity=0.7,
    line={"color": colors["eco-light-blue"]},
    color=alt.Gradient(
        gradient="linear",
        stops=[
            alt.GradientStop(color=colors["eco-background"], offset=0),
            alt.GradientStop(color=colors["eco-light-blue"], offset=0.7),
        ],
        x1=0.8,
        x2=1,
        y1=1,
        y2=0,
    ),
).encode(
    x=alt.X(
        "year:Q",
        axis=alt.Axis(
            grid=False,
            titleAlign="center",
            titleAnchor="middle",
            labelFontSize=12,
            title="",
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            tickCount=5,
            orient="bottom",
            labelAngle=0,
            format=".0f",
        ),
    ),
    y=alt.Y(
        "glaciers:Q",
        axis=alt.Axis(
            grid=True,
            gridColor=colors["eco-gray"],
            gridOpacity=0.1,
            title="m of water equivalent",
            titleAnchor="start",
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            titleFontSize=12,
            labelFontSize=12,
            titleFontWeight="normal",
            ticks=False,
            labelAlign="left",
            labelBaseline="middle",
            labelPadding=-5,
            labelOffset=-10,
            titleX=23,
            titleY=29,
            titleBaseline="bottom",
            titleAngle=0,
            titleAlign="left",
            tickCount=4,
            format=".0f",
        ),
    ),
)
title = alt.TitleParams(
    "Cumulative mass loss of glaciers worldwide",
    subtitle=["Source: EPA, based on WGMS"],
    anchor="start",
    align="left",
    dx=5,
    fontSize=14,
    subtitleFontSize=12,
    color=colors["eco-dot"],
    subtitleColor=colors["eco-dot"],
    subtitleFontStyle="italic",
)
layer1 = (
    (area)
    .properties(height=300, width=400, title=title)
    .configure(font="Georgia", background=colors["eco-background"])
    .configure_view(stroke=None)
)
layer1.save("visualisation/" + f + "_dark.json")
layer1.save("visualisation/" + f + "_dark.png", scale_factor=2.0)
layer1.save("visualisation/" + f + "_dark.svg")
readme = re.sub(f, f + "_dark", readme)
open("README.md", "a").write(readme)
layer1
# Out:
# alt.Chart(...)

# %% [markdown]
# # Article 13

# %% [markdown]
# ## Promises

# %%
readme = "# Article 13 \n\n## Promises\n\n"
open("README.md", "a").write(readme)
# Out:
# 28

# %% [markdown]
# ### Fig 13-1

# %%
# Tiloka
df = pd.read_csv("raw/ECO2.TENREYO.C1.csv").drop("Detail", axis=1)

# %%
f = "fig13-1_co2targets"
f13_1 = eco_git_path + f + ".csv"
df.to_csv("data/" + f + ".csv")
f += local_suffix
open("visualisation/" + f + ".html", "w").write(
    vega_embed.replace(
        "JSON_PATH", f13_1.replace("/data/", "/visualisation/").replace(".csv", ".json")
    )
)
if LOCAL:
    f13_1 = df

readme = (
    "### "
    + f
    + " --- [json](visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg](visualisation/'
    + f
    + '.svg "'
    + f
    + '") [png](visualisation/'
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"](visualisation/'
    + f
    + '.svg "'
    + f
    + '")](visualisation/'
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
df.head()
# Out:
#                country CountryCode     Value1     Value2
# 0  Antigua and Barbuda         ATG  73.865440 -80.052870
# 1            Australia         AUS   0.544275  -0.601545
# 2              Austria         AUT  43.387310   5.149522
# 3              Belarus         BLR -58.704910   3.913097
# 4              Belgium         BEL  26.009290   8.748268

# %%
base = alt.Chart(f13_1).encode(
    x=alt.X(
        "Value1:Q",
        axis=alt.Axis(
            grid=True,
            gridColor=colors["eco-gray"],
            gridOpacity=0.1,
            titleAlign="right",
            titleAnchor="end",
            title="Target reduction in emissions from starting year (%)",
            titleFontSize=10,
            labelFontSize=10,
            titleY=-15,
            titleFontWeight="normal",
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            tickCount=5,
            orient="bottom",
            labelAngle=0,
        ),
        scale=alt.Scale(domain=[-150, 100]),
    )
)
points = base.mark_point(
    clip=True,
    color=colors["eco-turquiose"],
    fill=colors["eco-turquiose"],
    size=50,
).encode(
    y=alt.Y(
        "Value2:Q",
        axis=alt.Axis(
            grid=True,
            gridColor=colors["eco-gray"],
            gridOpacity=0.1,
            title="Actual reduction in emissions between 2010-2018 (%)",
            titleAnchor="start",
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            titleFontSize=10,
            labelFontSize=10,
            titleFontWeight="normal",
            ticks=False,
            labelAlign="left",
            labelBaseline="middle",
            labelPadding=-5,
            labelOffset=-10,
            titleX=5,
            titleY=7,
            titleBaseline="bottom",
            titleAngle=0,
            titleAlign="left",
            tickCount=4,
            format=".0f",
        ),
        scale=alt.Scale(domain=[-62, 50], nice=False),
    )
)
# labels=bar.mark_text(color=colors['eco-turquiose'],align='right',dx=-5,baseline='middle').encode(text='Policy:N',x='x:Q').transform_calculate(x='min(0,datum.Average)')
title = alt.TitleParams(
    "Planned and actual reductions in emissions",
    subtitle=[
        "Negative values represent an emissions increase! Source: Tenreyo and de Silva (2021)"
    ],
    anchor="start",
    align="left",
    dx=5,
    dy=-5,
    fontSize=12,
    subtitleFontSize=11,
    subtitleFontStyle="italic",
)
line = points.mark_line(clip=True, color=colors["eco-turquiose"], opacity=0.8).encode(
    y="Value1:Q"
)
zero1 = (
    line.mark_line(clip=True, color=colors["eco-gray"], opacity=0.5)
    .encode(x="z:Q")
    .transform_calculate(z="0")
)
zero2 = (
    line.mark_line(clip=True, color=colors["eco-gray"], opacity=0.5)
    .encode(y="z:Q")
    .transform_calculate(z="0")
)
labels = (
    points.mark_text(clip=True, color=colors["eco-gray"], dy=12)
    .encode(text="CountryCode:N")
    .transform_filter(
        alt.FieldOneOfPredicate(
            field="CountryCode",
            oneOf=[
                "PNG",
                "IND",
                "IDN",
                "MDA",
                "UKR",
                "MLT",
                "GBR",
                "USA",
                "CHN",
                "ROU",
                "LTU",
                "CYP",
                "IRL",
                "JPN",
                "BRA",
                "RUS",
                "SGP",
                "NZL",
                "KOR",
                "CAN",
                "DNK",
                "FIN",
                "EUU",
                "ITA",
                "FRA",
                "DEU",
                "POL",
                "SVN",
                "FIN",
                "CAN",
            ],
        )
    )
)
layer1 = (
    ((zero1 + zero2 + line + points + labels).properties(height=300, width=400))
    .configure_view(stroke=None)
    .properties(title=title)
)
layer1.save("visualisation/" + f + ".json")
layer1.save("visualisation/" + f + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + ".svg")
open("README.md", "a").write(readme)
layer1
# Out:
# alt.LayerChart(...)

# %%
points.encoding.x.axis.titleFontSize = 12
points.encoding.y.axis.titleFontSize = 12
# points.encoding.y.axis.titleY += 2

theme = "_dark"
layer1 = (
    ((zero1 + zero2 + line + points + labels).properties(height=300, width=400))
    .configure_view(stroke=None)
    .properties(title=title)
)
layer1 = layer1.configure_axisY(labelFontSize=12)
layer1 = layer1.configure_axisX(labelFontSize=12)
layer1.config.font = "Georgia"
layer1.config.background = colors["eco-background"]
layer1.config.view.stroke = None
layer1.title.fontSize = 14
layer1.title.subtitleFontSize = 12
layer1.title.dy -= 2
layer1.title.color = colors["eco-dot"]
layer1.title.subtitleColor = colors["eco-dot"]
layer1.save("visualisation/" + f + theme + ".json")
layer1.save("visualisation/" + f + theme + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + theme + ".svg")
readme = re.sub(f, f + theme, readme)
open("README.md", "a").write(readme)
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# #### Fig 13-2a

# %%
configSource = "raw/ECO2.TENREYO.C2a.json"
config = json.loads(open(configSource, "r").read())
df = pd.read_csv(config["data"]["url"]).drop("Detail", axis=1)

# %%
f = "fig13-2a_emissions-by-region"
f13_2a = eco_git_path + f + ".csv"
df.to_csv("data/" + f + ".csv")
f += local_suffix
open("visualisation/" + f + ".html", "w").write(
    vega_embed.replace(
        "JSON_PATH",
        f13_2a.replace("/data/", "/visualisation/").replace(".csv", ".json"),
    )
)
if LOCAL:
    f13_2a = df
readme = (
    "### "
    + f
    + " --- [json](visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg](visualisation/'
    + f
    + '.svg "'
    + f
    + '") [png](visualisation/'
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"](visualisation/'
    + f
    + '.svg "'
    + f
    + '")](visualisation/'
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
df.head()
# Out:
#    Year              Region    Value1    Value2
# 0  1970  Sub Saharan Africa  271.4065  0.915174
# 1  1971  Sub Saharan Africa  284.8900  0.936775
# 2  1972  Sub Saharan Africa  307.0701  0.983175
# 3  1973  Sub Saharan Africa  350.0824  1.091057
# 4  1974  Sub Saharan Africa  379.0392  1.150727

# %%
config = json.loads(open(configSource, "r").read())
if not LOCAL:
    config["data"]["url"] = f13_2a
config["layer"][0]["encoding"]["x"]["axis"]["grid"] = False
config["layer"][0]["encoding"]["x"]["axis"]["labelColor"] = colors["eco-gray"]
config["layer"][0]["encoding"]["x"]["axis"]["titleColor"] = colors["eco-gray"]
config["layer"][0]["encoding"]["x"]["axis"]["tickColor"] = colors["eco-gray"]
config["layer"][0]["encoding"]["x"]["axis"]["domainColor"] = colors["eco-gray"]
config["layer"][0]["encoding"]["y"]["axis"]["grid"] = True
config["layer"][0]["encoding"]["y"]["axis"]["gridColor"] = colors["eco-gray"]
config["layer"][0]["encoding"]["y"]["axis"]["gridOpacity"] = 0.1
config["layer"][0]["encoding"]["y"]["axis"]["title"] = "GtCO₂e"
config["title"][
    "subtitle"
] = "Gigatonnes of CO₂ equivalent. Source: Author's calculations"
config["layer"][0]["encoding"]["y"]["axis"]["titleAnchor"] = "start"
config["layer"][0]["encoding"]["y"]["axis"]["labelColor"] = colors["eco-gray"]
config["layer"][0]["encoding"]["y"]["axis"]["titleColor"] = colors["eco-gray"]
config["layer"][0]["encoding"]["y"]["axis"]["tickColor"] = colors["eco-gray"]
config["layer"][0]["encoding"]["y"]["axis"]["domainColor"] = colors["eco-gray"]
config["layer"][0]["encoding"]["y"]["axis"]["titleFontSize"] = 10
config["layer"][0]["encoding"]["y"]["axis"]["titleFontWeight"] = "normal"
config["layer"][0]["encoding"]["y"]["axis"]["ticks"] = False
config["layer"][0]["encoding"]["y"]["axis"]["labelAlign"] = "left"
config["layer"][0]["encoding"]["y"]["axis"]["labelBaseline"] = "middle"
config["layer"][0]["encoding"]["y"]["axis"]["labelPadding"] = -5
config["layer"][0]["encoding"]["y"]["axis"]["labelOffset"] = -10
config["layer"][0]["encoding"]["y"]["axis"]["titleBaseline"] = "bottom"
config["layer"][0]["encoding"]["y"]["axis"]["titleAngle"] = 0
config["layer"][0]["encoding"]["y"]["axis"]["titleAlign"] = "left"
config["layer"][0]["encoding"]["y"]["axis"]["tickCount"] = 7
config["layer"][0]["encoding"]["y"]["axis"]["titleX"] = 20
config["layer"][0]["encoding"]["y"]["axis"]["titleY"] = -5
config["layer"][0]["encoding"]["y"]["field"] = "m"
config["layer"][0]["encoding"]["color"]["legend"] = None
config["layer"][1]["mark"]["color"] = colors["eco-gray"]
config["layer"][1]["mark"]["opacity"] = 0.1
config["layer"]=[config["layer"][1],config["layer"][0]]
config["title"]["dy"] = -5
config.pop("$schema")
config.pop("autosize")
config["view"] = {"stroke": None}
config["width"] = 400
config["height"] = 300
base = alt.Chart.from_dict(config).transform_calculate(m="datum.Value1/1000")
text = (
    (
        alt.Chart(f13_2a)
        .mark_text(align="left", x=405)
        .encode(
            y=alt.Y("m:Q"),
            text="Region:N",
            color="Region:N",
        )
    )
    .transform_calculate(m="datum.Value1/1000")
    .transform_filter("datum.Year==2018")
)
text1 = text.transform_filter("datum.Region!='South Asia'")
text2 = text.transform_filter("datum.Region=='South Asia'").mark_text(
    dy=-10, x=405, align="left"
)
text3 = (
    alt.Chart(pd.DataFrame([{"y": 15.5, "t": "Kyoto"},{"y": 14.8, "t": "1997"}]))
    .mark_text(color=scale_lightness(colors["eco-gray"], 1.4),align="right",x=220,fontSize=10)
    .encode(y="y:Q", text="t:N")
)
text4 = (
    alt.Chart(pd.DataFrame([{"y": 15.5, "t": "Copenhagen"},{"y": 14.8, "t": "2009"}]))
    .mark_text(color=scale_lightness(colors["eco-gray"], 1.4),align="right",x=322,fontSize=10)
    .encode(y="y:Q", text="t:N")
)
text5 = (
    alt.Chart(pd.DataFrame([{"y": 11.5, "t": "Paris"},{"y": 10.8, "t": "2015"}]))
    .mark_text(color=scale_lightness(colors["eco-gray"], 1.4),align="right",x=370,fontSize=10)
    .encode(y="y:Q", text="t:N")
)
layer1 = (base + text1 + text2 + text3+text4+text5).configure_view(stroke=None)
layer1.save("visualisation/" + f + ".json")
layer1.save("visualisation/" + f + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + ".svg")
open("README.md", "a").write(readme)
layer1
# altair_viewer.display(config, inline=True)
# Out:
# WARN Domains that should be unioned has conflicting sort properties. Sort will be set to true.
# WARN Domains that should be unioned has conflicting sort properties. Sort will be set to true.
# alt.LayerChart(...)

# %%
theme = "_dark"
base.title.fontSize = 14
base.title.subtitleFontSize = 12
base.title.dy -= 2
text3.mark.color=scale_lightness(colors['eco-gray'],0.9)
text4.mark.color=scale_lightness(colors['eco-gray'],0.9)
text5.mark.color=scale_lightness(colors['eco-gray'],0.9)
base.layer[1].encoding.y.axis.titleY += 1
base.layer[1].encoding.y.axis.titleX += 3
base.title.color = colors["eco-dot"]
base.title.subtitleColor = colors["eco-dot"]
layer1 = (base + text1 + text2+text3+text4+text5).configure_view(stroke=None)
layer1 = layer1.configure_axisY(labelFontSize=12)
layer1 = layer1.configure_axisX(labelFontSize=12)
layer1.config.font = "Georgia"
layer1.config.background = colors["eco-background"]
layer1.config.view.stroke = None
layer1.save("visualisation/" + f + theme + ".json")
layer1.save("visualisation/" + f + theme + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + theme + ".svg")
readme = re.sub(f, f + theme, readme)
open("README.md", "a").write(readme)
layer1
# Out:
# WARN Domains that should be unioned has conflicting sort properties. Sort will be set to true.
# WARN Domains that should be unioned has conflicting sort properties. Sort will be set to true.
# alt.LayerChart(...)

# %% [markdown]
# # Article 17

# %% [markdown]
# ## Historic pollution

# %%
readme = "# Article 17 \n\n## Historic pollution\n\n"
open("README.md", "a").write(readme)
# Out:
# 38

# %%
p = (
    eco_git_path.split("main")[0].replace("rawgit", "github")
    + "tree/"
    + "main"
    + "/articles/what-are-the-long-term-economic-effects-of-air-pollution/"
)
readme = "Cloned from [" + p.split("/")[-2] + "](" + p + ")\n\n"
open("README.md", "a").write(readme)
# Out:
# 218

# %% [markdown]
# ### Fig 17-1

# %%
f = "fig1_coal"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-da203fef64cf410981cf7e5db115ad0d"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-da203fef64cf410981cf7e5db115ad0d");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}}, "data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/what-are-the-long-term-economic-effects-of-air-pollution/data/fig1_coal.csv"}, "mark": {"type": "area", "color": {"gradient": "linear", "stops": [{"color": "white", "offset": 0}, {"color": "#122B39", "offset": 0.7}], "x1": 0.8, "x2": 0, "y1": 0.8, "y2": 0}, "fillOpacity": 0.7, "interpolate": "monotone", "line": {"color": "#122B39"}}, "encoding": {"x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 5, "title": "", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86"}, "field": "year"}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": true, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 4, "ticks": false, "title": "million tons", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": 25, "titleY": 22}, "field": "coal"}}, "height": 300, "title": {"text": "Coal consumption, 1750-2000", "align": "left", "anchor": "start", "dx": 5, "fontSize": 12, "subtitle": ["Source: Stephan Heblich, based on Warde (2007)"], "subtitleFontSize": 11, "subtitleFontStyle": "italic"}, "width": 400, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json"}, {});
# </script>

# %%
f += "_dark"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-b87294984980423da9526ca07c5253f5"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-b87294984980423da9526ca07c5253f5");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}, "background": "#122B39", "font": "Georgia"}, "data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/what-are-the-long-term-economic-effects-of-air-pollution/data/fig1_coal.csv"}, "mark": {"type": "area", "color": {"gradient": "linear", "stops": [{"color": "#122B39", "offset": 0}, {"color": "#179FDB", "offset": 0.7}], "x1": 0.8, "x2": 0, "y1": 0.8, "y2": 0}, "fillOpacity": 0.7, "interpolate": "monotone", "line": {"color": "#179FDB"}}, "encoding": {"x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "labelFontSize": 12, "orient": "bottom", "tickColor": "#676A86", "tickCount": 5, "title": "", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86", "titleFontSize": 12}, "field": "year"}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelFontSize": 12, "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 4, "ticks": false, "title": "million tons", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 12, "titleFontWeight": "normal", "titleX": 30, "titleY": 24}, "field": "coal"}}, "height": 300, "title": {"text": "Coal consumption, 1750-2000", "align": "left", "anchor": "start", "color": "#F4134D", "dx": 5, "dy": -5, "fontSize": 14, "subtitle": ["Source: Stephan Heblich, based on Warde (2007)"], "subtitleColor": "#F4134D", "subtitleFontSize": 12, "subtitleFontStyle": "italic"}, "width": 400, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json"}, {});
# </script>

# %% [markdown]
# ### Fig 17-2a

# %%
# Ordnance survey map
readme = "### Fig 17-2 Ordnance survey map\n\n"
open("README.md", "a").write(readme)
# Out:
# 34

# %% [markdown]
# ### Fig 17-3

# %%
f = "fig3_pollution"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-225b0a88920646609671ed72de804327"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-225b0a88920646609671ed72de804327");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}}, "layer": [{"mark": {"type": "line", "interpolate": "basis"}, "encoding": {"color": {"type": "nominal", "field": "year", "legend": null, "scale": {"range": ["#36B7B4", "#0063AF", "#179FDB", "#00A767", "#676A86"]}}, "x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".1f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 3, "title": "Pollution", "titleAlign": "right", "titleAnchor": "end", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleY": -15}, "field": "x"}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".1f", "grid": true, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 4, "ticks": false, "title": "Share of low-skilled workers (standardised)", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": 25, "titleY": 25}, "field": "y", "scale": {"domain": [-0.5, 0.5]}}}}, {"mark": {"type": "text", "align": "left", "dx": 5}, "encoding": {"color": {"type": "nominal", "field": "year", "legend": null, "scale": {"range": ["#36B7B4", "#0063AF", "#179FDB", "#00A767", "#676A86"]}}, "text": {"type": "nominal", "field": "year"}, "x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".1f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 3, "title": "Pollution", "titleAlign": "right", "titleAnchor": "end", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleY": -15}, "field": "x"}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".1f", "grid": true, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 4, "ticks": false, "title": "Share of low-skilled workers (standardised)", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": 25, "titleY": 25}, "field": "y", "scale": {"domain": [-0.5, 0.5]}}}, "transform": [{"filter": "datum.x>1.35"}, {"filter": "datum.year!=2011"}]}, {"mark": {"type": "text", "align": "left", "dx": 20}, "encoding": {"color": {"type": "nominal", "field": "year", "legend": null, "scale": {"range": ["#36B7B4", "#0063AF", "#179FDB", "#00A767", "#676A86"]}}, "text": {"type": "nominal", "field": "year"}, "x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".1f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 3, "title": "Pollution", "titleAlign": "right", "titleAnchor": "end", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleY": -15}, "field": "x"}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".1f", "grid": true, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 4, "ticks": false, "title": "Share of low-skilled workers (standardised)", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": 25, "titleY": 25}, "field": "y", "scale": {"domain": [-0.5, 0.5]}}}, "transform": [{"filter": "datum.x<-1.35"}, {"filter": "datum.year!=2011"}, {"filter": "datum.year!=1991"}]}, {"data": {"name": "data-e267e27f1d9cbced71b251fd7cb2277f"}, "mark": {"type": "text", "color": "#676A86"}, "encoding": {"text": {"type": "nominal", "field": "t"}, "x": {"type": "quantitativ ...
# </script>

# %%
f += "_dark"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-db4476cc3e2c44cca60c1f5acd08cda5"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-db4476cc3e2c44cca60c1f5acd08cda5");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}, "background": "#122B39", "font": "Georgia"}, "layer": [{"mark": {"type": "line", "interpolate": "basis"}, "encoding": {"color": {"type": "nominal", "field": "year", "legend": null, "scale": {"range": ["#36B7B4", "#0063AF", "#179FDB", "#00A767", "#676A86"]}}, "x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".1f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "labelFontSize": 12, "orient": "bottom", "tickColor": "#676A86", "tickCount": 3, "title": "Pollution", "titleAlign": "right", "titleAnchor": "end", "titleColor": "#676A86", "titleFontSize": 12, "titleFontWeight": "normal", "titleY": -15}, "field": "x"}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".1f", "grid": false, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelFontSize": 12, "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 4, "ticks": false, "title": "Share of low-skilled workers (standardised)", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 12, "titleFontWeight": "normal", "titleX": 27, "titleY": 27}, "field": "y", "scale": {"domain": [-0.5, 0.5]}}}}, {"mark": {"type": "text", "align": "left", "dx": 5}, "encoding": {"color": {"type": "nominal", "field": "year", "legend": null, "scale": {"range": ["#36B7B4", "#0063AF", "#179FDB", "#00A767", "#676A86"]}}, "text": {"type": "nominal", "field": "year"}, "x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".1f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "labelFontSize": 12, "orient": "bottom", "tickColor": "#676A86", "tickCount": 3, "title": "Pollution", "titleAlign": "right", "titleAnchor": "end", "titleColor": "#676A86", "titleFontSize": 12, "titleFontWeight": "normal", "titleY": -15}, "field": "x"}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".1f", "grid": false, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelFontSize": 12, "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 4, "ticks": false, "title": "Share of low-skilled workers (standardised)", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 12, "titleFontWeight": "normal", "titleX": 27, "titleY": 27}, "field": "y", "scale": {"domain": [-0.5, 0.5]}}}, "transform": [{"filter": "datum.x>1.35"}, {"filter": "datum.year!=2011"}]}, {"mark": {"type": "text", "align": "left", "dx": 20}, "encoding": {"color": {"type": "nominal", "field": "year", "legend": null, "scale": {"range": ["#36B7B4", "#0063AF", "#179FDB", "#00A767", "#676A86"]}}, "text": {"type": "nominal", "field": "year"}, "x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".1f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "labelFontSize": 12, "orient": "bottom", "tickColor": "#676A86", "tickCount": 3, "title": "Pollution", "titleAlign": "right", "titleAnchor": "end", "titleColor": "#676A86", "titleFontSize": 12, "titleFontWeight": "normal", "titleY": -15}, "field": "x"}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".1f", "grid": false, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelFontSize": 12, "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 4, "ticks": false, "title": "Share of low-skilled workers (standardised)", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 12, "titleFontWeight": "normal", "titleX": 27, "titleY": 27}, "field": "y", "scale": {"domain": [-0.5, 0.5]}}}, "transform": [{"filter": "datum.x<-1.35"}, {"filter": "datum.year!=2011"}, {"filter": "datum.year!=1991"}]}, {"data": {"name ...
# </script>

# %% [markdown]
# # Article 18

# %% [markdown]
# ## Productivity

# %%
readme = "# Article 18 \n\n## Productivity\n\n"
open("README.md", "a").write(readme)
# Out:
# 32

# %% [markdown]
# ### Fig 18-1a

# %%
# climate and productivity
# appendix table A1, available in the online version of the article.
# This should have the underlying results for fig 3a (high risk) and fig 4a (low risk)
df = pd.read_excel("raw/10694apa.xlsx")
df = df.dropna(axis=1, how="all")
for c in df.columns:
    df[c] = (
        df[c]
        .astype(str)
        .str.replace("—", "-")
        .str.replace(" ", "")
        .str.replace(" ", "")
    )
df.columns = ["temp", "l1", "o1", "l2", "o2", "l3", "o3", "o4"]
df = df.set_index("temp")
order = list(df.index[::2])[:-1]
df["columns"] = [i + j * "s" for i in list(df.index[::2]) for j in range(2)][:-1]
df["columns1"] = [j * "s" for i in list(df.index[::2]) for j in range(2)][:-1]
df["columns2"] = [i for i in list(df.index[::2]) for j in range(2)][:-1]
df["columns1"] = df["columns1"].replace("", "a")
df = (
    df.set_index(["columns2", "columns1"]).drop("columns", axis=1).stack().reset_index()
)
df.columns = ["temp", "cat", "measure", "value"]
df = df.set_index(["temp", "measure", "cat"]).unstack().dropna()["value"]
df["s"] = abs(df["s"].astype(float))
df["a"] = df["a"].astype(float)
df["a1"] = df["a"] - 2 * df["s"]
df["a2"] = df["a"] + 2 * df["s"]
df = (
    df.stack()
    .reset_index()
    .set_index(["temp", "measure", "cat"])
    .unstack()[0]
    .reset_index()
)
df = df.set_index("temp").loc[order].reset_index()

# %%
f = "fig18-1a_time-allocation"
f18_1a = eco_git_path + f + ".csv"
df.to_csv("data/" + f + ".csv")
f += local_suffix
open("visualisation/" + f + ".html", "w").write(
    vega_embed.replace(
        "JSON_PATH",
        f18_1a.replace("/data/", "/visualisation/").replace(".csv", ".json"),
    )
)
if LOCAL:
    f18_1a = df
readme = (
    "### "
    + f
    + " --- [json](visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg](visualisation/'
    + f
    + '.svg "'
    + f
    + '") [png](visualisation/'
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"](visualisation/'
    + f
    + '.svg "'
    + f
    + '")](visualisation/'
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
df.head()
# Out:
# cat temp measure       a      a1      a2       s
# 0    <30      l1   6.423 -13.277  26.123   9.850
# 1    <30      l2  14.653 -37.431  66.737  26.042
# 2    <30      l3   1.324 -32.212  34.860  16.768
# 3    <30      o1 -37.132 -46.240 -28.024   4.554
# 4    <30      o2 -47.095 -77.729 -16.461  15.317

# %%
base = alt.Chart(f18_1a).encode(
    x=alt.X(
        "temp:O",
        sort=[],
        axis=alt.Axis(
            grid=False,
            titleAlign="right",
            titleAnchor="end",
            titleFontSize=10,
            titleY=-15,
            titleFontWeight="normal",
            title="maximum temperature (°F)",
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            tickCount=5,
            orient="bottom",
            labelAngle=0,
            # zindex=1,
            # offset=-43
        ),
    )
)
line = (
    base.mark_line(color=colors["eco-mid-blue"], interpolate="basis")
    .encode(
        y=alt.Y(
            "a:Q",
            axis=alt.Axis(
                grid=True,
                title="minutes",
                titleAnchor="start",
                labelColor=colors["eco-gray"],
                titleColor=colors["eco-gray"],
                tickColor=colors["eco-gray"],
                domainColor=colors["eco-gray"],
                titleFontSize=10,
                titleFontWeight="normal",
                ticks=False,
                labelAlign="left",
                labelBaseline="middle",
                labelPadding=-5,
                labelOffset=-10,
                titleX=20,
                titleY=40,
                titleBaseline="bottom",
                titleAngle=0,
                titleAlign="left",
                tickCount=4,
                format=".0f",
            ),
            scale=alt.Scale(domain=[-120, 80]),
        )
    )
    .transform_filter('datum.measure=="l2"')
)
area = line.mark_area(
    color=colors["eco-mid-blue"], interpolate="basis", opacity=0.2
).encode(y="a1:Q", y2="a2:Q")
line2 = (
    base.mark_line(color=colors["eco-turquiose"], interpolate="basis")
    .encode(y="a:Q")
    .transform_filter('datum.measure=="o2"')
)
area2 = line2.mark_area(
    color=colors["eco-turquiose"], interpolate="basis", opacity=0.2
).encode(y="a1:Q", y2="a2:Q")
ruler = (
    base.mark_line(color=colors["eco-gray"], strokeDash=[5, 5], opacity=0.5)
    .encode(y="y:Q")
    .transform_calculate(y="0")
)
label1 = line.mark_text(
    color=colors["eco-mid-blue"], text="Labour", align="left", dx=5
).transform_filter('datum.temp==">100"')
label2 = line2.mark_text(
    color=colors["eco-turquiose"], text="Outdoor", align="left", dx=5
).transform_filter('datum.temp==">100"')
label3 = (
    line.mark_text(
        color=colors["eco-gray"], text=">38 °C", align="center", dx=7, fontSize=10
    )
    .encode(y="y:Q")
    .transform_calculate(y="-105")
    .transform_filter('datum.temp==">100"')
)
label4 = (
    line.mark_text(
        color=colors["eco-gray"], text="8-10 °C", align="center", dx=7, fontSize=10
    )
    .encode(y="y:Q")
    .transform_calculate(y="-115")
    .transform_filter('datum.temp=="46-50"')
)
label5 = (
    line.mark_text(
        color=colors["eco-gray"], text="19-21 °C", align="center", dx=7, fontSize=10
    )
    .encode(y="y:Q")
    .transform_calculate(y="-115")
    .transform_filter('datum.temp=="66-70"')
)
label6 = (
    line.mark_text(
        color=colors["eco-gray"], text="< -1 °C", align="center", dx=7, fontSize=10
    )
    .encode(y="y:Q")
    .transform_calculate(y="-115")
    .transform_filter('datum.temp=="<30"')
)
title = alt.TitleParams(
    "Temperature and time allocation",
    subtitle=["High-risk industries. Source: Zivin and Neidell (2021)"],
    anchor="start",
    align="left",
    dx=5,
    fontSize=12,
    subtitleFontSize=11,
    subtitleFontStyle="italic",
)
layer1 = (
    (
        (
            ruler
            + area
            + area2
            + line
            + line2
            + label1
            + label2
            + label3
            + label4
            + label5
            + label6
        ).properties(height=300, width=400)
    )
    .configure_view(stroke=None)
    .properties(title=title)
)
layer1.save("visualisation/" + f + ".json")
layer1.save("visualisation/" + f + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + ".svg")
open("README.md", "a").write(readme)
layer1
# Out:
# alt.LayerChart(...)

# %%
base = alt.Chart(f18_1a).encode(
    x=alt.X(
        "temp:O",
        sort=[],
        axis=alt.Axis(
            grid=False,
            titleAlign="right",
            titleAnchor="end",
            titleFontSize=12,
            labelFontSize=12,
            titleY=-17,
            titleX=420,
            titleFontWeight="normal",
            title="maximum temperature (°F)",
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            tickCount=5,
            orient="bottom",
            labelAngle=0,
            # zindex=1,
            # offset=-43
        ),
    )
)
line = (
    base.mark_line(color=colors["eco-light-blue"], interpolate="basis")
    .encode(
        y=alt.Y(
            "a:Q",
            axis=alt.Axis(
                grid=False,
                title="minutes",
                titleAnchor="start",
                labelColor=colors["eco-gray"],
                titleColor=colors["eco-gray"],
                tickColor=colors["eco-gray"],
                domainColor=colors["eco-gray"],
                titleFontSize=12,
                labelFontSize=12,
                titleFontWeight="normal",
                ticks=False,
                labelAlign="left",
                labelBaseline="middle",
                labelPadding=-5,
                labelOffset=-10,
                titleX=23,
                titleY=42,
                titleBaseline="bottom",
                titleAngle=0,
                titleAlign="left",
                tickCount=4,
                format=".0f",
            ),
            scale=alt.Scale(domain=[-120, 80]),
        )
    )
    .transform_filter('datum.measure=="l2"')
)
area = line.mark_area(
    color=colors["eco-light-blue"], interpolate="basis", opacity=0.2
).encode(y="a1:Q", y2="a2:Q")
line2 = (
    base.mark_line(color=colors["eco-turquiose"], interpolate="basis")
    .encode(y="a:Q")
    .transform_filter('datum.measure=="o2"')
)
area2 = line2.mark_area(
    color=colors["eco-turquiose"], interpolate="basis", opacity=0.2
).encode(y="a1:Q", y2="a2:Q")
ruler = (
    base.mark_line(color=colors["eco-gray"], strokeDash=[5, 5], opacity=0.5)
    .encode(y="y:Q")
    .transform_calculate(y="0")
)
label1 = line.mark_text(
    color=colors["eco-light-blue"], text="Labour", align="left", dx=5
).transform_filter('datum.temp==">100"')
label2 = line2.mark_text(
    color=colors["eco-turquiose"], text="Outdoor", align="left", dx=5
).transform_filter('datum.temp==">100"')
label3 = (
    line.mark_text(
        color=colors["eco-gray"], text=">38 °C", align="center", dx=7, fontSize=12
    )
    .encode(y="y:Q")
    .transform_calculate(y="-102")
    .transform_filter('datum.temp==">100"')
)
label4 = (
    line.mark_text(
        color=colors["eco-gray"], text="8-10 °C", align="center", dx=7, fontSize=12
    )
    .encode(y="y:Q")
    .transform_calculate(y="-112")
    .transform_filter('datum.temp=="46-50"')
)
label5 = (
    line.mark_text(
        color=colors["eco-gray"], text="19-21 °C", align="center", dx=7, fontSize=12
    )
    .encode(y="y:Q")
    .transform_calculate(y="-112")
    .transform_filter('datum.temp=="66-70"')
)
label6 = (
    line.mark_text(
        color=colors["eco-gray"], text="< -1 °C", align="center", dx=7, fontSize=12
    )
    .encode(y="y:Q")
    .transform_calculate(y="-112")
    .transform_filter('datum.temp=="<30"')
)
title = alt.TitleParams(
    "Temperature and time allocation",
    subtitle=["High-risk industries. Source: Zivin and Neidell (2021)"],
    anchor="start",
    align="left",
    dx=5,
    fontSize=14,
    subtitleFontSize=12,
    color=colors["eco-dot"],
    subtitleColor=colors["eco-dot"],
    subtitleFontStyle="italic",
)
layer1 = (
    (
        (
            ruler
            + area
            + area2
            + line
            + line2
            + label1
            + label2
            + label3
            + label4
            + label5
            + label6
        ).properties(height=300, width=400)
    )
    .configure(font="Georgia", background=colors["eco-background"])
    .configure_view(stroke=None)
    .properties(title=title)
)
layer1.save("visualisation/" + f + "_dark.json")
layer1.save("visualisation/" + f + "_dark.png", scale_factor=2.0)
layer1.save("visualisation/" + f + "_dark.svg")
readme = re.sub(f, f + "_dark", readme)
open("README.md", "a").write(readme)
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Fig 18-1b

# %%
f = "fig18-1b_time-allocation-b"
f18_1b = eco_git_path + f + ".csv"
df.to_csv("data/" + f + ".csv")
f += local_suffix
open("visualisation/" + f + ".html", "w").write(
    vega_embed.replace(
        "JSON_PATH",
        f18_1b.replace("/data/", "/visualisation/").replace(".csv", ".json"),
    )
)
if LOCAL:
    f18_1b = df
readme = (
    "### "
    + f
    + " --- [json](visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg](visualisation/'
    + f
    + '.svg "'
    + f
    + '") [png](visualisation/'
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"](visualisation/'
    + f
    + '.svg "'
    + f
    + '")](visualisation/'
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
df.head()
# Out:
# cat temp measure       a      a1      a2       s
# 0    <30      l1   6.423 -13.277  26.123   9.850
# 1    <30      l2  14.653 -37.431  66.737  26.042
# 2    <30      l3   1.324 -32.212  34.860  16.768
# 3    <30      o1 -37.132 -46.240 -28.024   4.554
# 4    <30      o2 -47.095 -77.729 -16.461  15.317

# %%
base = alt.Chart(f18_1b).encode(
    x=alt.X(
        "temp:O",
        sort=[],
        axis=alt.Axis(
            grid=False,
            titleAlign="right",
            titleAnchor="end",
            titleFontSize=10,
            titleY=-15,
            titleFontWeight="normal",
            title="maximum temperature (°F)",
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            tickCount=5,
            orient="bottom",
            labelAngle=0,
            # zindex=1,
            # offset=-43
        ),
    )
)
line = (
    base.mark_line(color=colors["eco-mid-blue"], interpolate="basis")
    .encode(
        y=alt.Y(
            "a:Q",
            axis=alt.Axis(
                grid=True,
                title="minutes",
                titleAnchor="start",
                labelColor=colors["eco-gray"],
                titleColor=colors["eco-gray"],
                tickColor=colors["eco-gray"],
                domainColor=colors["eco-gray"],
                titleFontSize=10,
                titleFontWeight="normal",
                ticks=False,
                labelAlign="left",
                labelBaseline="middle",
                labelPadding=-5,
                labelOffset=-10,
                titleX=20,
                titleY=40,
                titleBaseline="bottom",
                titleAngle=0,
                titleAlign="left",
                tickCount=4,
                format=".0f",
            ),
            scale=alt.Scale(domain=[-120, 80]),
        )
    )
    .transform_filter('datum.measure=="l3"')
)
area = line.mark_area(
    color=colors["eco-mid-blue"], interpolate="basis", opacity=0.2
).encode(y="a1:Q", y2="a2:Q")
line2 = (
    base.mark_line(color=colors["eco-turquiose"], interpolate="basis")
    .encode(y="a:Q")
    .transform_filter('datum.measure=="o3"')
)
area2 = line2.mark_area(
    color=colors["eco-turquiose"], interpolate="basis", opacity=0.2
).encode(y="a1:Q", y2="a2:Q")
ruler = (
    base.mark_line(color=colors["eco-gray"], strokeDash=[5, 5], opacity=0.5)
    .encode(y="y:Q")
    .transform_calculate(y="0")
)
label1 = line.mark_text(
    color=colors["eco-mid-blue"], text="Labour", align="left", dx=5
).transform_filter('datum.temp==">100"')
label2 = line2.mark_text(
    color=colors["eco-turquiose"], text="Outdoor", align="left", dx=5
).transform_filter('datum.temp==">100"')
label3 = (
    line.mark_text(
        color=colors["eco-gray"], text=">38 °C", align="center", dx=7, fontSize=10
    )
    .encode(y="y:Q")
    .transform_calculate(y="-105")
    .transform_filter('datum.temp==">100"')
)
label4 = (
    line.mark_text(
        color=colors["eco-gray"], text="8-10 °C", align="center", dx=7, fontSize=10
    )
    .encode(y="y:Q")
    .transform_calculate(y="-115")
    .transform_filter('datum.temp=="46-50"')
)
label5 = (
    line.mark_text(
        color=colors["eco-gray"], text="19-21 °C", align="center", dx=7, fontSize=10
    )
    .encode(y="y:Q")
    .transform_calculate(y="-115")
    .transform_filter('datum.temp=="66-70"')
)
label6 = (
    line.mark_text(
        color=colors["eco-gray"], text="< -1 °C", align="center", dx=7, fontSize=10
    )
    .encode(y="y:Q")
    .transform_calculate(y="-115")
    .transform_filter('datum.temp=="<30"')
)
title = alt.TitleParams(
    "Temperature and time allocation",
    subtitle=["Low-risk industries. Source: Zivin and Neidell (2021)"],
    anchor="start",
    align="left",
    dx=5,
    fontSize=12,
    subtitleFontSize=11,
    subtitleFontStyle="italic",
)
layer1 = (
    (
        (
            ruler
            + area
            + area2
            + line
            + line2
            + label1
            + label2
            + label3
            + label4
            + label5
            + label6
        ).properties(height=300, width=400)
    )
    .configure_view(stroke=None)
    .properties(title=title)
)
layer1.save("visualisation/" + f + ".json")
layer1.save("visualisation/" + f + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + ".svg")
open("README.md", "a").write(readme)
layer1
# Out:
# alt.LayerChart(...)

# %%
base = alt.Chart(f18_1b).encode(
    x=alt.X(
        "temp:O",
        sort=[],
        axis=alt.Axis(
            grid=False,
            titleAlign="right",
            titleAnchor="end",
            titleFontSize=12,
            labelFontSize=12,
            titleY=-17,
            titleX=420,
            titleFontWeight="normal",
            title="maximum temperature (°F)",
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            tickCount=5,
            orient="bottom",
            labelAngle=0,
            # zindex=1,
            # offset=-43
        ),
    )
)
line = (
    base.mark_line(color=colors["eco-light-blue"], interpolate="basis")
    .encode(
        y=alt.Y(
            "a:Q",
            axis=alt.Axis(
                grid=False,
                title="minutes",
                titleAnchor="start",
                labelColor=colors["eco-gray"],
                titleColor=colors["eco-gray"],
                tickColor=colors["eco-gray"],
                domainColor=colors["eco-gray"],
                titleFontSize=12,
                labelFontSize=12,
                titleFontWeight="normal",
                ticks=False,
                labelAlign="left",
                labelBaseline="middle",
                labelPadding=-5,
                labelOffset=-10,
                titleX=23,
                titleY=42,
                titleBaseline="bottom",
                titleAngle=0,
                titleAlign="left",
                tickCount=4,
                format=".0f",
            ),
            scale=alt.Scale(domain=[-120, 80]),
        )
    )
    .transform_filter('datum.measure=="l3"')
)
area = line.mark_area(
    color=colors["eco-light-blue"], interpolate="basis", opacity=0.2
).encode(y="a1:Q", y2="a2:Q")
line2 = (
    base.mark_line(color=colors["eco-turquiose"], interpolate="basis")
    .encode(y="a:Q")
    .transform_filter('datum.measure=="o3"')
)
area2 = line2.mark_area(
    color=colors["eco-turquiose"], interpolate="basis", opacity=0.2
).encode(y="a1:Q", y2="a2:Q")
ruler = (
    base.mark_line(color=colors["eco-gray"], strokeDash=[5, 5], opacity=0.5)
    .encode(y="y:Q")
    .transform_calculate(y="0")
)
label1 = line.mark_text(
    color=colors["eco-light-blue"], text="Labour", align="left", dx=5
).transform_filter('datum.temp==">100"')
label2 = line2.mark_text(
    color=colors["eco-turquiose"], text="Outdoor", align="left", dx=5
).transform_filter('datum.temp==">100"')
label3 = (
    line.mark_text(
        color=colors["eco-gray"], text=">38 °C", align="center", dx=7, fontSize=12
    )
    .encode(y="y:Q")
    .transform_calculate(y="-102")
    .transform_filter('datum.temp==">100"')
)
label4 = (
    line.mark_text(
        color=colors["eco-gray"], text="8-10 °C", align="center", dx=7, fontSize=12
    )
    .encode(y="y:Q")
    .transform_calculate(y="-112")
    .transform_filter('datum.temp=="46-50"')
)
label5 = (
    line.mark_text(
        color=colors["eco-gray"], text="19-21 °C", align="center", dx=7, fontSize=12
    )
    .encode(y="y:Q")
    .transform_calculate(y="-112")
    .transform_filter('datum.temp=="66-70"')
)
label6 = (
    line.mark_text(
        color=colors["eco-gray"], text="< -1 °C", align="center", dx=7, fontSize=12
    )
    .encode(y="y:Q")
    .transform_calculate(y="-112")
    .transform_filter('datum.temp=="<30"')
)
title = alt.TitleParams(
    "Temperature and time allocation",
    subtitle=["Low-risk industries. Source: Zivin and Neidell (2021)"],
    anchor="start",
    align="left",
    dx=5,
    fontSize=14,
    subtitleFontSize=12,
    color=colors["eco-dot"],
    subtitleColor=colors["eco-dot"],
    subtitleFontStyle="italic",
)
layer1 = (
    (
        (
            ruler
            + area
            + area2
            + line
            + line2
            + label1
            + label2
            + label3
            + label4
            + label5
            + label6
        ).properties(height=300, width=400)
    )
    .configure(font="Georgia", background=colors["eco-background"])
    .configure_view(stroke=None)
    .properties(title=title)
)
layer1.save("visualisation/" + f + "_dark.json")
layer1.save("visualisation/" + f + "_dark.png", scale_factor=2.0)
layer1.save("visualisation/" + f + "_dark.svg")
readme = re.sub(f, f + "_dark", readme)
open("README.md", "a").write(readme)
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Article 19

# %% [markdown]
# ## Coal

# %%
readme = "# Article 19 \n\n## Coal\n\n"
open("README.md", "a").write(readme)
# Out:
# 24

# %%
readme = (
    "### Fig 19-1 through 4: several charts in the article, but no specs or data\n\n"
)
open("README.md", "a").write(readme)
# Out:
# 77

# %% [markdown]
# # Article 21

# %% [markdown]
# ## Inequality

# %%
readme = "# Article 21 \n\n## Inequality\n\n"
open("README.md", "a").write(readme)
# Out:
# 30

# %%
p = (
    eco_git_path.split("main")[0].replace("rawgit", "github")
    + "tree/"
    + "main"
    + "/articles/what-are-the-implications-of-decarbonisation-for-inequality/"
)
readme = "Cloned from [" + p.split("/")[-2] + "](" + p + ")\n\n"
open("README.md", "a").write(readme)
# Out:
# 224

# %% [markdown]
# ### Fig 21-1

# %%
f = "fig1_outcomes"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-175ffbd07192481da7703e013240117e"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-175ffbd07192481da7703e013240117e");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}}, "vconcat": [{"layer": [{"data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/what-are-the-implications-of-decarbonisation-for-inequality/data/fig1_outcomes.csv"}, "mark": {"type": "bar", "opacity": 0.8}, "encoding": {"color": {"type": "nominal", "field": "a", "legend": null, "scale": {"range": ["#F4134D", "#676A86", "#179FDB"]}}, "order": {"type": "nominal", "field": "a", "sort": "ascending"}, "x": {"type": "nominal", "axis": {"domainColor": "#676A86", "grid": false, "labelAlign": "left", "labelAngle": -90, "labelColor": "#ebebef", "labelFontSize": 11, "labelFontWeight": "bold", "labelLimit": 1000, "labelPadding": -10, "orient": "bottom", "tickColor": "#676A86", "tickCount": 10, "title": "", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86", "titleX": 207, "titleY": -15, "zindex": 10}, "field": "cat", "sort": []}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0%", "grid": false, "labelColor": "#676A86", "tickColor": "#676A86", "title": "% of total evaluations", "titleAlign": "left", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleX": -5, "titleY": -5}, "field": "value", "sort": ["neg", "m", "pos"], "stack": true}}, "transform": [{"filter": "datum.subcat==\"Distributional outcomes\""}, {"filter": "datum.a!=\"total\""}]}, {"data": {"name": "data-bdea987054261dad9a2a17288646f178"}, "mark": {"type": "text", "angle": 270, "color": "#F4134D"}, "encoding": {"text": {"type": "nominal", "field": "t"}, "x": {"type": "nominal", "field": "x", "sort": []}, "y": {"type": "quantitative", "field": "y", "sort": [], "stack": false}}}, {"data": {"name": "data-8953675a7af9ba5c58c41e09bd1ba6d1"}, "mark": {"type": "text", "angle": 270, "color": "#676A86"}, "encoding": {"text": {"type": "nominal", "field": "t"}, "x": {"type": "nominal", "field": "x", "sort": []}, "y": {"type": "quantitative", "field": "y", "sort": [], "stack": false}}}, {"data": {"name": "data-f472f3ab2e0f841220d1f81831147e33"}, "mark": {"type": "text", "angle": 270, "color": "#179FDB"}, "encoding": {"text": {"type": "nominal", "field": "t"}, "x": {"type": "nominal", "field": "x", "sort": []}, "y": {"type": "quantitative", "field": "y", "sort": [], "stack": false}}}], "height": 250, "width": 400}, {"layer": [{"mark": {"type": "line", "color": "#36B7B4"}, "encoding": {"x": {"type": "nominal", "axis": {"domain": false, "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelFontSize": 0, "orient": "top", "tickColor": "#ffffff", "title": ""}, "field": "cat"}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelColor": "#676A86", "tickColor": "#676A86", "title": "Number of total evaluations", "titleAlign": "left", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleX": 5, "titleY": 13}, "field": "value", "sort": ["neg", "m", "pos"], "stack": true}}, "transform": [{"filter": "datum.subcat==\"Distributional outcomes\""}, {"filter": "datum.a==\"total\""}]}, {"mark": {"type": "point", "color": "#36B7B4", "fill": "#36B7B4"}, "encoding": {"x": {"type": "nominal", "axis": {"domain": false, "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelFontSize": 0, "orient": "top", "tickColor": "#ffffff", "title": ""}, "field": "cat"}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelColor": "#676A86", "tickColor": "#676A86", "title": "Number of total evaluations", "titleAlign": "left", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleX": 5, "titleY": 13}, "field": "value", "sort": ["neg", "m", "pos"], "stack": true}}, "transform": [{"filter": "datum.subcat==\"Distributional outcomes\""}, {"filter": "datum.a==\"total\""}]}, {"data": {"name": "data-42732b1bd5907d ...
# </script>

# %%
f += "_dark"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-a03ab24533814e6991bab73c642cb194"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-a03ab24533814e6991bab73c642cb194");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}, "axisXQuantitative": {"labelFontSize": 12}, "axisYQuantitative": {"labelFontSize": 12}, "background": "#122B39", "font": "Georgia"}, "vconcat": [{"layer": [{"data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/what-are-the-implications-of-decarbonisation-for-inequality/data/fig1_outcomes.csv"}, "mark": {"type": "bar", "opacity": 0.8}, "encoding": {"color": {"type": "nominal", "field": "a", "legend": null, "scale": {"range": ["#F4134D", "#676A86", "#179FDB"]}}, "order": {"type": "nominal", "field": "a", "sort": "ascending"}, "x": {"type": "nominal", "axis": {"domainColor": "#676A86", "grid": false, "labelAlign": "left", "labelAngle": -90, "labelColor": "#b5b7c6", "labelFontSize": 11, "labelFontWeight": "bold", "labelLimit": 1000, "labelPadding": -10, "orient": "bottom", "tickColor": "#676A86", "tickCount": 10, "title": "", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86", "titleX": 207, "titleY": -15, "zindex": 10}, "field": "cat", "sort": []}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0%", "grid": false, "labelColor": "#676A86", "tickColor": "#676A86", "title": "% of total evaluations", "titleAlign": "left", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleX": -5, "titleY": -5}, "field": "value", "sort": ["neg", "m", "pos"], "stack": true}}, "transform": [{"filter": "datum.subcat==\"Distributional outcomes\""}, {"filter": "datum.a!=\"total\""}]}, {"data": {"name": "data-bdea987054261dad9a2a17288646f178"}, "mark": {"type": "text", "angle": 270, "color": "#F4134D"}, "encoding": {"text": {"type": "nominal", "field": "t"}, "x": {"type": "nominal", "field": "x", "sort": []}, "y": {"type": "quantitative", "field": "y", "sort": [], "stack": false}}}, {"data": {"name": "data-8953675a7af9ba5c58c41e09bd1ba6d1"}, "mark": {"type": "text", "angle": 270, "color": "#676A86"}, "encoding": {"text": {"type": "nominal", "field": "t"}, "x": {"type": "nominal", "field": "x", "sort": []}, "y": {"type": "quantitative", "field": "y", "sort": [], "stack": false}}}, {"data": {"name": "data-f472f3ab2e0f841220d1f81831147e33"}, "mark": {"type": "text", "angle": 270, "color": "#179FDB"}, "encoding": {"text": {"type": "nominal", "field": "t"}, "x": {"type": "nominal", "field": "x", "sort": []}, "y": {"type": "quantitative", "field": "y", "sort": [], "stack": false}}}], "height": 250, "width": 400}, {"layer": [{"mark": {"type": "line", "color": "#36B7B4"}, "encoding": {"x": {"type": "nominal", "axis": {"domain": false, "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelFontSize": 0, "orient": "top", "tickColor": "#122B39", "title": ""}, "field": "cat"}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelColor": "#676A86", "tickColor": "#676A86", "title": "Number of total evaluations", "titleAlign": "left", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleX": 5, "titleY": 13}, "field": "value", "sort": ["neg", "m", "pos"], "stack": true}}, "transform": [{"filter": "datum.subcat==\"Distributional outcomes\""}, {"filter": "datum.a==\"total\""}]}, {"mark": {"type": "point", "color": "#36B7B4", "fill": "#36B7B4"}, "encoding": {"x": {"type": "nominal", "axis": {"domain": false, "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelFontSize": 0, "orient": "top", "tickColor": "#122B39", "title": ""}, "field": "cat"}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelColor": "#676A86", "tickColor": "#676A86", "title": "Number of total evaluations", "titleAlign": "left", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleX": 5, "titleY": 13}, "field": "value", "sort": ["neg", "m", "pos"], "stack": true}}, "transform":  ...
# </script>

# %% [markdown]
# ### Fig 21-2

# %%
# polar chart
readme = "### Fig 21-2 polar chart\n\n"
open("README.md", "a").write(readme)
# Out:
# 26

# %%
f = "fig2_polar"
readme = (
    "### "
    + f
    + " --- [pdf]("
    + p
    + "visualisation/"
    + f
    + '.pdf "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-65148bc4f6e0> in <module>
#       4     + f
#       5     + " --- [pdf]("
# ----> 6     + p
#       7     + "visualisation/"
#       8     + f
#
# NameError: name 'p' is not defined

# %% [markdown]
# # Article 22

# %% [markdown]
# ## Agriculture

# %%
readme = "# Article 22 \n\n## Agriculture\n\n"
open("README.md", "a").write(readme)
# Out:
# 31

# %%
p = (
    eco_git_path.split("main")[0].replace("rawgit", "github")
    + "tree/"
    + "main"
    + "/articles/how-are-agricultural-economies-affected-by-climate-change/"
)
readme = "Cloned from [" + p.split("/")[-2] + "](" + p + ")\n\n"
open("README.md", "a").write(readme)
# Out:
# 220

# %% [markdown]
# ### Fig 22-1

# %%
f = "fig1_productivity"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-9c0dc8a7b9b142fabb07caf52470e41a"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-9c0dc8a7b9b142fabb07caf52470e41a");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}}, "vconcat": [{"layer": [{"mark": {"type": "line", "color": "#676A86", "opacity": 0.5}, "encoding": {"x": {"type": "nominal", "axis": {"domainColor": "#676A86", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 7, "title": "Temperature bin (\u00b0C)", "titleAlign": "right", "titleAnchor": "end", "titleColor": "#676A86", "titleY": -15}, "field": "x", "sort": []}, "y": {"type": "quantitative", "field": "z"}}}, {"mark": {"type": "area", "color": "#36B7B4", "opacity": 0.2}, "encoding": {"x": {"type": "nominal", "axis": {"domainColor": "#676A86", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 7, "title": "Temperature bin (\u00b0C)", "titleAlign": "right", "titleAnchor": "end", "titleColor": "#676A86", "titleY": -15}, "field": "x", "sort": []}, "y": {"type": "quantitative", "field": "bottom"}, "y2": {"field": "top"}}}, {"mark": {"type": "line", "color": "#36B7B4"}, "encoding": {"x": {"type": "nominal", "axis": {"domainColor": "#676A86", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 7, "title": "Temperature bin (\u00b0C)", "titleAlign": "right", "titleAnchor": "end", "titleColor": "#676A86", "titleY": -15}, "field": "x", "sort": []}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".1f", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 7, "ticks": false, "title": "", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": 22, "titleY": 7}, "field": "a", "scale": {"domain": [-3.0, 1]}, "sort": []}}}], "height": 300, "width": 400}, {"mark": {"type": "bar", "color": "#179FDB", "opacity": 0.5, "width": 20}, "encoding": {"x": {"type": "nominal", "axis": {"domainColor": "#676A86", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 7, "title": "", "titleAlign": "right", "titleAnchor": "end", "titleColor": "#676A86", "titleY": -15}, "field": "x", "sort": []}, "y": {"type": "quantitative", "axis": null, "field": "bin"}}, "height": 50, "width": 400}], "data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/how-are-agricultural-economies-affected-by-climate-change/data/fig1_productivity.csv"}, "title": {"text": "Change in productivity at different temperatures", "align": "left", "anchor": "start", "dx": 5, "dy": -5, "fontSize": 12, "subtitle": ["Change in output per ha."], "subtitleFontSize": 11, "subtitleFontStyle": "italic"}, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json"}, {});
# </script>

# %%
f += "_dark"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-8436f5b230274c878dd9dc71291277ef"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-8436f5b230274c878dd9dc71291277ef");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}, "axisXQuantitative": {"labelFontSize": 12}, "axisYQuantitative": {"labelFontSize": 12}, "background": "#122B39", "font": "Georgia"}, "vconcat": [{"layer": [{"mark": {"type": "line", "color": "#676A86", "opacity": 0.5}, "encoding": {"x": {"type": "nominal", "axis": {"domainColor": "#676A86", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 7, "title": "Temperature bin (\u00b0C)", "titleAlign": "right", "titleAnchor": "end", "titleColor": "#676A86", "titleY": -15}, "field": "x", "sort": []}, "y": {"type": "quantitative", "field": "z"}}}, {"mark": {"type": "area", "color": "#36B7B4", "opacity": 0.2}, "encoding": {"x": {"type": "nominal", "axis": {"domainColor": "#676A86", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 7, "title": "Temperature bin (\u00b0C)", "titleAlign": "right", "titleAnchor": "end", "titleColor": "#676A86", "titleY": -15}, "field": "x", "sort": []}, "y": {"type": "quantitative", "field": "bottom"}, "y2": {"field": "top"}}}, {"mark": {"type": "line", "color": "#36B7B4"}, "encoding": {"x": {"type": "nominal", "axis": {"domainColor": "#676A86", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 7, "title": "Temperature bin (\u00b0C)", "titleAlign": "right", "titleAnchor": "end", "titleColor": "#676A86", "titleY": -15}, "field": "x", "sort": []}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".1f", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 7, "ticks": false, "title": "", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": 22, "titleY": 7}, "field": "a", "scale": {"domain": [-3.0, 1]}, "sort": []}}}], "height": 300, "width": 400}, {"mark": {"type": "bar", "color": "#179FDB", "opacity": 0.5, "width": 20}, "encoding": {"x": {"type": "nominal", "axis": {"domainColor": "#676A86", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 7, "title": "", "titleAlign": "right", "titleAnchor": "end", "titleColor": "#676A86", "titleY": -15}, "field": "x", "sort": []}, "y": {"type": "quantitative", "axis": null, "field": "bin"}}, "height": 50, "width": 400}], "data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/how-are-agricultural-economies-affected-by-climate-change/data/fig1_productivity.csv"}, "title": {"text": "Change in productivity at different temperatures", "align": "left", "anchor": "start", "color": "#F4134D", "dx": 5, "dy": -7, "fontSize": 14, "subtitle": ["Change in output per ha."], "subtitleColor": "#F4134D", "subtitleFontSize": 12, "subtitleFontStyle": "italic"}, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json"}, {});
# </script>

# %% [markdown]
# ### Fig 22-2

# %%
f = "fig2_yield"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-c96fe769e3914b1b86c25c1fb4dceb13"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-c96fe769e3914b1b86c25c1fb4dceb13");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}}, "layer": [{"mark": {"type": "line", "color": "#676A86", "opacity": 0.5}, "encoding": {"x": {"type": "nominal", "axis": {"domainColor": "#676A86", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 7, "title": "Temperature (\u00b0C)", "titleAlign": "right", "titleAnchor": "end", "titleColor": "#676A86", "titleY": -15}, "field": "x", "sort": []}, "y": {"type": "quantitative", "field": "z"}}}, {"mark": {"type": "area", "color": "#36B7B4", "opacity": 0.2}, "encoding": {"x": {"type": "nominal", "axis": {"domainColor": "#676A86", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 7, "title": "Temperature (\u00b0C)", "titleAlign": "right", "titleAnchor": "end", "titleColor": "#676A86", "titleY": -15}, "field": "x", "sort": []}, "y": {"type": "quantitative", "field": "bottom"}, "y2": {"field": "top"}}}, {"mark": {"type": "line", "color": "#36B7B4"}, "encoding": {"x": {"type": "nominal", "axis": {"domainColor": "#676A86", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 7, "title": "Temperature (\u00b0C)", "titleAlign": "right", "titleAnchor": "end", "titleColor": "#676A86", "titleY": -15}, "field": "x", "sort": []}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".2f", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 4, "ticks": false, "title": "log-yield (bu per hectare)", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": 30, "titleY": 35}, "field": "a", "sort": []}}}], "data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/how-are-agricultural-economies-affected-by-climate-change/data/fig2_yield.csv"}, "height": 300, "title": {"text": "Effects of temperature on wheat yields", "align": "left", "anchor": "start", "dx": 5, "dy": -5, "fontSize": 12, "subtitle": ["Data from South Africa. Source: Shew et al. (2020)"], "subtitleFontSize": 11, "subtitleFontStyle": "italic"}, "width": 400, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json"}, {});
# </script>

# %%
f += "_dark"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-5afeb70df4b243669b60912dede50fb4"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-5afeb70df4b243669b60912dede50fb4");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}, "axisXQuantitative": {"labelFontSize": 12}, "axisYQuantitative": {"labelFontSize": 12}, "background": "#122B39", "font": "Georgia"}, "layer": [{"mark": {"type": "line", "color": "#676A86", "opacity": 0.5}, "encoding": {"x": {"type": "nominal", "axis": {"domainColor": "#676A86", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 7, "title": "Temperature (\u00b0C)", "titleAlign": "right", "titleAnchor": "end", "titleColor": "#676A86", "titleY": -15}, "field": "x", "sort": []}, "y": {"type": "quantitative", "field": "z"}}}, {"mark": {"type": "area", "color": "#36B7B4", "opacity": 0.2}, "encoding": {"x": {"type": "nominal", "axis": {"domainColor": "#676A86", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 7, "title": "Temperature (\u00b0C)", "titleAlign": "right", "titleAnchor": "end", "titleColor": "#676A86", "titleY": -15}, "field": "x", "sort": []}, "y": {"type": "quantitative", "field": "bottom"}, "y2": {"field": "top"}}}, {"mark": {"type": "line", "color": "#36B7B4"}, "encoding": {"x": {"type": "nominal", "axis": {"domainColor": "#676A86", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 7, "title": "Temperature (\u00b0C)", "titleAlign": "right", "titleAnchor": "end", "titleColor": "#676A86", "titleY": -15}, "field": "x", "sort": []}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".2f", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 4, "ticks": false, "title": "log-yield (bu per hectare)", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 12, "titleFontWeight": "normal", "titleX": 33, "titleY": 40}, "field": "a", "sort": []}}}], "data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/how-are-agricultural-economies-affected-by-climate-change/data/fig2_yield.csv"}, "height": 300, "title": {"text": "Effects of temperature on wheat yields", "align": "left", "anchor": "start", "color": "#F4134D", "dx": 5, "dy": -7, "fontSize": 14, "subtitle": ["Data from South Africa. Source: Shew et al. (2020)"], "subtitleColor": "#F4134D", "subtitleFontSize": 12, "subtitleFontStyle": "italic"}, "width": 400, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json"}, {});
# </script>

# %% [markdown]
# ### Fig 22-3

# %%
f = "fig3_africa"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-c29f6a5553b9400c85e9041889398a09"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-c29f6a5553b9400c85e9041889398a09");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}}, "layer": [{"mark": {"type": "bar", "color": "#F4134D"}, "encoding": {"x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 7, "title": "", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86"}, "field": "Year", "scale": {"domain": [1896, 2025], "nice": false}, "sort": []}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".1f", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 7, "ticks": false, "title": "\u00b0C", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 10, "titleFontWeight": "normal", "titleX": 22, "titleY": 7}, "field": "Value", "sort": []}}, "transform": [{"filter": "datum.Value>0"}]}, {"mark": {"type": "bar", "color": "#179FDB"}, "encoding": {"x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 7, "title": "", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86"}, "field": "Year", "scale": {"domain": [1896, 2025], "nice": false}, "sort": []}, "y": {"type": "quantitative", "field": "Value", "sort": []}}, "transform": [{"filter": "datum.Value<0"}]}, {"data": {"name": "data-3ed4290038625a794a396d8e8be775be"}, "mark": {"type": "line", "color": "#676A86"}, "encoding": {"x": {"type": "quantitative", "field": "x", "sort": []}, "y": {"type": "quantitative", "field": "y"}}}, {"data": {"name": "data-3c9914816ad3e12cde86ac1bacb47d4a"}, "mark": {"type": "text", "align": "right", "baseline": "top", "color": "#676A86", "dy": 5}, "encoding": {"text": {"type": "nominal", "field": "t"}, "x": {"type": "quantitative", "field": "x"}, "y": {"type": "quantitative", "field": "y"}}}], "data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/how-are-agricultural-economies-affected-by-climate-change/data/fig3_africa.csv"}, "height": 300, "title": {"text": "Temperature anomaly in Africa", "align": "left", "anchor": "start", "dx": 5, "dy": -5, "fontSize": 12, "subtitle": ["January-December temperatures compared to the 20th century average. Source: NOAA"], "subtitleFontSize": 11, "subtitleFontStyle": "italic"}, "width": 400, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-3ed4290038625a794a396d8e8be775be": [{"x": 1895, "y": 0}, {"x": 2025, "y": 0}], "data-3c9914816ad3e12cde86ac1bacb47d4a": [{"x": 2025, "y": 0, "t": "20th century average"}]}}, {});
# </script>

# %%
f += "_dark"
readme = (
    "### "
    + f
    + " --- [json]("
    + p
    + "visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '") [png]('
    + p
    + "visualisation/"
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")]('
    + p
    + "visualisation/"
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
open("README.md", "a").write(readme)
altair_viewer.display(
    json.loads(requests.get(p + "visualisation/" + f + ".json").content), inline=True
)
# Out:
# <div id="altair-chart-5e1d0daa864647758c14afbce8f25f66"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt) {
#     const outputDiv = document.getElementById("altair-chart-5e1d0daa864647758c14afbce8f25f66");
#     const urls = {
#       "vega": "http://localhost:16195/scripts/vega.js",
#       "vega-lite": "http://localhost:16195/scripts/vega-lite.js",
#       "vega-embed": "http://localhost:16195/scripts/vega-embed.js",
#     };
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = urls[lib];
#         s.async = true;
#         s.onload = () => resolve(urls[lib]);
#         s.onerror = () => reject(`Error loading script: ${urls[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#         // requirejs paths need '.js' extension stripped.
#         const paths = Object.keys(urls).reduce(function(paths, package) {
#             paths[package] = urls[package].replace(/\.js$/, "");
#             return paths
#         }, {})
#         requirejs.config({paths});
#         require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#         displayChart(vegaEmbed);
#     } else {
#         loadScript("vega")
#             .then(() => loadScript("vega-lite"))
#             .then(() => loadScript("vega-embed"))
#             .catch(showError)
#             .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 400, "continuousHeight": 300, "stroke": null}, "axisXQuantitative": {"labelFontSize": 12}, "axisYQuantitative": {"labelFontSize": 12}, "background": "#122B39", "font": "Georgia"}, "layer": [{"mark": {"type": "bar", "color": "#F4134D"}, "encoding": {"x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 7, "title": "", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86"}, "field": "Year", "scale": {"domain": [1896, 2025], "nice": false}, "sort": []}, "y": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".1f", "grid": true, "gridColor": "#676A86", "gridOpacity": 0.1, "labelAlign": "left", "labelBaseline": "middle", "labelColor": "#676A86", "labelOffset": -10, "labelPadding": -5, "tickColor": "#676A86", "tickCount": 7, "ticks": false, "title": "\u00b0C", "titleAlign": "left", "titleAnchor": "start", "titleAngle": 0, "titleBaseline": "bottom", "titleColor": "#676A86", "titleFontSize": 12, "titleFontWeight": "normal", "titleX": 25, "titleY": 12}, "field": "Value", "sort": []}}, "transform": [{"filter": "datum.Value>0"}]}, {"mark": {"type": "bar", "color": "#179FDB"}, "encoding": {"x": {"type": "quantitative", "axis": {"domainColor": "#676A86", "format": ".0f", "grid": false, "labelAngle": 0, "labelColor": "#676A86", "orient": "bottom", "tickColor": "#676A86", "tickCount": 7, "title": "", "titleAlign": "center", "titleAnchor": "middle", "titleColor": "#676A86"}, "field": "Year", "scale": {"domain": [1896, 2025], "nice": false}, "sort": []}, "y": {"type": "quantitative", "field": "Value", "sort": []}}, "transform": [{"filter": "datum.Value<0"}]}, {"data": {"name": "data-3ed4290038625a794a396d8e8be775be"}, "mark": {"type": "line", "color": "#676A86"}, "encoding": {"x": {"type": "quantitative", "field": "x", "sort": []}, "y": {"type": "quantitative", "field": "y"}}}, {"data": {"name": "data-3c9914816ad3e12cde86ac1bacb47d4a"}, "mark": {"type": "text", "align": "right", "baseline": "top", "color": "#676A86", "dy": 5, "fontSize": 12}, "encoding": {"text": {"type": "nominal", "field": "t"}, "x": {"type": "quantitative", "field": "x"}, "y": {"type": "quantitative", "field": "y"}}}], "data": {"url": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/articles/how-are-agricultural-economies-affected-by-climate-change/data/fig3_africa.csv"}, "height": 300, "title": {"text": "Temperature anomaly in Africa", "align": "left", "anchor": "start", "color": "#F4134D", "dx": 5, "dy": -7, "fontSize": 14, "subtitle": ["January-December temperatures compared to the 20th century average. Source: NOAA"], "subtitleColor": "#F4134D", "subtitleFontSize": 12, "subtitleFontStyle": "italic"}, "width": 400, "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "datasets": {"data-3ed4290038625a794a396d8e8be775be": [{"x": 1895, "y": 0}, {"x": 2025, "y": 0}], "data-3c9914816ad3e12cde86ac1bacb47d4a": [{"x": 2025, "y": 0, "t": "20th century average"}]}}, {});
# </script>

# %% [markdown]
# ### Fig 22-4a

# %%
# map 1
readme = "### Fig 22-4a World map of warming scenario 1.5\n\n"
open("README.md", "a").write(readme)
# Out:
# 49

# %% [markdown]
# ### Fig 22-4b

# %%
# map 2
readme = "### Fig 22-4b World map of warming scenario 2\n\n"
open("README.md", "a").write(readme)
# Out:
# 47

# %% [markdown]
# # Article 23

# %% [markdown]
# ## Firms, competition

# %%
readme = "# Article 23 \n\n## Firms, competition\n\n"
open("README.md", "a").write(readme)
# Out:
# 38

# %% [markdown]
# ### Fig 23-1

# %%
df = pd.read_csv("raw/Gillingham_and_Stock_Table2.csv")

# %%
f = "fig23-1_policies"
f23_1 = eco_git_path + f + ".csv"
df.to_csv("data/" + f + ".csv")
f += local_suffix
open("visualisation/" + f + ".html", "w").write(
    vega_embed.replace(
        "JSON_PATH", f23_1.replace("/data/", "/visualisation/").replace(".csv", ".json")
    )
)
if LOCAL:
    f23_1 = df
readme = (
    "### "
    + f
    + " --- [json](visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg](visualisation/'
    + f
    + '.svg "'
    + f
    + '") [png](visualisation/'
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"](visualisation/'
    + f
    + '.svg "'
    + f
    + '")](visualisation/'
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
df.head()
# Out:
#                          Policy  Average   Min    Max
# 0  Behavioral Energy Efficiency  -190.00   NaN    NaN
# 1                 Reforestation     5.50  1.00  10.00
# 2              Clean Power Plan    11.00   NaN    NaN
# 3    Methane Flaring Regulation    20.00   NaN    NaN
# 4                        EU ETS    30.62  8.56  52.68

# %%
base = alt.Chart(f23_1).encode(y=alt.Y("Policy:N", sort=[], axis=None))
bar = base.mark_bar(color=colors["eco-turquiose"]).encode(
    x=alt.X(
        "Average:Q",
        axis=alt.Axis(
            grid=True,
            gridColor=colors["eco-gray"],
            gridOpacity=0.1,
            titleAlign="right",
            titleAnchor="end",
            title="2017 US$ / ton of CO₂",
            titleFontSize=10,
            labelFontSize=10,
            titleY=-41,
            titleFontWeight="normal",
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            tickCount=5,
            orient="bottom",
            labelAngle=0,
            # zindex=1,
            # offset=-43
        ),
        #         scale=alt.Scale(domain=[-120,80])
    )
)
labels = (
    bar.mark_text(
        color=colors["eco-turquiose"], align="right", dx=-5, baseline="middle"
    )
    .encode(text="Policy:N", x="x:Q")
    .transform_calculate(x="min(0,datum.Average)")
)
title = alt.TitleParams(
    "Cost and efficiency-based comparison of green policies",
    subtitle=[""],
    anchor="start",
    align="left",
    dx=5,
    fontSize=12,
    subtitleFontSize=11,
    subtitleFontStyle="italic",
)
layer1 = (
    ((bar + labels).properties(height=350, width=300))
    .configure_view(stroke=None)
    .properties(title=title)
)
layer1.save("visualisation/" + f + ".json")
layer1.save("visualisation/" + f + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + ".svg")
open("README.md", "a").write(readme)
layer1
# Out:
# alt.LayerChart(...)

# %%
bar.encoding.x.axis.titleFontSize = 12
bar.encoding.x.axis.titleY -= 5

theme = "_dark"
layer1 = (
    ((bar + labels).properties(height=350, width=300))
    .configure_view(stroke=None)
    .properties(title=title)
)
layer1 = layer1.configure_axisY(labelFontSize=12)
layer1 = layer1.configure_axisX(labelFontSize=12)
layer1.config.font = "Georgia"
layer1.config.background = colors["eco-background"]
layer1.config.view.stroke = None
layer1.title.fontSize = 14
layer1.title.subtitleFontSize = 12
# layer1.title.dy -= 2
layer1.title.color = colors["eco-dot"]
layer1.title.subtitleColor = colors["eco-dot"]
layer1.save("visualisation/" + f + theme + ".json")
layer1.save("visualisation/" + f + theme + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + theme + ".svg")
readme = re.sub(f, f + theme, readme)
open("README.md", "a").write(readme)
layer1
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Article 24

# %% [markdown]
# ## Public debt

# %%
readme = "# Article 24 \n\n## Public debt\n\n"
open("README.md", "a").write(readme)
# Out:
# 31

# %% [markdown]
# ### Fig 24-1

# %%
configSource = "raw/ECO2.DEBT.C1e.json"
config = json.loads(open(configSource, "r").read())
df = pd.read_csv(config["data"]["url"]).drop("Detail", axis=1)

# %%
f = "fig24-1_debt"
f24_1 = eco_git_path + f + ".csv"
df.to_csv("data/" + f + ".csv")
f += local_suffix
open("visualisation/" + f + ".html", "w").write(
    vega_embed.replace(
        "JSON_PATH", f24_1.replace("/data/", "/visualisation/").replace(".csv", ".json")
    )
)
if LOCAL:
    f24_1 = df
readme = (
    "### "
    + f
    + " --- [json](visualisation/"
    + f
    + '.json "'
    + f
    + '") [svg](visualisation/'
    + f
    + '.svg "'
    + f
    + '") [png](visualisation/'
    + f
    + '.png "'
    + f
    + '")\n[!["'
    + f
    + '"](visualisation/'
    + f
    + '.svg "'
    + f
    + '")](visualisation/'
    + f
    + '.svg "'
    + f
    + '")\n\n'
)
df.head()
# Out:
#    Year Country    Value1    Value2     Value3  Unnamed: 6  Unnamed: 7  \
# 0  2002  Canada  0.760149  0.750681  98.754443         NaN     1000.00
# 1  2003  Canada  0.895599  0.752476  84.019275         NaN         NaN
# 2  2004  Canada  1.026470  0.758597  73.903447         NaN        1.00
# 3  2005  Canada  1.173510  0.793334  67.603497         NaN        0.79
# 4  2006  Canada  1.319360  0.826672  62.657031         NaN        1.15
#
#   Unnamed: 8
# 0        NaN
# 1        NaN
# 2        USD
# 3        CAN
# 4        EUR

# %%
config = json.loads(open(configSource, "r").read())
if not LOCAL:
    config["data"]["url"] = f24_1
config["encoding"]["x"]["axis"]["grid"] = False
config["encoding"]["x"]["axis"]["labelColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["titleColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["tickColor"] = colors["eco-gray"]
config["encoding"]["x"]["axis"]["domainColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["grid"] = True
config["encoding"]["y"]["axis"]["gridColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["gridOpacity"] = 0.1
config["encoding"]["y"]["axis"]["title"] = ""
config["encoding"]["y"]["axis"]["titleAnchor"] = "start"
config["encoding"]["y"]["axis"]["labelColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["titleColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["tickColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["domainColor"] = colors["eco-gray"]
config["encoding"]["y"]["axis"]["titleFontSize"] = 10
config["encoding"]["y"]["axis"]["titleFontWeight"] = "normal"
config["encoding"]["y"]["axis"]["ticks"] = False
config["encoding"]["y"]["axis"]["labelAlign"] = "left"
config["encoding"]["y"]["axis"]["labelBaseline"] = "middle"
config["encoding"]["y"]["axis"]["labelPadding"] = -5
config["encoding"]["y"]["axis"]["labelOffset"] = -10
config["encoding"]["y"]["axis"]["titleBaseline"] = "bottom"
config["encoding"]["y"]["axis"]["titleAngle"] = 0
config["encoding"]["y"]["axis"]["titleAlign"] = "left"
config["encoding"]["y"]["axis"]["tickCount"] = 7
config["encoding"]["y"]["axis"]["titleX"] = 45
config["encoding"]["y"]["axis"]["titleY"] = -5
config["encoding"]["y"]["axis"]["format"] = ".0%"
config["encoding"]["y"]["scale"] = {"domain": [0, 3]}
config["encoding"]["y"]["field"] = "m"
config["title"]["dy"] = -5
config.pop("$schema")
config["encoding"]["color"]["legend"] = None
config["view"] = {"stroke": None}
config["width"] = 300
config["height"] = 220
base = alt.Chart.from_dict(config).transform_calculate(m="datum.Value3/100")
text = (
    base.mark_text(dx=5, align="left")
    .encode(text="Country:N")
    .transform_filter("year(datum.Year)==2020")
    .transform_filter("datum.Country!='UK'")
    .transform_filter("datum.Country!='United States'")
)
text2 = (
    base.mark_text(dx=5, dy=10, align="left")
    .encode(text="Country:N")
    .transform_filter("year(datum.Year)==2020")
    .transform_filter("datum.Country=='UK'")
)
text3 = (
    base.mark_text(dx=5, dy=-9, align="left")
    .encode(text="Country:N")
    .transform_filter("year(datum.Year)==2020")
    .transform_filter("datum.Country=='United States'")
)
layer1 = (base + text + text2 + text3).configure_view(stroke=None)
layer1.save("visualisation/" + f + ".json")
layer1.save("visualisation/" + f + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + ".svg")
open("README.md", "a").write(readme)
layer1
# altair_viewer.display(config, inline=True)
# Out:
# alt.LayerChart(...)

# %%
theme = "_dark"
base.title.fontSize = 14
base.title.subtitleFontSize = 12
base.title.dy -= 2
base.encoding.y.axis.titleY += 2
base.encoding.y.axis.titleX += 8
base.title.color = colors["eco-dot"]
base.title.subtitleColor = colors["eco-dot"]
layer1 = (base + text + text2 + text3).configure_view(stroke=None)
layer1 = layer1.configure_axisY(labelFontSize=12)
layer1 = layer1.configure_axisX(labelFontSize=12)
layer1.config.font = "Georgia"
layer1.config.background = colors["eco-background"]
layer1.config.view.stroke = None
layer1.save("visualisation/" + f + theme + ".json")
layer1.save("visualisation/" + f + theme + ".png", scale_factor=2.0)
layer1.save("visualisation/" + f + theme + ".svg")
readme = re.sub(f, f + theme, readme)
open("README.md", "a").write(readme)
layer1
# Out:
# alt.LayerChart(...)
