# %%
# !pip install altair 
# !pip install altair_saver
# !npm install -g vega-lite vega-cli canvas
# !pip install vl-convert-python

# %%
# !apt update
# !apt install ttf-mscorefonts-installer -y
# !apt reinstall fontconfig fontconfig-config libfontconfig1 -y

# %%
# !wget https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/guidelines/fonts/Circular/CircularStd-Black.otf -P /usr/local/share/fonts
# !wget https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/guidelines/fonts/Circular/CircularStd-Bold.otf -P /usr/local/share/fonts
# !wget https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/guidelines/fonts/Circular/CircularStd-Book.otf -P /usr/local/share/fonts
# !wget https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/guidelines/fonts/Circular/CircularStd-Medium.otf -P /usr/local/share/fonts

# %%
# !fc-cache -f

# %%
import json
import altair as alt
from altair import expr, datum
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import urllib.parse

# %%
import colorsys
from matplotlib.colors import to_hex, to_rgb


def scale_lightness(rgb, scale_l):
    rgbhex = False
    if "#" in rgb:
        rgb = to_rgb(rgb)
        rgbhex = True
    # convert rgb to hls
    h, l, s = colorsys.rgb_to_hls(*rgb)
    # manipulate h, l, s values and return as rgb
    c = colorsys.hls_to_rgb(h, min(1, l * scale_l), s=s)
    if rgbhex:
        c = to_hex(c)
    return c

# %%
SAVE = True
LOCAL = False

if LOCAL:
    local_suffix = "_local"
else:
    local_suffix = ""

# %%
# %%capture pwd
# !pwd

# %%
uid = pwd.stdout.split("/")[-1].split("\r")[0]
uid=urllib.parse.quote(uid)
eco_git_home = (
    "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/"
)
eco_git_path = eco_git_home + "articles/" + uid + "/data/"
vega_embed = requests.get(eco_git_home + "guidelines/html/vega-embed.html").text
colors = json.loads(
    requests.get(eco_git_home + "guidelines/colors/eco-colors.json").content
)
category_color = json.loads(
    requests.get(eco_git_home + "guidelines/colors/eco-category-color.json").content
)
hue_color = json.loads(
    requests.get(eco_git_home + "guidelines/colors/eco-single-hue-color.json").content
)
mhue_color = json.loads(
    requests.get(eco_git_home + "guidelines/colors/eco-multi-hue-color.json").content
)
div_color = json.loads(
    requests.get(eco_git_home + "guidelines/colors/eco-diverging-color.json").content
)
config = json.loads(
    requests.get(eco_git_home + "guidelines/charts/eco-global-config.json").content
)
mo=0.5
height = config["height"]
width = config["width"]
uid, height, width
# Out:
# ('war-in-ukraine-has-the-black-sea-grain-agreement-improved-global-food-security',
#  300,
#  500)

# %%
def save(df, f, LOCAL):
    fc = eco_git_path + f + ".csv"
    df.to_csv("data/" + f + ".csv")
    f += local_suffix
    open("visualisation/" + f + ".html", "w").write(
        vega_embed.replace(
            "JSON_PATH", fc.replace("/data/", "/visualisation/").replace(".csv", ".json")
        )
    )
    if LOCAL:
        fc = df
    
    from IPython.display import display, HTML
    display(HTML(df.head().to_html()))
    
    readme = "## Figure " + f.replace('fig','').split('_')[0] + \
        '  \n\nData: [`csv`](data/' + f + '.csv)' +\
        '  \nGitHub: [' + f + '](https://github.com/EconomicsObservatory/ECOvisualisations/tree/main/articles/'+uid +')'+\
        ''+\
        '  \n\n### Light theme  \n\nVersions with data locally embedded into the `Vega-lite` specification file: ' + \
        '[`png`](visualisation/' + f + '_local.png) [`svg`](visualisation/' + f + '_local.svg) [`json`](visualisation/' + f + '_local.json) '+ \
        '  \n (**Default**) Versions with data loaded from `GitHub`: ' + \
        '[`png`](visualisation/' + f + '.png) [`svg`](visualisation/' + f + '.svg) [`json`](visualisation/' + f + '.json)'+ \
        '  \nVersions (no ECO branding) with data locally embedded into the `Vega-lite` specification file: ' + \
        '[`png`](visualisation/' + f + '_local_no_branding.png) [`svg`](visualisation/' + f + '_local_no_branding.svg) [`json`](visualisation/' + f + '_local_no_branding.json) '+ \
        '  \nVersions (no ECO branding) with data loaded from `GitHub`: ' + \
        '[`png`](visualisation/' + f + '_no_branding.png) [`svg`](visualisation/' + f + '_no_branding.svg) [`json`](visualisation/' + f + '_no_branding.json) '+ \
        ''+\
        '  \n\n### Dark theme  \n\nVersions with data locally embedded into the `Vega-lite` specification file: ' + \
        '[`png`](visualisation/' + f + '_local_dark.png) [`svg`](visualisation/' + f + '_local_dark.svg) [`json`](visualisation/' + f + '_local_dark.json) '+ \
        '  \n Versions with data loaded from `GitHub`: ' + \
        '[`png`](visualisation/' + f + '_dark.png) [`svg`](visualisation/' + f + '_dark.svg) [`json`](visualisation/' + f + '_dark.json)'+ \
        '  \nVersions (no ECO branding) with data locally embedded into the `Vega-lite` specification file: ' + \
        '[`png`](visualisation/' + f + '_local_no_branding_dark.png) [`svg`](visualisation/' + f + '_local_no_branding_dark.svg) [`json`](visualisation/' + f + '_local_no_branding_dark.json) '+ \
        '  \nVersions (no ECO branding) with data loaded from `GitHub`: ' + \
        '[`png`](visualisation/' + f + '_no_branding_dark.png) [`svg`](visualisation/' + f + '_no_branding_dark.svg) [`json`](visualisation/' + f + '_no_branding_dark.json) '+ \
        ''+\
        '  \n\n!["' + f + '"](visualisation/' + f + '.png "' + f + '")\n\n' +\
        '  \n\n!["' + f + '_dark"](visualisation/' + f + '_dark.png "' + f + '")\n\n' 
    return readme, f, fc

# %%
def area(base,color,opacity=1,kind='area'):
    if kind=='area':
        return base.mark_area(opacity=opacity,
        interpolate="monotone",
        line={'color':color},
        color=alt.Gradient(
            gradient='linear',
            stops=[alt.GradientStop(color='#ffffff00', offset=0.2),
                   alt.GradientStop(color=color, offset=0.8)],
            x1=1, #0.8
            y1=1,
            x2=1,
            y2=0
            )
        )
    elif kind=='line':
        return base.mark_line(opacity=opacity,interpolate="monotone",color=color)
    elif kind=='dashed-line':
        return base.mark_line(opacity=opacity,interpolate="monotone",color=color,strokeDash=[5,5])
    else:
        print('Please specify kind...')
        return

# %%
# service_color='#d6c8da' '#e4bfe2' '#ce4b96' colors['eco-turquiose']
service_color='#b4c8d8'

def dark(f):
    # service_color='#d6c8da' '#e4bfe2' '#ce4b96' colors['eco-turquiose']
    service_color='#b4c8d8'
    configSource = "visualisation/" + f + ".json"
    config = json.loads(open(configSource, "r").read())
    config['background']=colors['eco-background']
    service_color='#b4c8d8'
    def dark_layer(config):
        def dark_color(color):
            return color.replace(colors['eco-gray'],service_color)\
                .replace(colors['eco-blue'],colors['eco-yellow'])\
                .replace(service_color,colors['eco-green'])

        for i in config['layer']:
            if 'encoding' in i:
                for x in ['x','y']:
                    if x in i['encoding']:
                        if 'axis' in i['encoding'][x]:
                            for c in ['domainColor','labelColor','tickColor','titleColor','gridColor']:
                                if 'axis' in i['encoding'][x]:
                                    if i['encoding'][x]['axis']!=None:
                                        if c in i['encoding'][x]['axis']:
                                            i['encoding'][x]['axis'][c]=service_color
            if 'mark' in i:
                if 'color' in i['mark']:
                    if i['mark']['color']==colors['eco-gray']:
                        i['mark']['color']=service_color
                    elif i['mark']['color']==colors['eco-blue']:
                        i['mark']['color']=colors['eco-yellow']
                    elif i['mark']['color']==service_color:
                        i['mark']['color']=colors['eco-green']
                    elif 'stops' in i['mark']['color']:
                        for s in i['mark']['color']['stops']:
                            if 'color' in s:
                                s['color']=dark_color(s['color'])
                if 'line' in i['mark']:
                    if type(i['mark'])==str:
                        if 'color' in i['encoding']:
                            if 'scale' in i['encoding']['color']:
                                if 'range' in i['encoding']['color']['scale']:
                                    for color in i['encoding']['color']['scale']['range']:
                                        color=dark_color(color)
                    else:
                        if 'color' in i['mark']['line']:
                            i['mark']['line']['color']=dark_color(i['mark']['line']['color'])
        return config

    if 'vconcat' in config:
        for layer in config['vconcat']:
            layer=dark_layer(layer)
    else:
        config=dark_layer(config)
    
    if 'datasets' in config:
        for i in config['datasets']:
            if 'img' in config['datasets'][i][0]:
                if 'eco-icon-dark' in config['datasets'][i][0]['img']:
                    config['datasets'][i][0]['img']=config['datasets'][i][0]['img'].replace('eco-icon-dark','eco-icon-light')
    
    return alt.Chart.from_dict(config)

# %% [markdown]
# # Fig 1

# %%
df = pd.read_csv("raw/wpd_datasets.csv",header=1)
df.index=['2022.'+str(i)+'.01' for i in range(1,13)]
df=df[['Y','Y.1','Y.2','Y.3']]
df.columns=['wheat5','corn5','wheat22','corn22']
df['wheat22']-=df['corn22']
df['wheat5']-=df['corn5'] #no stacked plots please
df=df.reset_index()

# %%
readme, f, fc = save(df,"fig1_wheat",LOCAL)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>wheat5</th>
#       <th>corn5</th>
#       <th>wheat22</th>
#       <th>corn22</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2022.1.01</td>
#       <td>0.922049</td>
#       <td>2.873051</td>
#       <td>1.109131</td>
#       <td>4.530067</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2022.2.01</td>
#       <td>0.881960</td>
#       <td>2.685969</td>
#       <td>1.042316</td>
#       <td>3.808463</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2022.3.01</td>
#       <td>1.015590</td>
#       <td>3.113586</td>
#       <td>0.307350</td>
#       <td>1.109131</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2022.4.01</td>
#       <td>1.042316</td>
#       <td>2.726058</td>
#       <td>0.133630</td>
#       <td>0.761693</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2022.5.01</td>
#       <td>1.055679</td>
#       <td>2.565702</td>
#       <td>0.080178</td>
#       <td>1.122494</td>
#     </tr>
#   </tbody>
# </table>

# %%
xmin='2022-01-01'
xmax='2022-12-01'
ymin=0
ymax=6
xaxis = alt.Chart(pd.DataFrame([{'x':xmin,'y':0},{'x':xmax,'y':0}])).mark_line(color=colors["eco-gray"],opacity=mo-0.2,strokeWidth=1).encode(
    x=alt.X(
        "x:T",
        sort=[],
        axis=alt.Axis(
            grid=False,
            titleAlign="center",
            titleAnchor="middle",
            title="",
            titleY=-15,
            titleX=207,
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            tickCount=10,
            domainOpacity=mo,
            tickOpacity=mo,
            labelOpacity=mo+0.2,
            titleOpacity=mo+0.3,
            titleFontSize=12,
            orient="bottom",
            labelAngle=0,
            format='%b'
        ),
    ),
    y=alt.Y(
        "y:Q",
        sort=[],
        axis=alt.Axis(
            # grid=False,
            gridDash=[1,5],
            gridColor=colors["eco-gray"],
            gridOpacity=mo,
            title="Metric tons (millions)",
            titleX=0,
            titleY=-7,
            titleBaseline="bottom",
            titleAngle=0,
            titleAlign="left",
            ticks=False,
            labelPadding=5,
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            domainOpacity=mo,
            tickOpacity=mo,
            labelOpacity=mo+0.2,
            titleOpacity=mo+0.3,
            titleFontSize=12,
            format='.0f',
            tickCount=8
        ),
        scale=alt.Scale(domain=[ymin, ymax],clamp=True),
    )
)

base = alt.Chart(fc).encode(x='index:T')\
    .transform_calculate(y22='toNumber(datum.wheat22)+toNumber(datum.corn22)')\
    .transform_calculate(y5='toNumber(datum.wheat5)+toNumber(datum.corn5)')
line1=area(base,colors['eco-turquiose']).encode(y='wheat22:Q')
line2=area(base,colors['eco-yellow']).encode(y='corn22:Q')
line12=area(base,colors['eco-dot'],kind='line').encode(y='y22:Q')
line3=area(base,colors['eco-turquiose'],kind='dashed-line').encode(y='wheat5:Q')
line4=area(base,colors['eco-yellow'],kind='dashed-line').encode(y='corn5:Q')
line34=area(base,colors['eco-light-blue'],kind='line').encode(y='y5:Q')
line1234=base.mark_area(interpolate="monotone",
        line={'color':color},
        color=alt.Gradient(
            gradient='linear',
            stops=[alt.GradientStop(color=colors['eco-dot'], offset=0.1),
                   alt.GradientStop(color=colors['eco-light-blue'], offset=0.9)],
            x1=1, #0.8
            y1=1,
            x2=1,
            y2=0
            )
    ).encode(
        x=alt.X(
        "index:T",
        sort=[],
        axis=alt.Axis(
            grid=False,
            titleAlign="center",
            titleAnchor="middle",
            title="",
            titleY=-15,
            titleX=207,
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            tickCount=10,
            domainOpacity=mo,
            tickOpacity=mo,
            labelOpacity=mo+0.2,
            titleOpacity=mo+0.3,
            titleFontSize=12,
            orient="bottom",
            labelAngle=0,
            format='%b'
        ),
    ),
        y=alt.Y(
        "y5:Q",
        sort=[],
        axis=alt.Axis(
            # grid=False,
            gridDash=[1,5],
            gridColor=colors["eco-gray"],
            gridOpacity=mo,
            title="",
            titleX=0,
            titleY=-7,
            titleBaseline="bottom",
            titleAngle=0,
            titleAlign="left",
            ticks=False,
            labelPadding=5,
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            domainOpacity=mo,
            tickOpacity=mo,
            labelOpacity=mo+0.2,
            titleOpacity=mo+0.3,
            titleFontSize=12,
            format='.0f',
            tickCount=3
        ),
        scale=alt.Scale(domain=[ymin, ymax],clamp=True),
    ),y2='y22:Q')

label1=line1.mark_text(color=colors['eco-turquiose'],align='left',dx=5,dy=-15,fontSize=12).encode(text='t:N').transform_calculate(t='["Wheat exports", "2017-21 average"]').transform_filter('datum.index>toDate("2022-11-01")')
label2=line2.mark_text(color=colors['eco-yellow'],align='left',dx=5,fontSize=12).encode(text='t:N').transform_calculate(t='["Corn exports", "2017-21 average"]').transform_filter('datum.index>toDate("2022-11-01")')
label3=line3.mark_text(color=colors['eco-turquiose'],align='left',dx=5,dy=5,fontSize=12).encode(text='t:N').transform_calculate(t='["Wheat exports", "2022"]').transform_filter('datum.index>toDate("2022-11-01")')
label4=line4.mark_text(color=colors['eco-yellow'],align='left',dx=5,dy=-20,fontSize=12).encode(text='t:N').transform_calculate(t='["Corn exports", "2022"]').transform_filter('datum.index>toDate("2022-11-01")')
label12=line12.mark_text(color=colors['eco-light-blue'],align='left',dx=5,dy=-20,fontSize=12).encode(text='t:N').transform_calculate(t='["Corn + Wheat", "2017-21 average"]').transform_filter('datum.index>toDate("2022-11-01")')
label34=line34.mark_text(color=colors['eco-dot'],align='left',dx=5,dy=15,fontSize=12).encode(text='t:N').transform_calculate(t='["Corn + Wheat", "2022"]').transform_filter('datum.index>toDate("2022-11-01")')
area1 = alt.Chart(pd.DataFrame([{'x':'2022-03-01','y':ymin,'y2':ymax},{'x':'2022-07-30','y':ymin,'y2':ymax}])).mark_area(color=colors["eco-gray"],opacity=0.1)\
    .encode(x='x:T',y='y:Q',y2='y2:Q')
area2 = alt.Chart(pd.DataFrame([{'x':'2022-08-03','y':ymin,'y2':ymax},{'x':'2022-12-01','y':ymin,'y2':ymax}])).mark_area(color=colors["eco-gray"],opacity=0.1)\
    .encode(x='x:T',y='y:Q',y2='y2:Q')
ylabel1=alt.Chart(pd.DataFrame([{'x':'2022-5-15','y':ymax,'t':['Restricted port activity','March-August 2022']}]))\
    .mark_text(color=colors["eco-gray"],opacity=mo+0.1,align='center',dy=15).encode(x='x:T',y='y:Q',text='t:N')
ylabel2=alt.Chart(pd.DataFrame([{'x':'2022-10-01','y':ymax,'t':'Black Sea Grain Initiative'}]))\
    .mark_text(color=colors["eco-gray"],opacity=mo+0.3,align='center',dy=15).encode(x='x:T',y='y:Q',text='t:N')

layer1t = (
    (xaxis+area1+area2+line1+line2+line3+line4+label1+label2+label3+label4+ylabel1+ylabel2).properties(height=300, width=400, title="")
)
layer1s = (
    (line1234+line12+line34+label12+label34).properties(height=100, width=400, title="")
)
layer1=(layer1t&layer1s).configure(font='Circular Std Book').configure_view(stroke=None)
if SAVE:
    layer1.save("visualisation/" + f + "_no_branding.json")
    layer1.save("visualisation/" + f + "_no_branding.svg")
    layer1.save("visualisation/" + f + "_no_branding.png")
    layer2=dark(f+'_no_branding')
    layer2.save("visualisation/" + f + "_no_branding_dark.json")
    layer2.save("visualisation/" + f + "_no_branding_dark.svg")
    layer2.save("visualisation/" + f + "_no_branding_dark.png")
    
logo=alt.Chart(pd.DataFrame([{"x": xmax, "y": ymax, "img": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/guidelines/logos/eco-icon-dark.png"}]))\
    .mark_image(width=40,height=40,align='right',baseline='top',yOffset=-33,opacity=mo,xOffset=105).encode(x='x:T',y='y:Q',url='img:N')
ecomark=alt.Chart(pd.DataFrame([{"x": xmin, "y": 14}]))\
    .mark_point(size=100,fill=colors['eco-turquiose'],stroke=None,opacity=1,xOffset=-20,yOffset=-20).encode(x='x:T',y='y:Q')
# layer1+=(ecomark)
layer1t+=(logo)

if SAVE:
    layer1.save("visualisation/" + f + ".json")
    layer1.save("visualisation/" + f + ".svg")
    layer1.save("visualisation/" + f + ".png")
    layer2=dark(f)
    layer2.save("visualisation/" + f + "_dark.json")
    layer2.save("visualisation/" + f + "_dark.svg")
    layer2.save("visualisation/" + f + "_dark.png")
    open("README.md", "w").write(readme)

print(f+'\n')
layer1.display()
if SAVE:
    layer2.display()
# Out:
# fig1_wheat
# alt.VConcatChart(...)
# alt.VConcatChart(...)

# %% [markdown]
# # Fig 2

# %%
df = pd.read_excel("raw/Data_20042023.xlsx",usecols='A:E',skiprows=3).dropna()
df.columns=['product','p21','p22','e21','e22']
df=df.set_index('product')
df1=df[['p21','e21']]
df1.columns=['prod','exp']
df1['year']=2021
df2=df[['p22','e22']]
df2.columns=['prod','exp']
df2['year']=2022
df=pd.concat([df1.reset_index(),df2.reset_index()])
# Out:
# /tmp/ipykernel_2859/802864125.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['year']=2021
# /tmp/ipykernel_2859/802864125.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['year']=2022

# %%
readme, f, fc = save(df,"fig2_global_shares",LOCAL)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product</th>
#       <th>prod</th>
#       <th>exp</th>
#       <th>year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Corn</td>
#       <td>3.5</td>
#       <td>12.0</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Wheat</td>
#       <td>4.3</td>
#       <td>9.0</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Sunflower oil</td>
#       <td>30.6</td>
#       <td>46.0</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Sunflower meal</td>
#       <td>27.5</td>
#       <td>54.0</td>
#       <td>2021</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Barley</td>
#       <td>6.8</td>
#       <td>17.0</td>
#       <td>2021</td>
#     </tr>
#   </tbody>
# </table>

# %%
xmin=0
xmax=35
ymin=0
ymax=60
xaxis = alt.Chart(pd.DataFrame([{'x':xmin,'y':0},{'x':xmax,'y':0}])).mark_line(color=colors["eco-gray"],opacity=mo-0.2,strokeWidth=1).encode(
    x=alt.X(
        "x:Q",
        sort=[],
        axis=alt.Axis(
            grid=False,
            titleAlign="right",
            titleAnchor="end",
            title="Ukraine's grain production as share of global production (%) ",
            titleY=-15,
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            tickCount=10,
            domainOpacity=mo,
            tickOpacity=mo,
            labelOpacity=mo+0.2,
            titleOpacity=mo+0.3,
            titleFontSize=12,
            orient="bottom",
            labelAngle=0
        ),
    ),
    y=alt.Y(
        "y:Q",
        sort=[],
        axis=alt.Axis(
            # grid=False,
            gridDash=[1,5],
            gridColor=colors["eco-gray"],
            gridOpacity=mo,
            title="Ukraine's grain export as share of global export (%)",
            titleX=0,
            titleY=-7,
            titleBaseline="bottom",
            titleAngle=0,
            titleAlign="left",
            ticks=False,
            labelPadding=5,
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            domainOpacity=mo,
            tickOpacity=mo,
            labelOpacity=mo+0.2,
            titleOpacity=mo+0.3,
            titleFontSize=12,
            format='.0f',
            tickCount=8
        ),
        # scale=alt.Scale(domain=[ymin, ymax],clamp=True),
    )
)

base = alt.Chart(fc)
points1=base.mark_point(opacity=1).encode(x='prod:Q',y='exp:Q',fill=alt.Color('product:N',legend=None,scale=alt.Scale(
    range=[colors['eco-orange'],colors['eco-yellow'],colors['eco-green'],colors['eco-light-blue'],colors['eco-dot'],colors['eco-turquiose']]
)),color=alt.Color('product:N',legend=None)).transform_filter('datum.year==2021')
points2=base.mark_point(opacity=1,shape='triangle').encode(x='prod:Q',y='exp:Q',fill='product:N',color='product:N').transform_filter('datum.year==2022')
lines=base.mark_line().encode(x='prod:Q',y='exp:Q',color=alt.Color('product:N',scale=alt.Scale(
    range=[colors['eco-orange'],colors['eco-yellow'],colors['eco-green'],colors['eco-light-blue'],colors['eco-dot'],colors['eco-turquiose']]
)))
year=base.mark_text(color=colors['eco-light-blue']).encode(x='prod:Q',y='exp:Q',text='year:N').transform_filter('datum.product=="Sunflower meal"')
year1=year.mark_text(color=colors['eco-light-blue'],dx=20).transform_filter('datum.year==2021')
year2=year.mark_text(color=colors['eco-light-blue'],dx=-20).transform_filter('datum.year==2022')
label1=lines.mark_text(dx=-5,dy=15,align='left').encode(text='product:N').transform_filter('datum.year==2021').transform_filter('datum.product=="Sunflower meal"')
label2=lines.mark_text(dx=50,dy=-15,align='left').encode(text='product:N').transform_filter('datum.year==2022').transform_filter('datum.product=="Sunflower oil"')
label3=lines.mark_text(dx=10,dy=5,align='left').encode(text='product:N').transform_filter('datum.year==2021').transform_filter('datum.product=="Wheat"')
label4=lines.mark_text(dx=5,dy=-8,align='left').encode(text='product:N').transform_filter('datum.year==2021').transform_filter('datum.product=="Rapseed"')
label5=lines.mark_text(dx=-7,dy=0,align='right').encode(text='product:N').transform_filter('datum.year==2021').transform_filter('datum.product=="Corn"')
label6=lines.mark_text(dx=5,dy=0,align='left').encode(text='product:N').transform_filter('datum.year==2021').transform_filter('datum.product=="Barley"')
ylabel1=alt.Chart(pd.DataFrame([{'x':12,'y':31.5,'t':['↓ drop in export share but','not in production share']}]))\
    .mark_text(color=colors["eco-gray"],opacity=mo+0.1,align='right',dy=-20).encode(x='x:Q',y='y:Q',text='t:N')
ylabel2=alt.Chart(pd.DataFrame([{'x':34,'y':26.5,'t':['↙ drop both in export share', '‪‪and in production share']}]))\
    .mark_text(color=colors["eco-gray"],opacity=mo+0.1,align='right',dy=0).encode(x='x:Q',y='y:Q',text='t:N')

layer1 = (
    (xaxis+points1+points2+lines+year1+year2+label1+label2+label3+label4+label5+label6+ylabel1+ylabel2).properties(height=300, width=400, title="")
).configure(font='Circular Std Book').configure_view(stroke=None)
if SAVE:
    layer1.save("visualisation/" + f + "_no_branding.json")
    layer1.save("visualisation/" + f + "_no_branding.svg")
    layer1.save("visualisation/" + f + "_no_branding.png")
    layer2=dark(f+'_no_branding')
    layer2.save("visualisation/" + f + "_no_branding_dark.json")
    layer2.save("visualisation/" + f + "_no_branding_dark.svg")
    layer2.save("visualisation/" + f + "_no_branding_dark.png")
    
logo=alt.Chart(pd.DataFrame([{"x": xmax, "y": ymax, "img": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/guidelines/logos/eco-icon-dark.png"}]))\
    .mark_image(width=40,height=40,align='right',baseline='top',yOffset=-33,opacity=mo,xOffset=0).encode(x='x:Q',y='y:Q',url='img:N')
ecomark=alt.Chart(pd.DataFrame([{"x": xmin, "y": ymax}]))\
    .mark_point(size=100,fill=colors['eco-turquiose'],stroke=None,opacity=1,xOffset=-20,yOffset=-20).encode(x='x:Q',y='y:Q')
# layer1+=(ecomark)
layer1+=(logo)

if SAVE:
    layer1.save("visualisation/" + f + ".json")
    layer1.save("visualisation/" + f + ".svg")
    layer1.save("visualisation/" + f + ".png")
    layer2=dark(f)
    layer2.save("visualisation/" + f + "_dark.json")
    layer2.save("visualisation/" + f + "_dark.svg")
    layer2.save("visualisation/" + f + "_dark.png")
    open("README.md", "a").write(readme)

print(f+'\n')
layer1.display()
if SAVE:
    layer2.display()
# Out:
# fig2_global_shares
# alt.LayerChart(...)
# alt.LayerChart(...)

# %% [markdown]
# # Fig 3

# %%
df = pd.read_excel("raw/Data_20042023.xlsx",usecols='H:I',skiprows=3).dropna()

# %%
readme, f, fc = save(df,"fig3_distribution",LOCAL)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>World Bank Classification</th>
#       <th>Grain export (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Low-income</td>
#       <td>2.6</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Lower-middle-income</td>
#       <td>16.5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Upper-middle-income</td>
#       <td>36.3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>High-income</td>
#       <td>44.6</td>
#     </tr>
#   </tbody>
# </table>

# %%
base=alt.Chart(fc).mark_arc(innerRadius=75).encode(
    theta="Grain export (%):Q",
    color=alt.Color("World Bank Classification:N",legend=None,scale=alt.Scale(
    range=[colors['eco-turquiose'],colors['eco-orange'],colors['eco-yellow'],colors['eco-light-blue']]
))).transform_calculate(y='datum["World Bank Classification"]+" "+datum["Grain export (%)"]+"%"')
label1=base.mark_text(dx=170,dy=-120,fontSize=12).encode(text="y:N").transform_filter('datum["World Bank Classification"]=="High-income"')
label2=base.mark_text(dx=170,dy=120,fontSize=12).encode(text="y:N").transform_filter('datum["World Bank Classification"]=="Low-income"')
label3=base.mark_text(dx=-180,dy=120,fontSize=12).encode(text="y:N").transform_filter('datum["World Bank Classification"]=="Lower-middle-income"')
label4=base.mark_text(dx=-180,dy=-120,fontSize=12).encode(text="y:N").transform_filter('datum["World Bank Classification"]=="Upper-middle-income"')
label=alt.Chart(fc).mark_text(fontSize=12,dy=-15,color=colors['eco-gray'],text=['Global distribution of', 'Ukraine’s export under the', 'Black Sea Agreement','as of Jan 2023'])
layer1 = (
    (base+label1+label2+label3+label4+label).properties(height=300, width=400, title="")
).configure(font='Circular Std Book').configure_view(stroke=None)
if SAVE:
    layer1.save("visualisation/" + f + "_no_branding.json")
    layer1.save("visualisation/" + f + "_no_branding.svg")
    layer1.save("visualisation/" + f + "_no_branding.png")
    layer2=dark(f+'_no_branding')
    layer2.save("visualisation/" + f + "_no_branding_dark.json")
    layer2.save("visualisation/" + f + "_no_branding_dark.svg")
    layer2.save("visualisation/" + f + "_no_branding_dark.png")
    
logo=alt.Chart(pd.DataFrame([{"x": 1, "y": 1, "img": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/guidelines/logos/eco-icon-dark.png"}]))\
    .mark_image(width=40,height=40,align='right',baseline='top',yOffset=-33,opacity=mo,xOffset=30).encode(x=alt.X('x:Q',axis=None),y=alt.Y('y:Q',axis=None),url='img:N')
ecomark=alt.Chart(pd.DataFrame([{"x": xmin, "y": 14}]))\
    .mark_point(size=100,fill=colors['eco-turquiose'],stroke=None,opacity=1,xOffset=-20,yOffset=-20).encode(x='x:Q',y='y:Q')
# layer1+=(ecomark)
layer1+=(logo)

if SAVE:
    layer1.save("visualisation/" + f + ".json")
    layer1.save("visualisation/" + f + ".svg")
    layer1.save("visualisation/" + f + ".png")
    layer2=dark(f)
    layer2.save("visualisation/" + f + "_dark.json")
    layer2.save("visualisation/" + f + "_dark.svg")
    layer2.save("visualisation/" + f + "_dark.png")
    open("README.md", "a").write(readme)

print(f+'\n')
layer1.display()
if SAVE:
    layer2.display()
# Out:
# fig3_distribution
# alt.LayerChart(...)
# alt.LayerChart(...)

# %% [markdown]
# # Fig 4

# %%
df = pd.read_excel("raw/Data_20042023.xlsx",usecols='L',skiprows=3).dropna()
df['month']=[str(2022+i//12)+'.'+str(i%12+1)+'.01' for i in range(0,15)]

# %%
readme, f, fc = save(df,"fig4_price_index",LOCAL)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Food Price Index</th>
#       <th>month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>135.594155</td>
#       <td>2022.1.01</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>141.235450</td>
#       <td>2022.2.01</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>159.713180</td>
#       <td>2022.3.01</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>158.435041</td>
#       <td>2022.4.01</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>158.052830</td>
#       <td>2022.5.01</td>
#     </tr>
#   </tbody>
# </table>

# %%
xmin='2022-01-01'
xmax='2023-03-01'
ymin=100
ymax=180
xaxis = alt.Chart(pd.DataFrame([{'x':xmin,'y':100},{'x':xmax,'y':100}])).mark_line(color=colors["eco-gray"],opacity=mo-0.2,strokeWidth=1).encode(
    x=alt.X(
        "x:T",
        sort=[],
        axis=alt.Axis(
            grid=False,
            titleAlign="center",
            titleAnchor="middle",
            title="",
            titleY=-15,
            titleX=207,
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            tickCount=10,
            domainOpacity=mo,
            tickOpacity=mo,
            labelOpacity=mo+0.2,
            titleOpacity=mo+0.3,
            titleFontSize=12,
            orient="bottom",
            labelAngle=0
        ),
    ),
    y=alt.Y(
        "y:Q",
        sort=[],
        axis=alt.Axis(
            # grid=False,
            gridDash=[1,5],
            gridColor=colors["eco-gray"],
            gridOpacity=mo,
            title="FAO price index",
            titleX=0,
            titleY=-7,
            titleBaseline="bottom",
            titleAngle=0,
            titleAlign="left",
            ticks=False,
            labelPadding=5,
            labelColor=colors["eco-gray"],
            titleColor=colors["eco-gray"],
            tickColor=colors["eco-gray"],
            domainColor=colors["eco-gray"],
            domainOpacity=mo,
            tickOpacity=mo,
            labelOpacity=mo+0.2,
            titleOpacity=mo+0.3,
            titleFontSize=12,
            format='.0f',
            tickCount=8
        ),
        scale=alt.Scale(domain=[ymin, ymax],clamp=True),
    )
)

base = alt.Chart(fc).encode(x='month:T')
line1=area(base,colors['eco-turquiose']).encode(y='Food Price Index:Q')
yaxis=alt.Chart(pd.DataFrame([{'x':'2022-07-22','y':ymin},{'x':'2022-07-22','y':ymax}])).mark_line(color=colors["eco-gray"],opacity=mo-0.2,strokeWidth=1).encode(x='x:T',y='y:Q')
ylabel=alt.Chart(pd.DataFrame([{'x':'2022-07-22','y':ymax,'t':'Grain deal signed'}]))\
    .mark_text(color=colors["eco-gray"],opacity=mo+0.1,align='left',dx=5,dy=12).encode(x='x:T',y='y:Q',text='t:N')

layer1 = (
    (xaxis+line1+yaxis+ylabel).properties(height=300, width=400, title="")
).configure(font='Circular Std Book').configure_view(stroke=None)
if SAVE:
    layer1.save("visualisation/" + f + "_no_branding.json")
    layer1.save("visualisation/" + f + "_no_branding.svg")
    layer1.save("visualisation/" + f + "_no_branding.png")
    layer2=dark(f+'_no_branding')
    layer2.save("visualisation/" + f + "_no_branding_dark.json")
    layer2.save("visualisation/" + f + "_no_branding_dark.svg")
    layer2.save("visualisation/" + f + "_no_branding_dark.png")
    
logo=alt.Chart(pd.DataFrame([{"x": xmax, "y": ymax, "img": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/guidelines/logos/eco-icon-dark.png"}]))\
    .mark_image(width=40,height=40,align='right',baseline='top',yOffset=-33,opacity=mo,xOffset=0).encode(x='x:T',y='y:Q',url='img:N')
ecomark=alt.Chart(pd.DataFrame([{"x": xmin, "y": 14}]))\
    .mark_point(size=100,fill=colors['eco-turquiose'],stroke=None,opacity=1,xOffset=-20,yOffset=-20).encode(x='x:T',y='y:Q')
# layer1+=(ecomark)
layer1+=(logo)

if SAVE:
    layer1.save("visualisation/" + f + ".json")
    layer1.save("visualisation/" + f + ".svg")
    layer1.save("visualisation/" + f + ".png")
    layer2=dark(f)
    layer2.save("visualisation/" + f + "_dark.json")
    layer2.save("visualisation/" + f + "_dark.svg")
    layer2.save("visualisation/" + f + "_dark.png")
    open("README.md", "a").write(readme)

print(f+'\n')
layer1.display()
if SAVE:
    layer2.display()
# Out:
# fig4_price_index
# alt.LayerChart(...)
# alt.LayerChart(...)

# %% [markdown]
# ## Export collage

# %% [markdown]
# First run static exports for both themes with `SAVE` `False` and `True`, LOCAL `True` and `False`

# %% [markdown]
# ### Extract text

# %%
# !pip install textract

# %%
import textract, re
from os import listdir
from os.path import isfile, join

if SAVE and not LOCAL:
    path='draft/'
    article = [f for f in listdir(path) if isfile(join(path, f))][0]
    text = textract.process(path+article)
    text = text.decode("utf-8") 

    text = re.sub(r'\n+', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()

# %%
# !pip install openai

# %%
if SAVE and not LOCAL:
    import openai
    # Set up the OpenAI API client
    openai.api_key = "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"
    # Generate a response
    completion = openai.Completion.create(
        engine="text-davinci-003",
        prompt='Summarize this in maximum 3 sentences: '+text+'; Summary:',
        max_tokens=200,
        n=1,
        stop=None,
        temperature=0.5,
    )

    summary = completion.choices[0].text.strip()
    print(summary)
# Out:
# The Black Sea Agreement has improved global food supply conditions by allowing grain exports from Ukraine, but production-related obstacles, as well as the ongoing conflict, are still a threat to global food security. Local food prices are not fully reflecting the gains from the fall in international food prices due to rising input costs, and food exports are mainly going to high-income countries. To ensure global food security, the war must end.

# %% [markdown]
# ### Make collage

# %%
from os import listdir
from os.path import isfile, join
path='visualisation/'
onlyfiles = [f for f in listdir(path) if isfile(join(path, f))]
figs=[i.replace('.html','') for i in onlyfiles if i[-5:]=='.html' and 'local' not in i]

# %%
if SAVE and not LOCAL:
    readme='  \n\n## Infographics  \nSummary auto-generated using [ChatGPT](https://chat.openai.com/)  '
    open("README.md", "a").write(readme)
    config=json.load(open('config.json','r'))
    d=30

    n=19
    summary_split=re.findall(" ".join(["[^ ]+"]*n), summary)
    summary_split+=[summary.split(summary_split[-1])[1]]

    base=alt.Chart(pd.DataFrame([{"x": 0, "y": 0}])).encode(x=alt.X('x:Q',axis=None),y=alt.Y('y:Q',axis=None)).mark_point(stroke=None)
    for theme in ['light','dark']:
        if theme=='light':
            z=''
            tcolor=colors['eco-gray']
            bg='white'
        else:
            z='_dark'
            tcolor=service_color
            bg=colors['eco-background']

        p1=alt.Chart(pd.DataFrame([{"x": 0, "y": 0, "img": eco_git_path.replace('/data/','/')+"visualisation/" + figs[0] + z+ ".png"}]))\
            .mark_image(height=300,width=400,align='right',baseline='bottom',xOffset=-d,yOffset=-d).encode(x='x:Q',y='y:Q',url='img:N')
        p2=alt.Chart(pd.DataFrame([{"x": 0, "y": 0, "img": eco_git_path.replace('/data/','/')+"visualisation/" + figs[1] + z+ ".png"}]))\
            .mark_image(height=300,width=400,align='left',baseline='bottom',xOffset=d,yOffset=-d).encode(x='x:Q',y='y:Q',url='img:N')
        p3=alt.Chart(pd.DataFrame([{"x": 0, "y": 0, "img": eco_git_path.replace('/data/','/')+"visualisation/" + figs[2] + z+ ".png"}]))\
            .mark_image(height=300,width=400,align='right',baseline='top',xOffset=-d,yOffset=d).encode(x='x:Q',y='y:Q',url='img:N')
        p4=alt.Chart(pd.DataFrame([{"x": 0, "y": 0, "img": eco_git_path.replace('/data/','/')+"visualisation/" + figs[3] + z+ ".png"}]))\
            .mark_image(height=300,width=400,align='left',baseline='top',xOffset=d,yOffset=d).encode(x='x:Q',y='y:Q',url='img:N')
        logo=alt.Chart(pd.DataFrame([{"x": 0, "y": 0, "img": "https://raw.githubusercontent.com/EconomicsObservatory/ECOvisualisations/main/guidelines/logos/eco-logo-"+theme+ ".png"}]))\
            .mark_image(width=200,height=300,align='center',baseline='middle',opacity=0.9,yOffset=450+3*d,xOffset=190+d).encode(x='x:Q',y='y:Q',url='img:N')
        abstract=alt.Chart(pd.DataFrame([{"x": 0, "y": 0,'t':summary_split}])).mark_text(color=tcolor,fontSize=15,yOffset=-460,
            lineHeight=22,baseline='bottom').encode(x='x:Q',y='y:Q',text='t:N')

        layer1= (base+p1+p2+p3+p4+logo+abstract).properties(height=300, width=400, title=config['title']).configure(font='Circular Std Book',padding=50,background=bg)\
            .configure_view(stroke=None).configure_title(fontSize=30,offset=50,color=tcolor)

        # layer1.save("visualisation/collage_"+theme+".png")
        # layer1.display()
        
        readme='  \n\n### '+theme.title()+' theme  \n\n!["' + f + '"](visualisation/collage_'+theme+'.png " collage_'+theme + '")'
        open("README.md", "a").write(readme)
# Out:
# alt.Chart(...)
